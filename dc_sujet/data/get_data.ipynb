# %%
import pandas as pd
import numpy as np

# %%
url = 'https://www.data.gouv.fr/fr/datasets/r/5c4e1452-3850-4b59-b11c-3dd51d7fb8b5'
df = pd.read_csv(url, dtype={'dep': 'str'})

df.head()
# Out:
#   dep        date  reg lib_dep                  lib_reg  tx_pos  tx_incid  \
# 0  01  2020-03-18   84     Ain  Auvergne et Rhône-Alpes     NaN       NaN
# 1  01  2020-03-19   84     Ain  Auvergne et Rhône-Alpes     NaN       NaN
# 2  01  2020-03-20   84     Ain  Auvergne et Rhône-Alpes     NaN       NaN
# 3  01  2020-03-21   84     Ain  Auvergne et Rhône-Alpes     NaN       NaN
# 4  01  2020-03-22   84     Ain  Auvergne et Rhône-Alpes     NaN       NaN
#
#          TO   R  hosp  ...  dchosp  reg_rea  incid_hosp  incid_rea  incid_rad  \
# 0  0.062612 NaN     2  ...       0       35         NaN        NaN        NaN
# 1  0.132379 NaN     2  ...       0       79         1.0        0.0        0.0
# 2  0.155635 NaN     2  ...       0       87         0.0        0.0        1.0
# 3  0.173524 NaN     4  ...       0       88         3.0        0.0        0.0
# 4  0.212880 NaN     8  ...       0      106         3.0        1.0        1.0
#
#    incid_dchosp  reg_incid_rea  pos  pos_7j  cv_dose1
# 0           NaN            NaN  NaN     NaN       NaN
# 1           0.0           44.0  NaN     NaN       NaN
# 2           0.0           16.0  NaN     NaN       NaN
# 3           0.0           15.0  NaN     NaN       NaN
# 4           0.0           25.0  NaN     NaN       NaN
#
# [5 rows x 22 columns]

# %%
# Check types
df.dtypes
# Out:
# dep               object
# date              object
# reg                int64
# lib_dep           object
# lib_reg           object
# tx_pos           float64
# tx_incid         float64
# TO               float64
# R                float64
# hosp               int64
# rea                int64
# rad                int64
# dchosp             int64
# reg_rea            int64
# incid_hosp       float64
# incid_rea        float64
# incid_rad        float64
# incid_dchosp     float64
# reg_incid_rea    float64
# pos              float64
# pos_7j           float64
# cv_dose1         float64
# dtype: object

# %%
# Set multi index
df = df.set_index(['date', 'dep']).sort_index()

# %%
df.tail(10)
# Out:
#                 reg            lib_dep        lib_reg  tx_pos  tx_incid  \
# date       dep
# 2022-04-11 91    11            Essonne  Île-de-France     NaN       NaN
#            92    11     Hauts-de-Seine  Île-de-France     NaN       NaN
#            93    11  Seine-Saint-Denis  Île-de-France     NaN       NaN
#            94    11       Val-de-Marne  Île-de-France     NaN       NaN
#            95    11         Val-d'Oise  Île-de-France     NaN       NaN
#            971    1         Guadeloupe     Guadeloupe     NaN       NaN
#            972    2         Martinique     Martinique     NaN       NaN
#            973    3             Guyane         Guyane     NaN       NaN
#            974    4            Réunion        Réunion     NaN       NaN
#            976    6            Mayotte        Mayotte     NaN       NaN
#
#                       TO   R  hosp  rea    rad  dchosp  reg_rea  incid_hosp  \
# date       dep
# 2022-04-11 91   0.335658 NaN   412   45  13831    2399      385        36.0
#            92   0.335658 NaN   902   70  20265    3349      385        55.0
#            93   0.335658 NaN   713   34  18095    3002      385        38.0
#            94   0.335658 NaN   594   42  19459    3646      385        48.0
#            95   0.335658 NaN   346   11  12992    2527      385        24.0
#            971  0.296296 NaN    63    8   4369    1031        8         0.0
#            972  0.192308 NaN    84    5   3820     918        5         0.0
#            973  0.153846 NaN    16    2   5529     387        2         0.0
#            974  0.288462 NaN   310   15   5956     749       15        39.0
#            976  0.000000 NaN     7    0   1652     162        0         0.0
#
#                 incid_rea  incid_rad  incid_dchosp  reg_incid_rea  pos  \
# date       dep
# 2022-04-11 91         2.0        7.0           4.0           22.0  NaN
#            92         5.0       49.0           4.0           22.0  NaN
#            93         0.0        9.0           2.0           22.0  NaN
#            94         2.0       38.0           4.0           22.0  NaN
#            95         1.0       11.0           1.0           22.0  NaN
#            971        0.0        5.0           0.0            0.0  NaN
#            972        0.0        0.0           0.0            0.0  NaN
#            973        0.0        3.0           0.0            0.0  NaN
#            974        1.0       25.0           1.0            1.0  NaN
#            976        0.0        0.0           0.0            0.0  NaN
#
#                 pos_7j  cv_dose1
# date       dep
# 2022-04-11 91      NaN       NaN
#            92      NaN       NaN
#            93      NaN       NaN
#            94      NaN       NaN
#            95      NaN       NaN
#            971     NaN       NaN
#            972     NaN       NaN
#            973     NaN       NaN
#            974     NaN       NaN
#            976     NaN       NaN

# %%
# Get info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 76255 entries, ('2020-03-18', '01') to ('2022-04-11', '976')
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reg            76255 non-null  int64
#  1   lib_dep        76255 non-null  object
#  2   lib_reg        76255 non-null  object
#  3   tx_pos         69690 non-null  float64
#  4   tx_incid       69690 non-null  float64
#  5   TO             76255 non-null  float64
#  6   R              11611 non-null  float64
#  7   hosp           76255 non-null  int64
#  8   rea            76255 non-null  int64
#  9   rad            76255 non-null  int64
#  10  dchosp         76255 non-null  int64
#  11  reg_rea        76255 non-null  int64
#  12  incid_hosp     76154 non-null  float64
#  13  incid_rea      76154 non-null  float64
#  14  incid_rad      76154 non-null  float64
#  15  incid_dchosp   76154 non-null  float64
#  16  reg_incid_rea  76154 non-null  float64
#  17  pos            70296 non-null  float64
#  18  pos_7j         69690 non-null  float64
#  19  cv_dose1       101 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 11.9+ MB

# %%
# Look into R
df[df['R'].isnull() == False].loc[(slice(None), '75'),'R'].plot()
# Out:
# <AxesSubplot:xlabel='date,dep'>

# %%
# Look into both pos'
df[df['pos'].isnull() == False].loc[(slice(None), '75'),'pos':'pos_7j'].tail()
# Out:
#                    pos   pos_7j
# date       dep
# 2022-04-04 75   6325.0  31569.0
# 2022-04-05 75   4714.0  30615.0
# 2022-04-06 75   4950.0  29863.0
# 2022-04-07 75   4284.0  29419.0
# 2022-04-08 75   3688.0  29074.0

# %%
df = df.drop(['R', 'cv_dose1', 'rad', 'incid_rad'], axis=1)

# %%
# Set tx_pos NaN to mean
x = df.reset_index()['tx_pos'].mean()
df['tx_pos'].fillna(x, inplace=True)
# Out:
#                 reg                  lib_dep                     lib_reg  \
# date       dep
# 2020-03-18 01    84                      Ain     Auvergne et Rhône-Alpes
#            02    32                    Aisne             Hauts-de-France
#            03    84                   Allier     Auvergne et Rhône-Alpes
#            04    93  Alpes-de-Haute-Provence  Provence-Alpes-Côte d'Azur
#            05    93             Hautes-Alpes  Provence-Alpes-Côte d'Azur
#
#                   tx_pos  tx_incid        TO  hosp  rea  dchosp  reg_rea  \
# date       dep
# 2020-03-18 01   7.892493       NaN  0.062612     2    0       0       35
#            02   7.892493       NaN  0.198630    41   10      11       87
#            03   7.892493       NaN  0.062612     4    0       0       35
#            04   7.892493       NaN  0.052174     3    1       0       24
#            05   7.892493       NaN  0.052174     8    1       0       24
#
#                 incid_hosp  incid_rea  incid_dchosp  reg_incid_rea  pos  \
# date       dep
# 2020-03-18 01          NaN        NaN           NaN            NaN  NaN
#            02          NaN        NaN           NaN            NaN  NaN
#            03          NaN        NaN           NaN            NaN  NaN
#            04          NaN        NaN           NaN            NaN  NaN
#            05          NaN        NaN           NaN            NaN  NaN
#
#                 pos_7j
# date       dep
# 2020-03-18 01      NaN
#            02      NaN
#            03      NaN
#            04      NaN
#            05      NaN

# %%
# Set tx_incid NaN to mean
x = df.reset_index()['tx_incid'].mean()
df['tx_incid'].fillna(x, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 76255 entries, ('2020-03-18', '01') to ('2022-04-11', '976')
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reg            76255 non-null  int64
#  1   lib_dep        76255 non-null  object
#  2   lib_reg        76255 non-null  object
#  3   tx_pos         76255 non-null  float64
#  4   tx_incid       76255 non-null  float64
#  5   TO             76255 non-null  float64
#  6   hosp           76255 non-null  int64
#  7   rea            76255 non-null  int64
#  8   dchosp         76255 non-null  int64
#  9   reg_rea        76255 non-null  int64
#  10  incid_hosp     76154 non-null  float64
#  11  incid_rea      76154 non-null  float64
#  12  incid_dchosp   76154 non-null  float64
#  13  reg_incid_rea  76154 non-null  float64
#  14  pos            70296 non-null  float64
#  15  pos_7j         69690 non-null  float64
# dtypes: float64(9), int64(5), object(2)
# memory usage: 11.6+ MB

# %%
df['pos'].fillna(0, inplace=True)

x = df.reset_index()['pos_7j'].mean()
df['pos_7j'].fillna(x, inplace=True)

# %%
columns = ['incid_hosp', 'incid_rea', 'incid_dchosp', 'reg_incid_rea']
df[columns] = df[columns].fillna(0)

# %%
# Corr matrix
df.corr()
# Out:
#                     reg    tx_pos  tx_incid        TO      hosp       rea  \
# reg            1.000000 -0.002825  0.013604 -0.108317 -0.185318 -0.151482
# tx_pos        -0.002825  1.000000  0.815227  0.275816  0.198537  0.100505
# tx_incid       0.013604  0.815227  1.000000  0.247401  0.193538  0.135834
# TO            -0.108317  0.275816  0.247401  1.000000  0.463724  0.475840
# hosp          -0.185318  0.198537  0.193538  0.463724  1.000000  0.908717
# rea           -0.151482  0.100505  0.135834  0.475840  0.908717  1.000000
# dchosp        -0.204141  0.137571  0.199453  0.103754  0.588290  0.550529
# reg_rea       -0.078500  0.166379  0.171403  0.615182  0.680844  0.670022
# incid_hosp    -0.103323  0.279403  0.304778  0.442157  0.755062  0.753001
# incid_rea     -0.109994  0.131258  0.162203  0.400933  0.693871  0.782903
# incid_dchosp  -0.097808  0.148539  0.140562  0.467151  0.732661  0.720793
# reg_incid_rea -0.038614  0.207456  0.213355  0.524273  0.525261  0.545871
# pos           -0.043368  0.495280  0.696765  0.145552  0.344699  0.294142
# pos_7j        -0.046840  0.555403  0.769365  0.187735  0.401626  0.341807
#
#                  dchosp   reg_rea  incid_hosp  incid_rea  incid_dchosp  \
# reg           -0.204141 -0.078500   -0.103323  -0.109994     -0.097808
# tx_pos         0.137571  0.166379    0.279403   0.131258      0.148539
# tx_incid       0.199453  0.171403    0.304778   0.162203      0.140562
# TO             0.103754  0.615182    0.442157   0.400933      0.467151
# hosp           0.588290  0.680844    0.755062   0.693871      0.732661
# rea            0.550529  0.670022    0.753001   0.782903      0.720793
# dchosp         1.000000  0.336802    0.411403   0.410640      0.312092
# reg_rea        0.336802  1.000000    0.565078   0.527327      0.573002
# incid_hosp     0.411403  0.565078    1.000000   0.842338      0.780803
# incid_rea      0.410640  0.527327    0.842338   1.000000      0.698743
# incid_dchosp   0.312092  0.573002    0.780803   0.698743      1.000000
# reg_incid_rea  0.252512  0.822494    0.655773   0.641620      0.562729
# pos            0.428018  0.189877    0.485179   0.349674      0.261238
# pos_7j         0.445579  0.234632    0.486889   0.344233      0.263709
#
#                reg_incid_rea       pos    pos_7j
# reg                -0.038614 -0.043368 -0.046840
# tx_pos              0.207456  0.495280  0.555403
# tx_incid            0.213355  0.696765  0.769365
# TO                  0.524273  0.145552  0.187735
# hosp                0.525261  0.344699  0.401626
# rea                 0.545871  0.294142  0.341807
# dchosp              0.252512  0.428018  0.445579
# reg_rea             0.822494  0.189877  0.234632
# incid_hosp          0.655773  0.485179  0.486889
# incid_rea           0.641620  0.349674  0.344233
# incid_dchosp        0.562729  0.261238  0.263709
# reg_incid_rea       1.000000  0.273006  0.266247
# pos                 0.273006  1.000000  0.906704
# pos_7j              0.266247  0.906704  1.000000

# %%
df.to_pickle('covid-all-stats-departments')
