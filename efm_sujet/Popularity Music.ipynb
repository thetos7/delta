# %%
import pandas as pd
import ast

# %%
artists = pd.read_csv("data/artists.csv", converters={2:ast.literal_eval})
artists
# Out:
#                              id  followers          genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0              []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0              []
# 2        0DmRESX2JknGPQyO15yxg7        0.0              []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0              []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0              []
# ...                         ...        ...             ...
# 1162090  3cOzi726Iav1toV2LRVEjp     4831.0  [black comedy]
# 1162091  6LogY6VMM3jgAE6fPzXeMl       46.0              []
# 1162092  19boQkDEIay9GaVAWkUhTa      257.0              []
# 1162093  5nvjpU3Y7L6Hpe54QuvDjy     2357.0  [black comedy]
# 1162094  2bP2cNhNBdKXHC6AnqgyVp       40.0    [new comedy]
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# ...

# %%
test = []
for ele in list(artists.genres):
    test.extend(ele)
test
# Out:
# ['carnaval cadiz',
#  'carnaval cadiz',
#  'carnaval cadiz',
#  'carnaval cadiz',
#  'classical harp',
#  'harp',
#  'classical contralto',
#  'british choir',
#  "children's story",
#  'classic persian pop',
#  'persian traditional',
#  'desi pop',
#  'punjabi hip hop',
#  'punjabi pop',
#  'afro dancehall',
#  'afropop',
#  'azontobeats',
#  'nigerian hip hop',
#  'nigerian pop',
#  'filmi',
#  'indian folk',
#  'indian rock',
#  'kannada pop',
#  'indian fusion',
#  'desi pop',
#  'hindi indie',
#  'indian indie',
#  'indian rock',
#  'new delhi indie',
#  'sufi',
#  'russian electronic',
#  'swedish electropop',
#  'indian folk',
#  'khaliji',
#  'sheilat',
#  'desi pop',
#  'modern bollywood',
#  'afro dancehall',
#  'afropop',
#  'alte',
#  'nigerian pop',
#  'environmental',
#  'sleep',
#  'desi hip hop',
#  'tamil pop',
#  'opm',
#  'pinoy hip hop',
#  'pinoy r&b',
#  'pinoy trap',
#  'tagalog rap',
#  'kuduro',
#  'australian hip hop',
#  'australian trap',
#  'afropop',
# ...

# %%
songs = pd.read_csv("data/tracks.csv")
songs.drop(songs[songs["popularity"] == 0].index, inplace = True)
songs
# Out:
#                             id                                       name  \
# 0       35iwgR4jXetI318WEWsa1Q                                      Carve
# 13      0QiT0Oo5QdLXdFw6RDOj7h                       Tu Verras Montmartre
# 26      112adU33vo4C1eRZct2hWy                             Nuits De Chine
# 149     2wAfHM7Whz67VFbdanhZlk  Nobody Knows You When You're Down and Out
# 150     3eMrYc092k7SIJfWJ7oasR                               Weather Bird
# ...                        ...                                        ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                        云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                      blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2                  What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                            A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                           Mar de Emociones
#
#         popularity  duration_ms  explicit                            artists  \
# ...

# %%
from collections import Counter #Ajouter collections dans 
c = Counter(test)
c
# Out:
# Counter({'carnaval cadiz': 69,
#          'classical harp': 86,
#          'harp': 120,
#          'classical contralto': 45,
#          'british choir': 158,
#          "children's story": 67,
#          'classic persian pop': 157,
#          'persian traditional': 152,
#          'desi pop': 346,
#          'punjabi hip hop': 48,
#          'punjabi pop': 242,
#          'afro dancehall': 163,
#          'afropop': 323,
#          'azontobeats': 304,
#          'nigerian hip hop': 75,
#          'nigerian pop': 224,
#          'filmi': 381,
#          'indian folk': 40,
#          'indian rock': 85,
#          'kannada pop': 39,
#          'indian fusion': 45,
#          'hindi indie': 48,
#          'indian indie': 159,
#          'new delhi indie': 29,
#          'sufi': 227,
#          'russian electronic': 84,
#          'swedish electropop': 75,
#          'khaliji': 105,
#          'sheilat': 31,
#          'modern bollywood': 212,
#          'alte': 46,
# ...

# %%
df = pd.read_csv("data//album_ratings.csv")
df
# Out:
#                             Artist                                    Title  \
# 0                        Neko Case                           Middle Cyclone
# 1      Jason Isbell & The 400 Unit              Jason Isbell & The 400 Unit
# 2                Animal Collective               Merriweather Post Pavilion
# 3                Bruce Springsteen                       Working on a Dream
# 4                      Andrew Bird                              Noble Beast
# ...                            ...                                      ...
# 32353           Death Valley Girls                   Under the Spell of Joy
# 32354                     Gorillaz  Song Machine, Season One: Strange Timez
# 32355                 Tobin Sprout                             Empty Horses
# 32356                  Jeremy Ivey                    Waiting out the Storm
# 32357                Delmer Darion                         Morning Pageants
#
# ...

# %%
test = df["Release Year"].unique()
test.sort()
test
# Out:
# array([1940, 1946, 1947, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957,
#        1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968,
#        1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
#        1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
test = df["Genre"].unique()
len(test)
# Out:
# 294

# %%
genres = df.groupby("Genre").count()
genres
#genres.loc[:,"Metacritic Reviews"]
# Out:
#                   Artist  Title  Release Month  Release Day  Release Year  \
# Genre
# AOR                    5      5              4            4             5
# Abstract Hip Hop      49     49             49           49            49
# Acid House            12     12             11           11            12
# Acid Jazz              6      6              6            6             6
# Acid Techno            4      4              3            3             4
# ...                  ...    ...            ...          ...           ...
# Witch House            9      9              9            9             9
# Wonky                 41     41             41           41            41
# World                 25     25             24           24            25
# Yacht Rock             4      4              3            3             4
# YÃ©-yÃ©                3      3              3            3             3
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(genres.loc[:, "Metacritic User Reviews"].sort_values(ascending = False).head())

# %%
genres.sort_values(by= "Title", ascending = False)
# Out:
#                    Artist  Title  Release Month  Release Day  Release Year  \
# Genre
# Hip Hop              1714   1714           1710         1710          1714
# Indie Rock           1631   1631           1631         1631          1631
# Indie Pop            1022   1022           1022         1022          1022
# Alternative Rock     1014   1014           1014         1014          1014
# Singer-Songwriter     953    953            944          944           953
# ...                   ...    ...            ...          ...           ...
# Flamenco nuevo          1      1              1            1             1
# Field Recordings        1      1              1            1             1
# Exotica                 1      1              0            0             1
# EDM                     1      1              1            1             1
# Future Bass             1      1              1            1             1
#
# ...

# %%
genresMean = df.groupby("Genre").mean()
genresMean.sort_values(by= "Metacritic Critic Score", ascending = False, inplace =  True)
genresMean
#genresMean.iloc[0:3]
#genresMean.loc["Indie Pop", "Metacritic Critic Score"]
plt.figure(figsize=(15,5))
plt.plot(genresMean.iloc[0:10].loc[:,"Metacritic Critic Score"])

# %%
df[df["Genre"] == "Blackgaze"]
# Out:
#                                 Artist  \
# 3454                            Alcest
# 5013                        Deafheaven
# 12407  An Autumn for Crippled Children
# 17247                        Astronoid
# 17359                       Numenorean
# 21877             Harakiri For The Sky
# 22878                             MÃ¸l
# 22919                       Deafheaven
# 23978                     Bliss Signal
# 28321  An Autumn for Crippled Children
#
#                                         Title Release Month Release Day  \
# 3454                        Ã‰cailles de Lune         March          29
# 5013                                Sunbather          June          11
# 12407                        The Long Goodbye      February          17
# 17247                                     Air          June          10
# 17359                                    Home          July          22
# 21877                                   Arson      February          16
# ...
