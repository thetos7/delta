# %%
import pandas as pd
import io
import zipfile
import urllib.request
import seaborn as sns
import numpy as np
import folium
from geopy.geocoders import Nominatim

# %% [markdown]
# # Download data

# %%
data_2021 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/Donnees_consolidees_2021.zip"
data_2020 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2020.zip"
data_2019 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2019.zip"
data_2018 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2018.zip"
data_2017 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2017.zip"
data_2016 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2016.zip"
data_2015 = "https://www.pole-emploi.org/files/live/sites/peorg/files/documents/Statistiques-et-analyses/Open-data/BMO/donnees_consolidees_2015.zip"

data_2021 = urllib.request.urlopen(data_2021)
zipfile = zipfile.ZipFile(io.BytesIO(data_2021.read()))
extracted_file = zipfile.open(zipfile.namelist()[0])

# %%
data = pd.read_excel(extracted_file, sheet_name=1)
data = data[data.met != "*"].dropna()
data.met = data.met.astype(int)

# %%
data.drop(columns=["Code métier BMO", "Famille_met", "BE21", "Dept", "REG", "xmet", "smet"])
# Out:
#        annee         Nom métier BMO                            Lbl_fam_met  \
# 0       2021  Agriculteurs salariés                         Autres métiers
# 1       2021  Agriculteurs salariés                         Autres métiers
# 2       2021  Agriculteurs salariés                         Autres métiers
# 3       2021  Agriculteurs salariés                         Autres métiers
# 4       2021  Agriculteurs salariés                         Autres métiers
# ...      ...                    ...                                    ...
# 46587   2021             Formateurs  Fonctions sociales et médico-sociales
# 46588   2021             Formateurs  Fonctions sociales et médico-sociales
# 46589   2021             Formateurs  Fonctions sociales et médico-sociales
# 46590   2021             Formateurs  Fonctions sociales et médico-sociales
# 46591   2021             Formateurs  Fonctions sociales et médico-sociales
#
#                           NOMBE21           NomDept  \
# 0              BASSIN BASSE-TERRE        Guadeloupe
# 1             BASSIN GRANDE-TERRE        Guadeloupe
# 2                   BASSIN CENTRE        Guadeloupe
# 3               MARTINIQUE CENTRE        Martinique
# 4      MARTINIQUE NORD ATLANTIQUE        Martinique
# ...                           ...               ...
# 46587                     LA CASA   Alpes-Maritimes
# 46588                PAYS D ARLES  Bouches-du-Rhône
# 46589                     EST VAR               Var
# 46590                    HAUT VAR               Var
# 46591         AIX  GARDANNE SALON  Bouches-du-Rhône
#
#                           NOM_REG  met
# 0                      Guadeloupe  252
# 1                      Guadeloupe  198
# 2                      Guadeloupe   95
# 3                      Martinique  143
# 4                      Martinique  109
# ...                           ...  ...
# 46587  Provence-Alpes-Côte d'Azur   29
# 46588  Provence-Alpes-Côte d'Azur   85
# 46589  Provence-Alpes-Côte d'Azur  103
# 46590  Provence-Alpes-Côte d'Azur   37
# 46591  Provence-Alpes-Côte d'Azur  189
#
# [37071 rows x 7 columns]

# %%
data = data.groupby(["NomDept"]).agg({'met': np.sum})

# %%
france = folium.Map(location=[46.8,2], zoom_start=6)

# %%
data
# Out:
#                            met
# NomDept
# Ain                      15529
# Aisne                    18567
# Allier                    9011
# Alpes-Maritimes          50364
# Alpes-de-Haute-Provence   9287
# ...                        ...
# Vendée                   40805
# Vienne                   16951
# Vosges                    9549
# Yonne                     9879
# Yvelines                 42340
#
# [99 rows x 1 columns]

# %%
geolocator = Nominatim(user_agent="example")
locs = []

for dept in data.index.values:
    try:
        loc = geolocator.geocode(dept).raw
    except:
        print(f"Not working for {dept}")
        loc.append((None, None))
        continue
    print(f"Loc for {dept}: ({loc['lat'], loc['lon']})")
    locs.append((loc['lat'], loc['lon']))
# Out:
# Loc for Ain: (('49.453285449999996', '3.606899003594057'))
# Loc for Aisne: (('49.453285449999996', '3.606899003594057'))
# Loc for Allier: (('46.36746405', '3.163882848311948'))
# Loc for Alpes-Maritimes: (('43.9210587', '7.1790785'))
# Loc for Alpes-de-Haute-Provence: (('44.1640832', '6.187851538609079'))
# Loc for Ardennes: (('49.69801175', '4.671600518245179'))
# Loc for Ardèche: (('44.815194000000005', '4.3986524702343965'))
# Loc for Ariège: (('42.9455368', '1.4065544156065486'))
# Loc for Aube: (('48.3201921', '4.1905396615047525'))
# Loc for Aude: (('43.0542733', '2.512471457499548'))
# Loc for Aveyron: (('44.315857449999996', '2.5065697302419823'))
# Loc for Bas-Rhin: (('48.5991783', '7.533672856882669'))
# Loc for Bouches-du-Rhône: (('43.5424182', '5.034323560504859'))
# Loc for Calvados: (('49.09076485', '-0.24139505722798021'))
# Loc for Cantal: (('45.0497701', '2.699717567737356'))
# Loc for Charente: (('45.6667902', '0.09730504409848517'))
# Loc for Charente-Maritime: (('45.73022675', '-0.7212875872563794'))
# Loc for Cher: (('47.024882399999996', '2.5753333606655704'))
# Loc for Corrèze: (('45.342904700000005', '1.8176424406120555'))
# Loc for Creuse: (('46.0593485', '2.04890101251091'))
# Loc for Côte-d'Or: (('47.465503350000006', '4.74812234575117'))
# Loc for Côtes-d'Armor: (('48.461487700000006', '-2.751432791068642'))
# Loc for Deux-Sèvres: (('46.53914', '-0.29947849341978416'))
# Loc for Dordogne: (('45.14291985', '0.6321258058651044'))
# Loc for Doubs: (('47.06699155', '6.235622772820445'))
# Loc for Drôme: (('44.72953475', '5.204637164536667'))
# Loc for Essonne: (('48.53034015', '2.239291805668168'))
# Loc for Eure: (('49.0756358', '0.9652025944774796'))
# Loc for Eure-et-Loir: (('48.4474102', '1.3998820185020766'))
# Loc for Finistère: (('48.24511525', '-4.044090245241742'))
# Loc for Gard: (('43.95995', '4.297637002377168'))
# Loc for Gers: (('43.695527600000005', '0.4101019175237992'))
# Loc for Gironde: (('44.883745950000005', '-0.6051264440438711'))
# Loc for Guadeloupe: (('16.2490067', '-61.5650444'))
# Loc for Guyane: (('4.0039882', '-52.999998'))
# Loc for Haut-Rhin: (('47.8654746', '7.231543347579764'))
# Loc for Haute-Garonne: (('43.305454600000004', '0.9716791701901577'))
# Loc for Haute-Loire: (('45.085724850000005', '3.833826117673291'))
# Loc for Haute-Marne: (('48.1329414', '5.252910789751933'))
# Loc for Haute-Savoie: (('46.068820849999994', '6.344536991587102'))
# Loc for Haute-Saône: (('47.63842335', '6.095114088932768'))
# Loc for Haute-Vienne: (('45.91901925', '1.203176771876291'))
# Loc for Hautes-Alpes: (('44.6564666', '6.352024584507948'))
# Loc for Hautes-Pyrénées: (('43.1437925', '0.15866611287926924'))
# Loc for Hauts-de-Seine: (('48.840185899999994', '2.1986299985796083'))
# Loc for Hérault: (('43.591422', '3.3553309364095925'))
# Loc for Ille-et-Vilaine: (('48.17276805', '-1.6498092420681134'))
# Loc for Indre: (('46.81210565', '1.5382051557056249'))
# Loc for Indre-et-Loire: (('47.2232046', '0.6866702523286876'))
# Loc for Isère: (('45.28979315', '5.634382477386232'))
# Loc for Jura: (('46.783362499999996', '5.783285726354901'))
# Loc for La Réunion: (('-21.130737949999997', '55.536480112992315'))
# Loc for Landes: (('44.00996945', '-0.6433872354467377'))
# Loc for Loir-et-Cher: (('47.65977515', '1.297183525390464'))
# Loc for Loire: (('45.75385355', '4.045473682551104'))
# Loc for Loire-Atlantique: (('47.34816145', '-1.8727461214619257'))
# Loc for Loiret: (('47.91387245', '2.3075036458463853'))
# Loc for Lot: (('44.624991800000004', '1.6657742169753669'))
# Loc for Lot-et-Garonne: (('44.3691703', '0.45391575832487524'))
# Loc for Lozère: (('44.5425706', '3.521114648333333'))
# Loc for Maine-et-Loire: (('47.38863045', '-0.3909097146387368'))
# Loc for Manche: (('49.091895199999996', '-1.2454952394090721'))
# Loc for Marne: (('48.961264', '4.31224359285714'))
# Loc for Martinique: (('14.6367927', '-61.01582685063731'))
# Loc for Mayenne: (('48.1507819', '-0.6491273812007092'))
# Loc for Mayotte: (('-12.823048', '45.1520755'))
# Loc for Meurthe-et-Moselle: (('48.95596825', '5.987038299756556'))
# Loc for Meuse: (('26.2540493', '29.2675469'))
# Loc for Morbihan: (('47.825981150000004', '-2.7633492695588253'))
# Loc for Moselle: (('49.0207259', '6.538035170357949'))
# Loc for Nièvre: (('47.11969705', '3.5448897947227174'))
# Loc for Nord: (('50.52896715', '3.0883523694464854'))
# Loc for Oise: (('49.41205455', '2.406487846905477'))
# Loc for Orne: (('48.57605325', '0.04466171759588161'))
# Loc for Paris: (('48.8588897', '2.3200410217200766'))
# Loc for Pas-de-Calais: (('50.5144061', '2.258007849773996'))
# Loc for Puy-de-Dôme: (('45.7715343', '3.0839934206717934'))
# Loc for Pyrénées-Atlantiques: (('43.18718655', '-0.728247400084667'))
# Loc for Pyrénées-Orientales: (('42.625894', '2.5065089946931507'))
# Loc for Rhône: (('45.8802348', '4.564533629559522'))
# Loc for Sarthe: (('48.026928749999996', '0.2538217482247317'))
# Loc for Savoie: (('45.494895150000005', '6.384660381375652'))
# Loc for Saône-et-Loire: (('46.6557086', '4.55855481835173'))
# Loc for Seine-Maritime: (('49.66323745', '0.9401133910609153'))
# Loc for Seine-Saint-Denis: (('48.9098125', '2.4528634784461856'))
# Loc for Seine-et-Marne: (('48.61902069999999', '3.0418157506708345'))
# Loc for Somme: (('49.96894815', '2.373885538932255'))
# Loc for Tarn: (('43.7921741', '2.133964772269535'))
# Loc for Tarn-et-Garonne: (('44.080656000000005', '1.2050632958700225'))
# Loc for Territoire de Belfort: (('47.62923095', '6.899301156710882'))
# Loc for Val-d'Oise: (('49.07507045', '2.209811443668384'))
# Loc for Val-de-Marne: (('48.774489349999996', '2.4543321444588204'))
# Loc for Var: (('43.4173592', '6.2664620128919'))
# Loc for Vaucluse: (('43.993864349999996', '5.1818898389002355'))
# Loc for Vendée: (('46.67577325', '-1.29144634801388'))
# Loc for Vienne: (('48.2083537', '16.3725042'))
# Loc for Vosges: (('48.16378605', '6.382071173595532'))
# Loc for Yonne: (('47.85512575', '3.6450439257238765'))
# Loc for Yvelines: (('48.76203735', '1.8871375621264361'))

# %%
data["locs"] = locs

# %%
data
# Out:
#                            met                                     locs
# NomDept
# Ain                      15529  (49.453285449999996, 3.606899003594057)
# Aisne                    18567  (49.453285449999996, 3.606899003594057)
# Allier                    9011         (46.36746405, 3.163882848311948)
# Alpes-Maritimes          50364                  (43.9210587, 7.1790785)
# Alpes-de-Haute-Provence   9287          (44.1640832, 6.187851538609079)
# ...                        ...                                      ...
# Vendée                   40805         (46.67577325, -1.29144634801388)
# Vienne                   16951                 (48.2083537, 16.3725042)
# Vosges                    9549         (48.16378605, 6.382071173595532)
# Yonne                     9879        (47.85512575, 3.6450439257238765)
# Yvelines                 42340        (48.76203735, 1.8871375621264361)
#
# [99 rows x 2 columns]

# %%
for (lat,lon),val in zip(data.locs, data.met):
    folium.Marker((lat,lon), popup="%i" % val).add_to(france)

# %%
france
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0042e5a6665e4bc1be7097950faef13d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0042e5a6665e4bc1be7097950faef13d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0042e5a6665e4bc1be7097950faef13d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0042e5a6665e4bc1be7097950faef13d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B46.8%2C%202.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...
