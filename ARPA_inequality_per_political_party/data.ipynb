# %%
import pandas as pd

# %% [markdown]
# ## Chargement des données sur la politique mondiale

# %%
columns = ['eu', 'year', 'country', 'gov_right1', 'gov_cent1', 'gov_left1', 'gov_right3', 'gov_cent3', 'gov_left3']
df1 = pd.read_excel('./data/politique_mondiale.xlsx', usecols=columns)
df1 = df1[(df1.eu == 1) & (df1.year >= 2000)]
df1
# Out:
#         year         country   eu  gov_right1  gov_cent1  gov_left1  \
# 100   2000.0         Austria  1.0       45.36      49.64       4.29
# 101   2001.0         Austria  1.0       50.00      50.00       0.00
# 102   2002.0         Austria  1.0       50.00      50.00       0.00
# 103   2003.0         Austria  1.0       28.97      64.02       0.00
# 104   2004.0         Austria  1.0       25.00      66.67       0.00
# ...      ...             ...  ...         ...        ...        ...
# 1693  2015.0  United Kingdom  1.0      100.00       0.00       0.00
# 1694  2016.0  United Kingdom  1.0      100.00       0.00       0.00
# 1695  2017.0  United Kingdom  1.0      100.00       0.00       0.00
# 1696  2018.0  United Kingdom  1.0      100.00       0.00       0.00
# 1697  2019.0  United Kingdom  1.0      100.00       0.00       0.00
#
#       gov_right3  gov_cent3  gov_left3
# 100    25.760000      28.40        3.6
# 101    28.400000      28.40        0.0
# 102    28.400000      28.40        0.0
# 103    12.760000      40.85        0.0
# 104     9.800000      43.20        0.0
# ...          ...        ...        ...
# 1693   52.639726       0.00        0.0
# 1694   50.810000       0.00        0.0
# 1695   49.640000       0.00        0.0
# 1696   48.800000       0.00        0.0
# 1697   48.020000       0.00        0.0
#
# [493 rows x 9 columns]

# %% [markdown]
# ## Formattage des noms de pays du dataframe en français

# %%
country_name_en = df1['country'].unique().tolist()
country_name_fr = ['Autriche', 'Belgique', 'Bulgarie', 'Croatie', 'Chypre', 'République tchèque', 'Danemark', 'Estonie', 'Finlande', 'France', 'Allemagne', 'Grèce', 'Hongrie', 'Irlande', 'Italie', 'Lettonie', 'Lituanie', 'Luxembourg', 'Malte', 'Pays-Bas', 'Pologne', 'Portugal', 'Roumanie', 'Slovaquie', 'Slovénie', 'Espagne', 'Suède', 'Royaume-Uni']
df1 = df1.replace(country_name_en, country_name_fr)
df1
# Out:
#         year      country   eu  gov_right1  gov_cent1  gov_left1  gov_right3  \
# 100   2000.0     Autriche  1.0       45.36      49.64       4.29   25.760000
# 101   2001.0     Autriche  1.0       50.00      50.00       0.00   28.400000
# 102   2002.0     Autriche  1.0       50.00      50.00       0.00   28.400000
# 103   2003.0     Autriche  1.0       28.97      64.02       0.00   12.760000
# 104   2004.0     Autriche  1.0       25.00      66.67       0.00    9.800000
# ...      ...          ...  ...         ...        ...        ...         ...
# 1693  2015.0  Royaume-Uni  1.0      100.00       0.00       0.00   52.639726
# 1694  2016.0  Royaume-Uni  1.0      100.00       0.00       0.00   50.810000
# 1695  2017.0  Royaume-Uni  1.0      100.00       0.00       0.00   49.640000
# 1696  2018.0  Royaume-Uni  1.0      100.00       0.00       0.00   48.800000
# 1697  2019.0  Royaume-Uni  1.0      100.00       0.00       0.00   48.020000
#
#       gov_cent3  gov_left3
# 100       28.40        3.6
# 101       28.40        0.0
# 102       28.40        0.0
# 103       40.85        0.0
# 104       43.20        0.0
# ...         ...        ...
# 1693       0.00        0.0
# 1694       0.00        0.0
# 1695       0.00        0.0
# 1696       0.00        0.0
# 1697       0.00        0.0
#
# [493 rows x 9 columns]

# %% [markdown]
# ## Chargement des données sur les inégalités en Europe

# %%
df2 = pd.read_excel('./data/inegalite_europe.xlsx', header=None, names=['country', 'def', 'pall', 'year', 'geni'], usecols=['country', 'year', 'geni'])
df2
# Out:
#        country  year      geni
# 0    Allemagne  2000  0.436821
# 1    Allemagne  2001  0.439630
# 2    Allemagne  2002  0.443165
# 3    Allemagne  2003  0.434784
# 4    Allemagne  2004  0.446877
# ..         ...   ...       ...
# 555      Suède  2015  0.408765
# 556      Suède  2016  0.392907
# 557      Suède  2017  0.399593
# 558      Suède  2018  0.394447
# 559      Suède  2019  0.395844
#
# [560 rows x 3 columns]

# %% [markdown]
# ## Fusion des deux dataframes

# %%
df = pd.merge(df1, df2)
df
# Out:
#        year      country   eu  gov_right1  gov_cent1  gov_left1  gov_right3  \
# 0    2000.0     Autriche  1.0       45.36      49.64       4.29   25.760000
# 1    2001.0     Autriche  1.0       50.00      50.00       0.00   28.400000
# 2    2002.0     Autriche  1.0       50.00      50.00       0.00   28.400000
# 3    2003.0     Autriche  1.0       28.97      64.02       0.00   12.760000
# 4    2004.0     Autriche  1.0       25.00      66.67       0.00    9.800000
# ..      ...          ...  ...         ...        ...        ...         ...
# 488  2015.0  Royaume-Uni  1.0      100.00       0.00       0.00   52.639726
# 489  2016.0  Royaume-Uni  1.0      100.00       0.00       0.00   50.810000
# 490  2017.0  Royaume-Uni  1.0      100.00       0.00       0.00   49.640000
# 491  2018.0  Royaume-Uni  1.0      100.00       0.00       0.00   48.800000
# 492  2019.0  Royaume-Uni  1.0      100.00       0.00       0.00   48.020000
#
#      gov_cent3  gov_left3      geni
# 0        28.40        3.6  0.445938
# 1        28.40        0.0  0.432687
# 2        28.40        0.0  0.448204
# 3        40.85        0.0  0.458622
# 4        43.20        0.0  0.442338
# ..         ...        ...       ...
# 488       0.00        0.0  0.469553
# 489       0.00        0.0  0.467841
# 490       0.00        0.0  0.466156
# 491       0.00        0.0  0.467227
# 492       0.00        0.0  0.464900
#
# [493 rows x 10 columns]

# %% [markdown]
# ## Fonction pour extraire les données dans un unique dataframe

# %%
def extract_data():
    country_name_fr = [
        'Autriche', 'Belgique', 'Bulgarie', 'Croatie', 'Chypre', 'République tchèque', 'Danemark', 'Estonie',
        'Finlande', 'France', 'Allemagne', 'Grèce', 'Hongrie', 'Irlande', 'Italie', 'Lettonie', 'Lituanie',
        'Luxembourg', 'Malte', 'Pays-Bas', 'Pologne', 'Portugal', 'Roumanie', 'Slovaquie', 'Slovénie', 'Espagne',
        'Suède', 'Royaume-Uni'
    ]
    columns = ['eu', 'year', 'country', 'gov_right1', 'gov_cent1', 'gov_left1', 'gov_right3', 'gov_cent3', 'gov_left3']
    
    df1 = pd.read_excel('./data/politique_mondiale.xlsx', usecols=columns).query('(eu == 1) & (year >= 2000)')
    df1 = df1.replace(df1['country'].unique().tolist(), country_name_fr)
    
    df2 = pd.read_excel('./data/inegalite_europe.xlsx', header=None, names=['country', 'def', 'pall', 'year', 'geni'], usecols=['country', 'year', 'geni'])
    
    return pd.merge(df1, df2)
