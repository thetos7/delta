# %%
import pandas as pd
import numpy as np
import logging
from urllib import request
logging.basicConfig(level=logging.INFO)
import os
import json

# %%
TGVCSVURL = "https://ressources.data.sncf.com/explore/dataset/regularite-mensuelle-tgv-aqst/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B"

# %%
TGVCSVFILE = "regularite-mensuelle-tgv-aqst.csv"

# %%
STATIONSJSONURL = "https://ressources.data.sncf.com/explore/dataset/liste-des-gares/download/?format=json&timezone=Europe/Paris&lang=fr"
STATIONSJSONFILE = "liste-des-gares.json"
STATIONSIDXJSONFILE = "stations.json"

# %%
def get_data():
    request.urlretrieve(TGVCSVURL, TGVCSVFILE)
    request.urlretrieve(STATIONSJSONURL, STATIONSJSONFILE)
    with open(STATIONSJSONFILE) as f:
        stations = json.load(f)
    statidx = {}
    for s in stations:
        statidx[s["fields"]["libelle"].lower().replace('-', ' ')] = s
    with open(STATIONSIDXJSONFILE, "w") as f:
        json.dump(statidx, f)
get_data()

# %%
# board = pd.read_csv(TGVCSVFILE, compression='gzip', header=None, names=COLUMNS, usecols=COLUMNSONLY, dtype=COLUMNSTYPES)
df = pd.read_csv(TGVCSVFILE, sep=";")

# %%
df
# Out:
#          Date   Service              Gare de départ      Gare d'arrivée  \
# 0     2018-01  National           ANGERS SAINT LAUD  PARIS MONTPARNASSE
# 1     2018-01  National           LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 2     2018-01  National          PARIS MONTPARNASSE    BORDEAUX ST JEAN
# 3     2018-01  National          PARIS MONTPARNASSE               LAVAL
# 4     2018-01  National          PARIS MONTPARNASSE              NANTES
# ...       ...       ...                         ...                 ...
# 6319  2022-03  National                  PARIS NORD               DOUAI
# 6320  2022-03  National                    POITIERS  PARIS MONTPARNASSE
# 6321  2022-03  National                      RENNES      LYON PART DIEU
# 6322  2022-03  National  SAINT ETIENNE CHATEAUCREUX          PARIS LYON
# 6323  2022-03  National                  STRASBOURG              NANTES
#
#       Durée moyenne du trajet  Nombre de circulations prévues  \
# 0                          91                             393
# 1                         165                             222
# 2                         143                             775
# 3                          84                             217
# 4                         124                             508
# ...                       ...                             ...
# 6319                       70                             140
# 6320                       99                             476
# 6321                      234                              75
# 6322                      168                             115
# 6323                      315                              58
#
#       Nombre de trains annulés  Commentaire annulations  \
# 0                            2                      NaN
# 1                            0                      NaN
# 2                            7                      NaN
# 3                            0                      NaN
# 4                            3                      NaN
# ...                        ...                      ...
# 6319                         0                      NaN
# 6320                         8                      NaN
# 6321                         0                      NaN
# 6322                         0                      NaN
# 6323                         1                      NaN
#
#       Nombre de trains en retard au départ  \
# 0                                      204
# 1                                        8
# 2                                      148
# 3                                       32
# 4                                       71
# ...                                    ...
# 6319                                    10
# 6320                                   162
# 6321                                    20
# 6322                                    23
# 6323                                     7
#
#       Retard moyen des trains en retard au départ  ...  \
# 0                                        6.400490  ...
# 1                                        2.875000  ...
# 2                                        9.377815  ...
# 3                                       11.609375  ...
# 4                                        7.235211  ...
# ...                                           ...  ...
# 6319                                    23.931667  ...
# 6320                                     6.578498  ...
# 6321                                     7.215000  ...
# 6322                                     2.039130  ...
# 6323                                     1.792857  ...
#
#       Nombre trains en retard > 15min  \
# 0                                  35
# 1                                  22
# 2                                  45
# 3                                  16
# 4                                  39
# ...                               ...
# 6319                                8
# 6320                               38
# 6321                                5
# 6322                                5
# 6323                                2
#
#       Retard moyen trains en retard > 15 (si liaison concurrencée par vol)  \
# 0                                              6.072847
# 1                                              5.696096
# 2                                              2.546962
# 3                                              5.822811
# 4                                              5.292211
# ...                                                 ...
# 6319                                          45.275000
# 6320                                          31.825000
# 6321                                          50.123333
# 6322                                          33.846667
# 6323                                          35.875000
#
#       Nombre trains en retard > 30min  Nombre trains en retard > 60min  \
# 0                                  19                                4
# 1                                   5                                0
# 2                                  21                                4
# 3                                   5                                2
# 4                                  18                                8
# ...                               ...                              ...
# 6319                                5                                2
# 6320                               15                                3
# 6321                                3                                2
# 6322                                2                                1
# 6323                                1                                0
#
#       Prct retard pour causes externes Prct retard pour cause infrastructure  \
# 0                            37.500000                             37.500000
# 1                            15.384615                             30.769231
# 2                            21.666667                             25.000000
# 3                            24.242424                             54.545455
# 4                            33.333333                             22.222222
# ...                                ...                                   ...
# 6319                         25.000000                             16.666667
# 6320                         17.187500                             37.500000
# 6321                         20.000000                              0.000000
# 6322                         12.500000                             12.500000
# 6323                         50.000000                              0.000000
#
#       Prct retard pour cause gestion trafic  \
# 0                                  8.928571
# 1                                 38.461538
# 2                                 11.666667
# 3                                  3.030303
# 4                                 16.666667
# ...                                     ...
# 6319                              16.666667
# 6320                              12.500000
# 6321                              40.000000
# 6322                              12.500000
# 6323                               0.000000
#
#       Prct retard pour cause matériel roulant  \
# 0                                    5.357143
# 1                                   11.538462
# 2                                   40.000000
# 3                                   12.121212
# 4                                   20.370370
# ...                                       ...
# 6319                                 8.333333
# 6320                                14.062500
# 6321                                 0.000000
# 6322                                50.000000
# 6323                                50.000000
#
#       Prct retard pour cause gestion en gare et réutilisation de matériel  \
# 0                                              8.928571
# 1                                              3.846154
# 2                                              1.666667
# 3                                              3.030303
# 4                                              5.555556
# ...                                                 ...
# 6319                                           8.333333
# 6320                                           7.812500
# 6321                                           0.000000
# 6322                                           0.000000
# 6323                                           0.000000
#
#       Prct retard pour cause prise en compte voyageurs (affluence, gestions PSH, correspondances)
# 0                                              1.785714
# 1                                              0.000000
# 2                                              0.000000
# 3                                              3.030303
# 4                                              1.851852
# ...                                                 ...
# 6319                                          25.000000
# 6320                                          10.937500
# 6321                                          40.000000
# 6322                                          12.500000
# 6323                                           0.000000
#
# [6324 rows x 26 columns]

# %%
df.set_index('Date')
# Out:
#           Service              Gare de départ      Gare d'arrivée  \
# Date
# 2018-01  National           ANGERS SAINT LAUD  PARIS MONTPARNASSE
# 2018-01  National           LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 2018-01  National          PARIS MONTPARNASSE    BORDEAUX ST JEAN
# 2018-01  National          PARIS MONTPARNASSE               LAVAL
# 2018-01  National          PARIS MONTPARNASSE              NANTES
# ...           ...                         ...                 ...
# 2022-03  National                  PARIS NORD               DOUAI
# 2022-03  National                    POITIERS  PARIS MONTPARNASSE
# 2022-03  National                      RENNES      LYON PART DIEU
# 2022-03  National  SAINT ETIENNE CHATEAUCREUX          PARIS LYON
# 2022-03  National                  STRASBOURG              NANTES
#
#          Durée moyenne du trajet  Nombre de circulations prévues  \
# Date
# 2018-01                       91                             393
# 2018-01                      165                             222
# 2018-01                      143                             775
# 2018-01                       84                             217
# 2018-01                      124                             508
# ...                          ...                             ...
# 2022-03                       70                             140
# 2022-03                       99                             476
# 2022-03                      234                              75
# 2022-03                      168                             115
# 2022-03                      315                              58
#
#          Nombre de trains annulés  Commentaire annulations  \
# Date
# 2018-01                         2                      NaN
# 2018-01                         0                      NaN
# 2018-01                         7                      NaN
# 2018-01                         0                      NaN
# 2018-01                         3                      NaN
# ...                           ...                      ...
# 2022-03                         0                      NaN
# 2022-03                         8                      NaN
# 2022-03                         0                      NaN
# 2022-03                         0                      NaN
# 2022-03                         1                      NaN
#
#          Nombre de trains en retard au départ  \
# Date
# 2018-01                                   204
# 2018-01                                     8
# 2018-01                                   148
# 2018-01                                    32
# 2018-01                                    71
# ...                                       ...
# 2022-03                                    10
# 2022-03                                   162
# 2022-03                                    20
# 2022-03                                    23
# 2022-03                                     7
#
#          Retard moyen des trains en retard au départ  \
# Date
# 2018-01                                     6.400490
# 2018-01                                     2.875000
# 2018-01                                     9.377815
# 2018-01                                    11.609375
# 2018-01                                     7.235211
# ...                                              ...
# 2022-03                                    23.931667
# 2022-03                                     6.578498
# 2022-03                                     7.215000
# 2022-03                                     2.039130
# 2022-03                                     1.792857
#
#          Retard moyen de tous les trains au départ  ...  \
# Date                                                ...
# 2018-01                                   3.455754  ...
# 2018-01                                   0.095796  ...
# 2018-01                                   1.582530  ...
# 2018-01                                   1.455760  ...
# 2018-01                                   0.734290  ...
# ...                                            ...  ...
# 2022-03                                   1.438690  ...
# 2022-03                                   2.081156  ...
# 2022-03                                   1.938444  ...
# 2022-03                                   0.845072  ...
# 2022-03                                   0.156140  ...
#
#          Nombre trains en retard > 15min  \
# Date
# 2018-01                               35
# 2018-01                               22
# 2018-01                               45
# 2018-01                               16
# 2018-01                               39
# ...                                  ...
# 2022-03                                8
# 2022-03                               38
# 2022-03                                5
# 2022-03                                5
# 2022-03                                2
#
#          Retard moyen trains en retard > 15 (si liaison concurrencée par vol)  \
# Date
# 2018-01                                           6.072847
# 2018-01                                           5.696096
# 2018-01                                           2.546962
# 2018-01                                           5.822811
# 2018-01                                           5.292211
# ...                                                    ...
# 2022-03                                          45.275000
# 2022-03                                          31.825000
# 2022-03                                          50.123333
# 2022-03                                          33.846667
# 2022-03                                          35.875000
#
#          Nombre trains en retard > 30min  Nombre trains en retard > 60min  \
# Date
# 2018-01                               19                                4
# 2018-01                                5                                0
# 2018-01                               21                                4
# 2018-01                                5                                2
# 2018-01                               18                                8
# ...                                  ...                              ...
# 2022-03                                5                                2
# 2022-03                               15                                3
# 2022-03                                3                                2
# 2022-03                                2                                1
# 2022-03                                1                                0
#
#         Prct retard pour causes externes  \
# Date
# 2018-01                        37.500000
# 2018-01                        15.384615
# 2018-01                        21.666667
# 2018-01                        24.242424
# 2018-01                        33.333333
# ...                                  ...
# 2022-03                        25.000000
# 2022-03                        17.187500
# 2022-03                        20.000000
# 2022-03                        12.500000
# 2022-03                        50.000000
#
#          Prct retard pour cause infrastructure  \
# Date
# 2018-01                              37.500000
# 2018-01                              30.769231
# 2018-01                              25.000000
# 2018-01                              54.545455
# 2018-01                              22.222222
# ...                                        ...
# 2022-03                              16.666667
# 2022-03                              37.500000
# 2022-03                               0.000000
# 2022-03                              12.500000
# 2022-03                               0.000000
#
#          Prct retard pour cause gestion trafic  \
# Date
# 2018-01                               8.928571
# 2018-01                              38.461538
# 2018-01                              11.666667
# 2018-01                               3.030303
# 2018-01                              16.666667
# ...                                        ...
# 2022-03                              16.666667
# 2022-03                              12.500000
# 2022-03                              40.000000
# 2022-03                              12.500000
# 2022-03                               0.000000
#
#          Prct retard pour cause matériel roulant  \
# Date
# 2018-01                                 5.357143
# 2018-01                                11.538462
# 2018-01                                40.000000
# 2018-01                                12.121212
# 2018-01                                20.370370
# ...                                          ...
# 2022-03                                 8.333333
# 2022-03                                14.062500
# 2022-03                                 0.000000
# 2022-03                                50.000000
# 2022-03                                50.000000
#
#          Prct retard pour cause gestion en gare et réutilisation de matériel  \
# Date
# 2018-01                                           8.928571
# 2018-01                                           3.846154
# 2018-01                                           1.666667
# 2018-01                                           3.030303
# 2018-01                                           5.555556
# ...                                                    ...
# 2022-03                                           8.333333
# 2022-03                                           7.812500
# 2022-03                                           0.000000
# 2022-03                                           0.000000
# 2022-03                                           0.000000
#
#          Prct retard pour cause prise en compte voyageurs (affluence, gestions PSH, correspondances)
# Date
# 2018-01                                           1.785714
# 2018-01                                           0.000000
# 2018-01                                           0.000000
# 2018-01                                           3.030303
# 2018-01                                           1.851852
# ...                                                    ...
# 2022-03                                          25.000000
# 2022-03                                          10.937500
# 2022-03                                          40.000000
# 2022-03                                          12.500000
# 2022-03                                           0.000000
#
# [6324 rows x 25 columns]

# %%
df = df[df['Service'] == 'National']

# %%
def _():
    with open(STATIONSIDXJSONFILE) as f:
        return json.load(f)
stations = _()

# %%
stations
# Out:
# {'roubaix wattrelos': {'datasetid': 'liste-des-gares',
#   'recordid': '9f0d8622f5cd9c833939bc71dd3a3f397a0b6a4d',
#   'fields': {'idreseau': 6311,
#    'y_l93': 7065961.276900001,
#    'commune': 'ROUBAIX',
#    'voyageurs': 'N',
#    'code_uic': '87286757',
#    'geo_shape': {'coordinates': [3.20417901400531, 50.69028973836216],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Roubaix-Wattrelos',
#    'pk': '016+926',
#    'idgaia': 'e54a641c-6667-11e3-a7ff-01f464e0362d',
#    'departemen': 'NORD',
#    'rg_troncon': 1,
#    'x_l93': 714453.6001000032,
#    'x_wgs84': 3.20417901400531,
#    'code_ligne': '271000',
#    'c_geo': [50.69028973929999, 3.20417901400531],
#    'geo_point_2d': [50.69028973836216, 3.2041790140053097],
#    'y_wgs84': 50.69028973929999},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.20417901400531, 50.69028973929999]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'hellemmes': {'datasetid': 'liste-des-gares',
#   'recordid': 'e9cfb8b6d9bfd047e40c6c84d0bbe2b6c082327a',
#   'fields': {'idreseau': 4429,
#    'y_l93': 7058436.268199999,
#    'commune': 'LILLE',
#    'voyageurs': 'O',
#    'code_uic': '87286062',
#    'geo_shape': {'coordinates': [3.116260107935155, 50.62287383540383],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Hellemmes',
#    'pk': '004+096',
#    'idgaia': 'd9b659f8-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'NORD',
#    'rg_troncon': 1,
#    'x_l93': 708240.9878000021,
#    'x_wgs84': 3.116260107935155,
#    'code_ligne': '269000',
#    'c_geo': [50.62287383634239, 3.116260107935155],
#    'geo_point_2d': [50.62287383540383, 3.1162601079351546],
#    'y_wgs84': 50.62287383634239},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.116260107935155, 50.62287383634239]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rivarennes': {'datasetid': 'liste-des-gares',
#   'recordid': '4961535511bdfcadd4147d7bf94e69315f49b7b1',
#   'fields': {'idreseau': 9040,
#    'y_l93': 6688548.883200001,
#    'commune': 'RIVARENNES',
#    'voyageurs': 'O',
#    'code_uic': '87571653',
#    'geo_shape': {'coordinates': [0.360658187062774, 47.26723632444582],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Rivarennes',
#    'pk': '217+468',
#    'idgaia': 'd9c0b346-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'INDRE-ET-LOIRE',
#    'rg_troncon': 1,
#    'x_l93': 500474.98920000345,
#    'x_wgs84': 0.360658187062776,
#    'code_ligne': '525000',
#    'c_geo': [47.267236325416576, 0.36065818706277614],
#    'geo_point_2d': [47.26723632444582, 0.36065818706277447],
#    'y_wgs84': 47.267236325416576},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.36065818706277614, 47.267236325416576]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rothau': {'datasetid': 'liste-des-gares',
#   'recordid': 'feaaa78390bd9b01501d8f8ad02f744303ab5c1c',
#   'fields': {'idreseau': 6309,
#    'y_l93': 6825947.0227999985,
#    'commune': 'ROTHAU',
#    'voyageurs': 'O',
#    'code_uic': '87214726',
#    'geo_shape': {'coordinates': [7.207432343690651, 48.45922303076995],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Rothau',
#    'pk': '044+926',
#    'idgaia': 'd999b8dc-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'BAS-RHIN',
#    'rg_troncon': 1,
#    'x_l93': 1010921.9029999971,
#    'x_wgs84': 7.207432343690648,
#    'code_ligne': '110000',
#    'c_geo': [48.45922303173024, 7.207432343690648],
#    'geo_point_2d': [48.45922303076995, 7.207432343690651],
#    'y_wgs84': 48.45922303173024},
#   'geometry': {'type': 'Point',
#    'coordinates': [7.207432343690648, 48.45922303173024]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'is sur tille': {'datasetid': 'liste-des-gares',
#   'recordid': 'cb21c820e5c7022bf7fa52d944390be9d46e4d06',
#   'fields': {'idreseau': 4496,
#    'y_l93': 6715479.904199999,
#    'commune': 'MARCILLY-SUR-TILLE',
#    'voyageurs': 'O',
#    'code_uic': '87713859',
#    'geo_shape': {'coordinates': [5.129777870847223, 47.52023448655534],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Is-sur-Tille',
#    'pk': '305+566',
#    'idgaia': 'd9c98fb2-6667-11e3-89ff-01f464e0362d',
#    'departemen': "COTE-D'OR",
#    'rg_troncon': 1,
#    'x_l93': 860256.2731999978,
#    'x_wgs84': 5.129777870847223,
#    'code_ligne': '838000',
#    'c_geo': [47.52023448752397, 5.129777870847223],
#    'geo_point_2d': [47.52023448655534, 5.1297778708472235],
#    'y_wgs84': 47.52023448752397},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.129777870847223, 47.52023448752397]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'dordives': {'datasetid': 'liste-des-gares',
#   'recordid': '773a9d7fa042502e18f3bbbbded416cb54631d43',
#   'fields': {'idreseau': 3990,
#    'y_l93': 6783021.141199999,
#    'commune': 'DORDIVES',
#    'voyageurs': 'O',
#    'code_uic': '87684233',
#    'geo_shape': {'coordinates': [2.762535922688356, 48.14731643041944],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Dordives',
#    'pk': '101+349',
#    'idgaia': 'd976c850-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'LOIRET',
#    'rg_troncon': 1,
#    'x_l93': 682339.2855999991,
#    'x_wgs84': 2.762535922688357,
#    'code_ligne': '750000',
#    'c_geo': [48.1473164313826, 2.7625359226883566],
#    'geo_point_2d': [48.14731643041944, 2.762535922688356],
#    'y_wgs84': 48.1473164313826},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.7625359226883566, 48.1473164313826]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'jardres': {'datasetid': 'liste-des-gares',
#   'recordid': '5ad33d7e69567af77e4cd52bd1444c9f81f16e5e',
#   'fields': {'idreseau': 8178,
#    'y_l93': 6609942.2872,
#    'commune': 'JARDRES',
#    'voyageurs': 'N',
#    'code_uic': '87575720',
#    'geo_shape': {'coordinates': [0.560320283222386, 46.56353108415663],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Jardres',
#    'pk': '360+780',
#    'idgaia': '295ee18e-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'VIENNE',
#    'rg_troncon': 1,
#    'x_l93': 513149.29119999707,
#    'x_wgs84': 0.560320283222388,
#    'code_ligne': '601000',
#    'c_geo': [46.56353108511348, 0.5603202832223879],
#    'geo_point_2d': [46.56353108415663, 0.5603202832223863],
#    'y_wgs84': 46.56353108511348},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.5603202832223879, 46.56353108511348]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'donchery': {'datasetid': 'liste-des-gares',
#   'recordid': '4ab2c1afe87702e83f9e2c4e157f36939703998e',
#   'fields': {'idreseau': 3985,
#    'y_l93': 6957080.5945999995,
#    'commune': 'DONCHERY',
#    'voyageurs': 'O',
#    'code_uic': '87172239',
#    'geo_shape': {'coordinates': [4.874829747177438, 49.69831634841525],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Donchery',
#    'pk': '154+063',
#    'idgaia': 'd97a7a40-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'ARDENNES',
#    'rg_troncon': 2,
#    'x_l93': 835327.3869000003,
#    'x_wgs84': 4.874829747177437,
#    'code_ligne': '204000',
#    'c_geo': [49.6983163493635, 4.874829747177437],
#    'geo_point_2d': [49.69831634841525, 4.874829747177438],
#    'y_wgs84': 49.6983163493635},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.874829747177437, 49.6983163493635]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'st germain st rémy': {'datasetid': 'liste-des-gares',
#   'recordid': 'e91f18b07ba078c813a04831b0a305538de0b319',
#   'fields': {'idreseau': 6482,
#    'y_l93': 6852393.879099999,
#    'commune': 'SAINT-GERMAIN-SUR-AVRE',
#    'voyageurs': 'O',
#    'code_uic': '87393520',
#    'geo_shape': {'coordinates': [1.256292124313498, 48.758914575751646],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'St-Germain-St-Rémy',
#    'pk': '090+990',
#    'idgaia': 'e126da1a-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'EURE-ET-LOIR',
#    'rg_troncon': 1,
#    'x_l93': 571828.1895999983,
#    'x_wgs84': 1.256292124313499,
#    'code_ligne': '395000',
#    'c_geo': [48.758914576709124, 1.256292124313499],
#    'geo_point_2d': [48.758914575751646, 1.2562921243134977],
#    'y_wgs84': 48.758914576709124},
#   'geometry': {'type': 'Point',
#    'coordinates': [1.256292124313499, 48.758914576709124]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'le douhet écoyeux': {'datasetid': 'liste-des-gares',
#   'recordid': '2a0da07df00d0e85ec051077d3a697e40d2f0f15',
#   'fields': {'idreseau': 4931,
#    'y_l93': 6529999.300099999,
#    'commune': 'LE DOUHET',
#    'voyageurs': 'N',
#    'code_uic': '87491316',
#    'geo_shape': {'coordinates': [-0.559544832069209, 45.81356394270588],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Le Douhet-Écoyeux',
#    'pk': '478+534',
#    'idgaia': 'd9bc048a-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'CHARENTE-MARITIME',
#    'rg_troncon': 1,
#    'x_l93': 423676.6328999996,
#    'x_wgs84': -0.559544832069206,
#    'code_ligne': '500000',
#    'c_geo': [45.813563943665976, -0.559544832069206],
#    'geo_point_2d': [45.81356394270588, -0.5595448320692088],
#    'y_wgs84': 45.813563943665976},
#   'geometry': {'type': 'Point',
#    'coordinates': [-0.559544832069206, 45.813563943665976]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'la brigue': {'datasetid': 'liste-des-gares',
#   'recordid': '5b54a3e66c73ade4ac636dcea7605cddcfaf4d26',
#   'fields': {'idreseau': 4605,
#    'y_l93': 6340026.160700001,
#    'commune': 'LA BRIGUE',
#    'voyageurs': 'O',
#    'code_uic': '87756874',
#    'geo_shape': {'coordinates': [7.603034286339615, 44.06252385074694],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'La Brigue',
#    'pk': '054+484',
#    'idgaia': '29754304-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'ALPES-MARITIMES',
#    'rg_troncon': 1,
#    'x_l93': 1068578.0540999994,
#    'x_wgs84': 7.603034286339613,
#    'code_ligne': '946000',
#    'c_geo': [44.06252385171183, 7.603034286339613],
#    'geo_point_2d': [44.06252385074694, 7.603034286339615],
#    'y_wgs84': 44.06252385171183},
#   'geometry': {'type': 'Point',
#    'coordinates': [7.603034286339613, 44.06252385171183]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'belleville': {'datasetid': 'liste-des-gares',
#   'recordid': '43f19f91640db0c55b6f4a9f701399b0bc45d390',
#   'fields': {'idreseau': 8493,
#    'y_l93': 6862179.144699998,
#    'commune': 'BELLEVILLE',
#    'voyageurs': 'O',
#    'code_uic': '87141804',
#    'geo_shape': {'coordinates': [6.101709203382133, 48.819425056062265],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Belleville',
#    'pk': '351+572',
#    'idgaia': '2991592c-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'MEURTHE-ET-MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 927687.8202999979,
#    'x_wgs84': 6.101709203382132,
#    'code_ligne': '090000',
#    'c_geo': [48.81942505701919, 6.101709203382132],
#    'geo_point_2d': [48.819425056062265, 6.101709203382133],
#    'y_wgs84': 48.81942505701919},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.101709203382132, 48.81942505701919]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'commentry': {'datasetid': 'liste-des-gares',
#   'recordid': '9c543aae44639bff39dc4d365bfd60ff9a450233',
#   'fields': {'idreseau': 3784,
#    'y_l93': 6577296.6688,
#    'commune': 'COMMENTRY',
#    'voyageurs': 'O',
#    'code_uic': '87641415',
#    'geo_shape': {'coordinates': [2.740155183201144, 46.295268415050934],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Commentry',
#    'pk': '340+847',
#    'idgaia': 'e135c8ae-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'ALLIER',
#    'rg_troncon': 1,
#    'x_l93': 679997.7824999988,
#    'x_wgs84': 2.740155183201145,
#    'code_ligne': '705000',
#    'c_geo': [46.29526841600905, 2.740155183201145],
#    'geo_point_2d': [46.295268415050934, 2.740155183201144],
#    'y_wgs84': 46.29526841600905},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.740155183201145, 46.29526841600905]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'hesdin': {'datasetid': 'liste-des-gares',
#   'recordid': 'b3c7cc8b0779d0e1b7e0d317a51965d19e6ec942',
#   'fields': {'idreseau': 4448,
#    'y_l93': 7031602.5506,
#    'commune': 'HESDIN',
#    'voyageurs': 'O',
#    'code_uic': '87317222',
#    'geo_shape': {'coordinates': [2.03529744900273, 50.37830124077323],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Hesdin',
#    'pk': '101+161',
#    'idgaia': 'd9e163f4-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'PAS-DE-CALAIS',
#    'rg_troncon': 1,
#    'x_l93': 631286.7690000013,
#    'x_wgs84': 2.035297449002732,
#    'code_ligne': '308000',
#    'c_geo': [50.37830124171442, 2.035297449002732],
#    'geo_point_2d': [50.37830124077323, 2.0352974490027305],
#    'y_wgs84': 50.37830124171442},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.035297449002732, 50.37830124171442]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'port ste marie': {'datasetid': 'liste-des-gares',
#   'recordid': 'c25942fccb492b13efa7cec5eed7a100a7a683e4',
#   'fields': {'idreseau': 6124,
#    'y_l93': 6353608.924400002,
#    'commune': 'PORT-SAINTE-MARIE',
#    'voyageurs': 'O',
#    'code_uic': '87586107',
#    'geo_shape': {'coordinates': [0.388545716635137, 44.250464513464756],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Port-Ste-Marie',
#    'pk': '115+609',
#    'idgaia': 'e1b12594-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'LOT-ET-GARONNE',
#    'rg_troncon': 1,
#    'x_l93': 491503.52839999646,
#    'x_wgs84': 0.388545716635139,
#    'code_ligne': '643000',
#    'c_geo': [44.250464514429325, 0.3885457166351385],
#    'geo_point_2d': [44.250464513464756, 0.38854571663513676],
#    'y_wgs84': 44.250464514429325},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.3885457166351385, 44.250464514429325]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'marne la vallée chessy': {'datasetid': 'liste-des-gares',
#   'recordid': 'c98e4aa499da125b71a2a56ba58aba36098d3f19',
#   'fields': {'idreseau': 72767,
#    'y_l93': 6863342.1371,
#    'commune': 'CHESSY',
#    'voyageurs': 'O',
#    'code_uic': '87111849',
#    'geo_shape': {'coordinates': [2.782675554747206, 48.8699090633343],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Marne-la-Vallée-Chessy',
#    'pk': '031+319',
#    'idgaia': 'e152b624-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'SEINE-ET-MARNE',
#    'rg_troncon': 1,
#    'x_l93': 684058.1853,
#    'x_wgs84': 2.782675554747207,
#    'code_ligne': '226310',
#    'c_geo': [48.869909064290724, 2.7826755547472066],
#    'geo_point_2d': [48.8699090633343, 2.7826755547472057],
#    'y_wgs84': 48.869909064290724},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.7826755547472066, 48.869909064290724]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'dijon ville': {'datasetid': 'liste-des-gares',
#   'recordid': '90c37feaacd73f6e77c7e22a86536bc46e46f48c',
#   'fields': {'idreseau': 3958,
#    'y_l93': 6690173.2656,
#    'commune': 'LONGVIC',
#    'voyageurs': 'O',
#    'code_uic': '87713040',
#    'geo_shape': {'coordinates': [5.047449224021286, 47.29382365219269],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Dijon-Ville',
#    'pk': '314+208',
#    'idgaia': 'c101fe76-f312-11e3-90ff-015864e0362d',
#    'departemen': "COTE-D'OR",
#    'rg_troncon': 1,
#    'x_l93': 854714.9098000005,
#    'x_wgs84': 5.047449224021285,
#    'code_ligne': '849000',
#    'c_geo': [47.29382365316323, 5.047449224021285],
#    'geo_point_2d': [47.29382365219269, 5.047449224021286],
#    'y_wgs84': 47.29382365316323},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.047449224021285, 47.29382365316323]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'frévin capelle': {'datasetid': 'liste-des-gares',
#   'recordid': 'f8adde44c36144ea0572724c2d1f1e1eb9756ae4',
#   'fields': {'idreseau': 4238,
#    'y_l93': 7027787.856600001,
#    'commune': 'FRÉVIN-CAPELLE',
#    'voyageurs': 'O',
#    'code_uic': '87342212',
#    'geo_shape': {'coordinates': [2.633359694784461, 50.34727761311],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Frévin-Capelle',
#    'pk': '207+821',
#    'idgaia': 'd9d9f484-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'PAS-DE-CALAIS',
#    'rg_troncon': 1,
#    'x_l93': 673868.572300002,
#    'x_wgs84': 2.633359694784462,
#    'code_ligne': '307000',
#    'c_geo': [50.34727761405151, 2.6333596947844624],
#    'geo_point_2d': [50.34727761311, 2.633359694784461],
#    'y_wgs84': 50.34727761405151},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.6333596947844624, 50.34727761405151]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'villars les dombes': {'datasetid': 'liste-des-gares',
#   'recordid': '3a4443e20df9504a515cea44de8beacf9dae7c05',
#   'fields': {'idreseau': 7222,
#    'y_l93': 6546961.364700001,
#    'commune': 'VILLARS-LES-DOMBES',
#    'voyageurs': 'O',
#    'code_uic': '87723759',
#    'geo_shape': {'coordinates': [5.028308326099551, 46.004247126912084],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Villars-les-Dombes',
#    'pk': '038+142',
#    'idgaia': 'd9dabfaa-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'AIN',
#    'rg_troncon': 1,
#    'x_l93': 856947.3862999976,
#    'x_wgs84': 5.028308326099552,
#    'code_ligne': '886000',
#    'c_geo': [46.00424712787144, 5.028308326099552],
#    'geo_point_2d': [46.004247126912084, 5.028308326099551],
#    'y_wgs84': 46.00424712787144},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.028308326099552, 46.00424712787144]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'la bohalle': {'datasetid': 'liste-des-gares',
#   'recordid': '6a2665fe08c03b9705f94dc12d4a323ce7a94a10',
#   'fields': {'idreseau': 4595,
#    'y_l93': 6709306.7718,
#    'commune': 'LA BOHALLE',
#    'voyageurs': 'O',
#    'code_uic': '87487843',
#    'geo_shape': {'coordinates': [-0.400795047670262, 47.43443992573877],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'La Bohalle',
#    'pk': '330+549',
#    'idgaia': 'e1b99df4-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'MAINE-ET-LOIRE',
#    'rg_troncon': 1,
#    'x_l93': 443743.08680000156,
#    'x_wgs84': -0.40079504767026,
#    'code_ligne': '515000',
#    'c_geo': [47.43443992670813, -0.40079504767026014],
#    'geo_point_2d': [47.43443992573877, -0.4007950476702624],
#    'y_wgs84': 47.43443992670813},
#   'geometry': {'type': 'Point',
#    'coordinates': [-0.40079504767026014, 47.43443992670813]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'albias': {'datasetid': 'liste-des-gares',
#   'recordid': '1a5e69f7a088d4a121c1c080b9883e1a20c40fbe',
#   'fields': {'idreseau': 2840,
#    'y_l93': 6333695.987100001,
#    'commune': 'ALBIAS',
#    'voyageurs': 'O',
#    'code_uic': '87613398',
#    'geo_shape': {'coordinates': [1.443633051368781, 44.09121318041722],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Albias',
#    'pk': '650+664',
#    'idgaia': '29315884-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'TARN-ET-GARONNE',
#    'rg_troncon': 2,
#    'x_l93': 575377.5574000031,
#    'x_wgs84': 1.443633051368783,
#    'code_ligne': '590000',
#    'c_geo': [44.09121318138205, 1.4436330513687827],
#    'geo_point_2d': [44.09121318041722, 1.4436330513687814],
#    'y_wgs84': 44.09121318138205},
#   'geometry': {'type': 'Point',
#    'coordinates': [1.4436330513687827, 44.09121318138205]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'mont sur meurthe': {'datasetid': 'liste-des-gares',
#   'recordid': 'cf2f9873fa8206d5ed9c4014e74e50597a25e1ea',
#   'fields': {'idreseau': 5567,
#    'y_l93': 6834434.5528,
#    'commune': 'REHAINVILLER',
#    'voyageurs': 'O',
#    'code_uic': '87141143',
#    'geo_shape': {'coordinates': [6.450133611525778, 48.5600845876737],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Mont-sur-Meurthe',
#    'pk': '380+354',
#    'idgaia': '2990ce8e-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'MEURTHE-ET-MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 954508.6457000002,
#    'x_wgs84': 6.450133611525778,
#    'code_ligne': '070000',
#    'c_geo': [48.560084588633046, 6.450133611525778],
#    'geo_point_2d': [48.5600845876737, 6.450133611525778],
#    'y_wgs84': 48.560084588633046},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.450133611525778, 48.560084588633046]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'nurieux': {'datasetid': 'liste-des-gares',
#   'recordid': '41df7d09701ccbb8fd759b639c66622021d520ec',
#   'fields': {'idreseau': 5841,
#    'y_l93': 6568035.0667,
#    'commune': 'NURIEUX-VOLOGNAT',
#    'voyageurs': 'O',
#    'code_uic': '87743351',
#    'geo_shape': {'coordinates': [5.533214675860809, 46.18394454032505],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Nurieux',
#    'pk': '033+466',
#    'idgaia': 'd9b381e6-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'AIN',
#    'rg_troncon': 1,
#    'x_l93': 895364.1084000021,
#    'x_wgs84': 5.533214675860809,
#    'code_ligne': '884000',
#    'c_geo': [46.183944541283616, 5.533214675860809],
#    'geo_point_2d': [46.18394454032505, 5.533214675860809],
#    'y_wgs84': 46.183944541283616},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.533214675860809, 46.183944541283616]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'ponthierry pringy': {'datasetid': 'liste-des-gares',
#   'recordid': 'cafecabf72186e85c91360601f8c5a4debb6759d',
#   'fields': {'idreseau': 6107,
#    'y_l93': 6826181.322299998,
#    'commune': 'SAINT-FARGEAU-PONTHIERRY',
#    'voyageurs': 'O',
#    'code_uic': '87682526',
#    'geo_shape': {'coordinates': [2.5450606801092, 48.534996522695195],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Ponthierry-Pringy',
#    'pk': '047+628',
#    'idgaia': 'e1592a44-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'SEINE-ET-MARNE',
#    'rg_troncon': 1,
#    'x_l93': 666413.5799999982,
#    'x_wgs84': 2.545060680109201,
#    'code_ligne': '746000',
#    'c_geo': [48.53499652365479, 2.545060680109201],
#    'geo_point_2d': [48.534996522695195, 2.5450606801092004],
#    'y_wgs84': 48.53499652365479},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.545060680109201, 48.53499652365479]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'capdenac': {'datasetid': 'liste-des-gares',
#   'recordid': '9231df7053cd0cabb4322db3eac9607124daa0d5',
#   'fields': {'idreseau': 3477,
#    'y_l93': 6387047.063299999,
#    'commune': 'CAPDENAC-GARE',
#    'voyageurs': 'O',
#    'code_uic': '87613109',
#    'geo_shape': {'coordinates': [2.077408214377481, 44.57865477486293],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Capdenac',
#    'pk': '243+250',
#    'idgaia': 'd9b26ed4-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'AVEYRON',
#    'rg_troncon': 1,
#    'x_l93': 626755.2048999965,
#    'x_wgs84': 2.077408214377482,
#    'code_ligne': '718000',
#    'c_geo': [44.57865477582681, 2.0774082143774817],
#    'geo_point_2d': [44.57865477486293, 2.0774082143774812],
#    'y_wgs84': 44.57865477582681},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.0774082143774817, 44.57865477582681]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'tarbes': {'datasetid': 'liste-des-gares',
#   'recordid': 'a5c79d4a72888cbc89fdffd85f66fd3f252b7489',
#   'fields': {'idreseau': 6932,
#    'y_l93': 6242320.8456000015,
#    'commune': 'TARBES',
#    'voyageurs': 'O',
#    'code_uic': '87671008',
#    'geo_shape': {'coordinates': [0.069345942402881, 43.24030670414689],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Tarbes',
#    'pk': '156+293',
#    'idgaia': 'e17516d6-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'HAUTES-PYRENEES',
#    'rg_troncon': 1,
#    'x_l93': 461864.42390000075,
#    'x_wgs84': 0.069345942402883,
#    'code_ligne': '650000',
#    'c_geo': [43.24030670511259, 0.06934594240288312],
#    'geo_point_2d': [43.24030670414689, 0.06934594240288111],
#    'y_wgs84': 43.24030670511259},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.06934594240288312, 43.24030670511259]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'lathus': {'datasetid': 'liste-des-gares',
#   'recordid': '27685aafd320a76ac7b6a7247ac394623bf7a63b',
#   'fields': {'idreseau': 8180,
#    'y_l93': 6584037.443100002,
#    'commune': 'LATHUS-SAINT-RÉMY',
#    'voyageurs': 'O',
#    'code_uic': '87575498',
#    'geo_shape': {'coordinates': [0.965037394641158, 46.33810288977653],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Lathus',
#    'pk': '401+403',
#    'idgaia': '2981951a-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'VIENNE',
#    'rg_troncon': 1,
#    'x_l93': 543493.1970999986,
#    'x_wgs84': 0.96503739464116,
#    'code_ligne': '604000',
#    'c_geo': [46.338102890734426, 0.9650373946411603],
#    'geo_point_2d': [46.33810288977653, 0.9650373946411585],
#    'y_wgs84': 46.338102890734426},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.9650373946411603, 46.338102890734426]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'thann st jacques': {'datasetid': 'liste-des-gares',
#   'recordid': '87271fb2e952226079e6ec521e264c69f40db223',
#   'fields': {'idreseau': 6957,
#    'y_l93': 6753811.3532,
#    'commune': 'THANN',
#    'voyageurs': 'O',
#    'code_uic': '87182881',
#    'geo_shape': {'coordinates': [7.093342642302614, 47.81324746443295],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Thann-St-Jacques',
#    'pk': '015+530',
#    'idgaia': '29b4fe4e-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'HAUT-RHIN',
#    'rg_troncon': 1,
#    'x_l93': 1006218.3399000019,
#    'x_wgs84': 7.093342642302613,
#    'code_ligne': '130000',
#    'c_geo': [47.81324746539905, 7.093342642302613],
#    'geo_point_2d': [47.81324746443295, 7.0933426423026145],
#    'y_wgs84': 47.81324746539905},
#   'geometry': {'type': 'Point',
#    'coordinates': [7.093342642302613, 47.81324746539905]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'sérézin': {'datasetid': 'liste-des-gares',
#   'recordid': '88e792ba16763dc9f00b4ae25fa654eeb1aad07d',
#   'fields': {'idreseau': 6824,
#    'y_l93': 6504707.8182,
#    'commune': 'SÉRÉZIN-DU-RHÔNE',
#    'voyageurs': 'O',
#    'code_uic': '87722546',
#    'geo_shape': {'coordinates': [4.817813906825309, 45.6272306542698],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Sérézin',
#    'pk': '526+418',
#    'idgaia': 'e13bf49e-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'RHONE',
#    'rg_troncon': 1,
#    'x_l93': 841626.4624999985,
#    'x_wgs84': 4.81781390682531,
#    'code_ligne': '830000',
#    'c_geo': [45.6272306552306, 4.81781390682531],
#    'geo_point_2d': [45.6272306542698, 4.817813906825309],
#    'y_wgs84': 45.6272306552306},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.81781390682531, 45.6272306552306]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'sarreguemines': {'datasetid': 'liste-des-gares',
#   'recordid': '218309d050a73e986721d3007c90778460b5a51c',
#   'fields': {'idreseau': 6764,
#    'y_l93': 6897347.6785,
#    'commune': 'SARREGUEMINES',
#    'voyageurs': 'O',
#    'code_uic': '87193615',
#    'geo_shape': {'coordinates': [7.067955834918421, 49.107099548106575],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Sarreguemines',
#    'pk': '084+025',
#    'idgaia': 'd9e22970-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 996914.6124000028,
#    'x_wgs84': 7.06795583491842,
#    'code_ligne': '159000',
#    'c_geo': [49.10709954906073, 7.06795583491842],
#    'geo_point_2d': [49.107099548106575, 7.067955834918421],
#    'y_wgs84': 49.10709954906073},
#   'geometry': {'type': 'Point',
#    'coordinates': [7.06795583491842, 49.10709954906073]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'chaville rive gauche': {'datasetid': 'liste-des-gares',
#   'recordid': 'f48abfb3658ed9f66c54814e67250b44bce8155c',
#   'fields': {'idreseau': 3677,
#    'y_l93': 6856397.053599998,
#    'commune': 'CHAVILLE',
#    'voyageurs': 'O',
#    'code_uic': '87393207',
#    'geo_shape': {'coordinates': [2.189228436283295, 48.80489731094275],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Chaville-Rive-Gauche',
#    'pk': '012+457',
#    'idgaia': '296c6b6e-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'HAUTS-DE-SEINE',
#    'rg_troncon': 1,
#    'x_l93': 640452.6731999964,
#    'x_wgs84': 2.189228436283296,
#    'code_ligne': '420000',
#    'c_geo': [48.80489731189981, 2.1892284362832957],
#    'geo_point_2d': [48.80489731094275, 2.1892284362832948],
#    'y_wgs84': 48.80489731189981},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.1892284362832957, 48.80489731189981]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'le pouzin': {'datasetid': 'liste-des-gares',
#   'recordid': 'ca06d05f1aadcc7e946abd9646ac3e9ccb6c8aeb',
#   'fields': {'idreseau': 4997,
#    'y_l93': 6407393.7227,
#    'commune': 'LE POUZIN',
#    'voyageurs': 'N',
#    'code_uic': '87764407',
#    'geo_shape': {'coordinates': [4.750066436271399, 44.75186456015283],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Le Pouzin',
#    'pk': '640+765',
#    'idgaia': 'd9e3ad52-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'ARDECHE',
#    'rg_troncon': 1,
#    'x_l93': 838503.6247999966,
#    'x_wgs84': 4.750066436271399,
#    'code_ligne': '800000',
#    'c_geo': [44.751864561116314, 4.750066436271399],
#    'geo_point_2d': [44.75186456015283, 4.750066436271399],
#    'y_wgs84': 44.751864561116314},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.750066436271399, 44.751864561116314]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'noyon': {'datasetid': 'liste-des-gares',
#   'recordid': '1aabbc142a4bf0232430cee43c7e756d2c099655',
#   'fields': {'idreseau': 5834,
#    'y_l93': 6941974.331700001,
#    'commune': 'NOYON',
#    'voyageurs': 'O',
#    'code_uic': '87276782',
#    'geo_shape': {'coordinates': [3.006670255659019, 49.577008396767546],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Noyon',
#    'pk': '106+968',
#    'idgaia': '293a00aa-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'OISE',
#    'rg_troncon': 1,
#    'x_l93': 700482.6524000019,
#    'x_wgs84': 3.00667025565902,
#    'code_ligne': '242000',
#    'c_geo': [49.57700839771704, 3.0066702556590195],
#    'geo_point_2d': [49.577008396767546, 3.0066702556590186],
#    'y_wgs84': 49.57700839771704},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.0066702556590195, 49.57700839771704]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'pignans': {'datasetid': 'liste-des-gares',
#   'recordid': 'ece3461dbb147aa4843a1100a4f516340c2b1697',
#   'fields': {'idreseau': 6002,
#    'y_l93': 6249711.355900001,
#    'commune': 'PIGNANS',
#    'voyageurs': 'O',
#    'code_uic': '87755389',
#    'geo_shape': {'coordinates': [6.224888239870713, 43.29845349870851],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Pignans',
#    'pk': '104+678',
#    'idgaia': 'd989fcb2-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'VAR',
#    'rg_troncon': 1,
#    'x_l93': 961767.4949000031,
#    'x_wgs84': 6.224888239870714,
#    'code_ligne': '930000',
#    'c_geo': [43.298453499674146, 6.2248882398707135],
#    'geo_point_2d': [43.29845349870851, 6.2248882398707135],
#    'y_wgs84': 43.298453499674146},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.2248882398707135, 43.298453499674146]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'bossey veyrier': {'datasetid': 'liste-des-gares',
#   'recordid': '04add088d9ae54e72f6948f51f0182fd48eed22b',
#   'fields': {'idreseau': 3306,
#    'y_l93': 6567168.557500001,
#    'commune': 'ÉTREMBIÈRES',
#    'voyageurs': 'N',
#    'code_uic': '87745471',
#    'geo_shape': {'coordinates': [6.181542318223384, 46.159830364123074],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Bossey-Veyrier',
#    'pk': '165+921',
#    'idgaia': 'd9d797b6-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'HAUTE-SAVOIE',
#    'rg_troncon': 1,
#    'x_l93': 945447.3672000021,
#    'x_wgs84': 6.181542318223384,
#    'code_ligne': '892000',
#    'c_geo': [46.159830365081774, 6.181542318223384],
#    'geo_point_2d': [46.159830364123074, 6.181542318223384],
#    'y_wgs84': 46.159830365081774},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.181542318223384, 46.159830365081774]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'nogent le rotrou': {'datasetid': 'liste-des-gares',
#   'recordid': 'f3f30702dfff97917e5165b2d1a9d895916bb746',
#   'fields': {'idreseau': 5807,
#    'y_l93': 6805068.773699999,
#    'commune': 'NOGENT-LE-ROTROU',
#    'voyageurs': 'O',
#    'code_uic': '87394296',
#    'geo_shape': {'coordinates': [0.810167196602149, 48.32568335166827],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Nogent-le-Rotrou',
#    'pk': '148+113',
#    'idgaia': 'e1546426-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'EURE-ET-LOIR',
#    'rg_troncon': 1,
#    'x_l93': 537707.7427999973,
#    'x_wgs84': 0.810167196602151,
#    'code_ligne': '420000',
#    'c_geo': [48.32568335262978, 0.8101671966021508],
#    'geo_point_2d': [48.32568335166827, 0.8101671966021489],
#    'y_wgs84': 48.32568335262978},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.8101671966021508, 48.32568335262978]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'marseille en beauvaisis': {'datasetid': 'liste-des-gares',
#   'recordid': 'a63eb4d764fcfc3174799045ac76697fac7d542f',
#   'fields': {'idreseau': 5394,
#    'y_l93': 6941801.140000001,
#    'commune': 'MARSEILLE-EN-BEAUVAISIS',
#    'voyageurs': 'O',
#    'code_uic': '87313726',
#    'geo_shape': {'coordinates': [1.954684190772342, 49.57095250518969],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Marseille-en-Beauvaisis',
#    'pk': '100+078',
#    'idgaia': 'e008bdc0-19bf-11e5-82ff-01fc64e0362d',
#    'departemen': 'OISE',
#    'rg_troncon': 1,
#    'x_l93': 624355.3805000037,
#    'x_wgs84': 1.954684190772344,
#    'code_ligne': '325000',
#    'c_geo': [49.57095250613924, 1.954684190772344],
#    'geo_point_2d': [49.57095250518969, 1.954684190772342],
#    'y_wgs84': 49.57095250613924},
#   'geometry': {'type': 'Point',
#    'coordinates': [1.954684190772344, 49.57095250613924]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rezé pont rousseau': {'datasetid': 'liste-des-gares',
#   'recordid': 'de47e725650b50c03490d5be2ab92e008a4d751e',
#   'fields': {'idreseau': 6244,
#    'y_l93': 6686925.624400001,
#    'commune': 'REZE',
#    'voyageurs': 'O',
#    'code_uic': '87481036',
#    'geo_shape': {'coordinates': [-1.549492482887931, 47.1933346686705],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Rezé-Pont-Rousseau',
#    'pk': '001+755',
#    'idgaia': 'd9b7dde2-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'LOIRE-ATLANTIQUE',
#    'rg_troncon': 1,
#    'x_l93': 355727.81440000236,
#    'x_wgs84': -1.549492482887928,
#    'code_ligne': '534000',
#    'c_geo': [47.19333466964187, -1.5494924828879282],
#    'geo_point_2d': [47.1933346686705, -1.5494924828879308],
#    'y_wgs84': 47.19333466964187},
#   'geometry': {'type': 'Point',
#    'coordinates': [-1.5494924828879282, 47.19333466964187]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rougebarre': {'datasetid': 'liste-des-gares',
#   'recordid': 'eb9ec83ab573d9ed6c598b21f0d2a188531d6dfc',
#   'fields': {'idreseau': 80928,
#    'y_l93': 7061935.995299999,
#    'commune': 'MARCQ-EN-BAROEUL',
#    'voyageurs': 'N',
#    'code_uic': '87286252',
#    'geo_shape': {'coordinates': [3.105847130233248, 50.654290442286566],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Rougebarre',
#    'pk': '003+612',
#    'idgaia': 'e547e6a6-6667-11e3-a7ff-01f464e0362d',
#    'departemen': 'NORD',
#    'rg_troncon': 1,
#    'x_l93': 707498.1815000027,
#    'x_wgs84': 3.105847130233249,
#    'code_ligne': '278000',
#    'c_geo': [50.65429044322478, 3.1058471302332493],
#    'geo_point_2d': [50.654290442286566, 3.1058471302332484],
#    'y_wgs84': 50.65429044322478},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.1058471302332493, 50.65429044322478]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'chabenet': {'datasetid': 'liste-des-gares',
#   'recordid': '67ba66913d832f9858f14743757d6e366a17fc82',
#   'fields': {'idreseau': 3544,
#    'y_l93': 6615407.570900001,
#    'commune': 'LE PONT-CHRÉTIEN-CHABENET',
#    'voyageurs': 'O',
#    'code_uic': '87597112',
#    'geo_shape': {'coordinates': [1.509793321730763, 46.62904874985032],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Chabenet',
#    'pk': '290+160',
#    'idgaia': 'c1410402-f312-11e3-90ff-015864e0362d',
#    'departemen': 'INDRE',
#    'rg_troncon': 2,
#    'x_l93': 585993.6608999968,
#    'x_wgs84': 1.509793321730764,
#    'code_ligne': '590000',
#    'c_geo': [46.62904875080688, 1.5097933217307644],
#    'geo_point_2d': [46.62904874985032, 1.5097933217307629],
#    'y_wgs84': 46.62904875080688},
#   'geometry': {'type': 'Point',
#    'coordinates': [1.5097933217307644, 46.62904875080688]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'langeais': {'datasetid': 'liste-des-gares',
#   'recordid': '38f1239bf823b465ea1c1b1e30193ab99df47ae4',
#   'fields': {'idreseau': 4856,
#    'y_l93': 6694726.228599999,
#    'commune': 'LANGEAIS',
#    'voyageurs': 'O',
#    'code_uic': '87571828',
#    'geo_shape': {'coordinates': [0.410677308449882, 47.3240049013241],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Langeais',
#    'pk': '260+233',
#    'idgaia': 'c08b050e-f312-11e3-90ff-015864e0362d',
#    'departemen': 'INDRE-ET-LOIRE',
#    'rg_troncon': 1,
#    'x_l93': 504461.63710000366,
#    'x_wgs84': 0.410677308449883,
#    'code_ligne': '515000',
#    'c_geo': [47.3240049022944, 0.41067730844988326],
#    'geo_point_2d': [47.3240049013241, 0.4106773084498816],
#    'y_wgs84': 47.3240049022944},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.41067730844988326, 47.3240049022944]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'metz ville': {'datasetid': 'liste-des-gares',
#   'recordid': '46865c146261f4fbb813e670e4bc5b102afbd122',
#   'fields': {'idreseau': 5484,
#    'y_l93': 6894763.672200002,
#    'commune': 'METZ',
#    'voyageurs': 'O',
#    'code_uic': '87192039',
#    'geo_shape': {'coordinates': [6.180568549134687, 49.1106004671715],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Metz-Ville',
#    'pk': '154+320',
#    'idgaia': '293fac44-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 932169.6546000019,
#    'x_wgs84': 6.180568549134685,
#    'code_ligne': '180000',
#    'c_geo': [49.110600468125604, 6.180568549134685],
#    'geo_point_2d': [49.1106004671715, 6.180568549134687],
#    'y_wgs84': 49.110600468125604},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.180568549134685, 49.110600468125604]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'lamballe': {'datasetid': 'liste-des-gares',
#   'recordid': '61872e6f22843361f364331039d9a60190f9a929',
#   'fields': {'idreseau': 4831,
#    'y_l93': 6832621.676199999,
#    'commune': 'LAMBALLE',
#    'voyageurs': 'O',
#    'code_uic': '87473108',
#    'geo_shape': {'coordinates': [-2.511460566036287, 48.46594346827299],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Lamballe',
#    'pk': '454+259',
#    'idgaia': 'e142fab4-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': "COTES-D'ARMOR",
#    'rg_troncon': 1,
#    'x_l93': 292902.77870000154,
#    'x_wgs84': -2.511460566036283,
#    'code_ligne': '420000',
#    'c_geo': [48.46594346923323, -2.5114605660362828],
#    'geo_point_2d': [48.46594346827299, -2.5114605660362868],
#    'y_wgs84': 48.46594346923323},
#   'geometry': {'type': 'Point',
#    'coordinates': [-2.5114605660362828, 48.46594346923323]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'labarthe avezac': {'datasetid': 'liste-des-gares',
#   'recordid': '91c9da49f18eb9ee4bd0a86d678b61f9d55420c8',
#   'fields': {'idreseau': 9128,
#    'y_l93': 6223926.392000001,
#    'commune': 'AVEZAC-PRAT-LAHITTE',
#    'voyageurs': 'N',
#    'code_uic': '87671404',
#    'geo_shape': {'coordinates': [0.361662204714229, 43.08230064976865],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Labarthe-Avezac',
#    'pk': '124+919',
#    'idgaia': 'c03cca7e-f312-11e3-90ff-015864e0362d',
#    'departemen': 'HAUTES-PYRENEES',
#    'rg_troncon': 1,
#    'x_l93': 485020.9416999966,
#    'x_wgs84': 0.361662204714232,
#    'code_ligne': '667000',
#    'c_geo': [43.08230065073437, 0.3616622047142317],
#    'geo_point_2d': [43.08230064976865, 0.3616622047142292],
#    'y_wgs84': 43.08230065073437},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.3616622047142317, 43.08230065073437]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'viry châtillon': {'datasetid': 'liste-des-gares',
#   'recordid': '14adffd1c85ddef0c1705dbf21ea663944a8a54a',
#   'fields': {'idreseau': 7303,
#    'y_l93': 6841948.931200001,
#    'commune': 'VIRY-CHATILLON',
#    'voyageurs': 'O',
#    'code_uic': '87681312',
#    'geo_shape': {'coordinates': [2.386823087795418, 48.67612207448848],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Viry-Châtillon',
#    'pk': '022+730',
#    'idgaia': 'd98818ce-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'ESSONNE',
#    'rg_troncon': 1,
#    'x_l93': 654853.5428000018,
#    'x_wgs84': 2.386823087795419,
#    'code_ligne': '745000',
#    'c_geo': [48.67612207544676, 2.3868230877954186],
#    'geo_point_2d': [48.67612207448848, 2.3868230877954177],
#    'y_wgs84': 48.67612207544676},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3868230877954186, 48.67612207544676]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'dompierre sept fons': {'datasetid': 'liste-des-gares',
#   'recordid': '3cc869458e60251027267ed2af498b08e4ccc301',
#   'fields': {'idreseau': 3983,
#    'y_l93': 6603155.090100002,
#    'commune': 'DOMPIERRE-SUR-BESBRE',
#    'voyageurs': 'O',
#    'code_uic': '87696427',
#    'geo_shape': {'coordinates': [3.675343009355433, 46.52641660079302],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Dompierre-Sept-Fons',
#    'pk': '027+752',
#    'idgaia': 'd9a3e864-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'ALLIER',
#    'rg_troncon': 1,
#    'x_l93': 751766.1656000018,
#    'x_wgs84': 3.675343009355433,
#    'code_ligne': '770000',
#    'c_geo': [46.52641660175006, 3.675343009355433],
#    'geo_point_2d': [46.52641660079302, 3.675343009355433],
#    'y_wgs84': 46.52641660175006},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.675343009355433, 46.52641660175006]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'vorey': {'datasetid': 'liste-des-gares',
#   'recordid': 'f8e4a9b6bdde2c4bc8bc0a6b631fa3e45c66ba4f',
#   'fields': {'idreseau': 7326,
#    'y_l93': 6454257.8336,
#    'commune': 'VOREY',
#    'voyageurs': 'O',
#    'code_uic': '87734723',
#    'geo_shape': {'coordinates': [3.910845069786844, 45.183917173773025],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Vorey',
#    'pk': '073+095',
#    'idgaia': 'd9a12334-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'HAUTE-LOIRE',
#    'rg_troncon': 1,
#    'x_l93': 771536.8153999969,
#    'x_wgs84': 3.910845069786845,
#    'code_ligne': '798000',
#    'c_geo': [45.183917174735306, 3.9108450697868453],
#    'geo_point_2d': [45.183917173773025, 3.910845069786844],
#    'y_wgs84': 45.183917174735306},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.9108450697868453, 45.183917174735306]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'aéroport charles de gaulle 2 tgv': {'datasetid': 'liste-des-gares',
#   'recordid': '4c0ac94066a32ecc0fdf6addfeec283fbc3f1c22',
#   'fields': {'idreseau': 87381,
#    'y_l93': 6878315.6182,
#    'commune': 'TREMBLAY-EN-FRANCE',
#    'voyageurs': 'O',
#    'code_uic': '87271494',
#    'geo_shape': {'coordinates': [2.571223196694158, 49.00399011664727],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Aéroport-Charles-de-Gaulle 2-TGV',
#    'pk': '007+487',
#    'idgaia': '2923885c-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'SEINE-ET-MARNE',
#    'rg_troncon': 1,
#    'x_l93': 668628.1960999966,
#    'x_wgs84': 2.571223196694159,
#    'code_ligne': '226310',
#    'c_geo': [49.00399011760242, 2.5712231966941586],
#    'geo_point_2d': [49.00399011664727, 2.571223196694158],
#    'y_wgs84': 49.00399011760242},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.5712231966941586, 49.00399011760242]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'ronchin': {'datasetid': 'liste-des-gares',
#   'recordid': '57b0204cb20845af518637a7eb5b455fc06a0c62',
#   'fields': {'idreseau': 6293,
#    'y_l93': 7056315.305599999,
#    'commune': 'RONCHIN',
#    'voyageurs': 'O',
#    'code_uic': '87286534',
#    'geo_shape': {'coordinates': [3.077597498635682, 50.60386936078378],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Ronchin',
#    'pk': '246+423',
#    'idgaia': 'd9c8603e-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'NORD',
#    'rg_troncon': 1,
#    'x_l93': 705502.5073999986,
#    'x_wgs84': 3.077597498635683,
#    'code_ligne': '272000',
#    'c_geo': [50.60386936172255, 3.0775974986356833],
#    'geo_point_2d': [50.60386936078378, 3.077597498635682],
#    'y_wgs84': 50.60386936172255},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.0775974986356833, 50.60386936172255]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'teting': {'datasetid': 'liste-des-gares',
#   'recordid': '3505ddb411370c62eec768c967a70951f266b122',
#   'fields': {'idreseau': 6955,
#    'y_l93': 6889753.8486,
#    'commune': 'TETING-SUR-NIED',
#    'voyageurs': 'O',
#    'code_uic': '87193342',
#    'geo_shape': {'coordinates': [6.664731283040831, 49.05171884864747],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Teting',
#    'pk': '021+843',
#    'idgaia': 'd9c22258-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 967791.8531000018,
#    'x_wgs84': 6.66473128304083,
#    'code_ligne': '172000',
#    'c_geo': [49.05171884960215, 6.66473128304083],
#    'geo_point_2d': [49.05171884864747, 6.664731283040831],
#    'y_wgs84': 49.05171884960215},
#   'geometry': {'type': 'Point',
#    'coordinates': [6.66473128304083, 49.05171884960215]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'st brieuc': {'datasetid': 'liste-des-gares',
#   'recordid': 'ea757af35a75afd849a4f6c3e205aaaf4b97a8db',
#   'fields': {'idreseau': 6396,
#    'y_l93': 6838695.787300002,
#    'commune': 'SAINT-BRIEUC',
#    'voyageurs': 'O',
#    'code_uic': '87473009',
#    'geo_shape': {'coordinates': [-2.773798977672478, 48.50824301261329],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'St-Brieuc',
#    'pk': '474+489',
#    'idgaia': 'e0168a32-19bf-11e5-82ff-01fc64e0362d',
#    'departemen': "COTES-D'ARMOR",
#    'rg_troncon': 1,
#    'x_l93': 273902.7466999963,
#    'x_wgs84': -2.773798977672474,
#    'code_ligne': '475000',
#    'c_geo': [48.50824301357313, -2.7737989776724743],
#    'geo_point_2d': [48.50824301261329, -2.7737989776724783],
#    'y_wgs84': 48.50824301357313},
#   'geometry': {'type': 'Point',
#    'coordinates': [-2.7737989776724743, 48.50824301357313]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'montreux vieux': {'datasetid': 'liste-des-gares',
#   'recordid': '2e8dd38912c4960c98edb0e2861ed7a6328eac8d',
#   'fields': {'idreseau': 5655,
#    'y_l93': 6731892.921399999,
#    'commune': 'MONTREUX-VIEUX',
#    'voyageurs': 'O',
#    'code_uic': '87184275',
#    'geo_shape': {'coordinates': [7.026212962770895, 47.61803856386719],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Montreux-Vieux',
#    'pk': '456+799',
#    'idgaia': 'd9987bf0-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'HAUT-RHIN',
#    'rg_troncon': 1,
#    'x_l93': 1002306.2242000028,
#    'x_wgs84': 7.026212962770893,
#    'code_ligne': '001000',
#    'c_geo': [47.618038564834976, 7.026212962770893],
#    'geo_point_2d': [47.61803856386719, 7.026212962770895],
#    'y_wgs84': 47.618038564834976},
#   'geometry': {'type': 'Point',
#    'coordinates': [7.026212962770893, 47.618038564834976]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'chissay en touraine': {'datasetid': 'liste-des-gares',
#   'recordid': 'bd98476e1033ef564ba61a8df77192a3f210542a',
#   'fields': {'idreseau': 3712,
#    'y_l93': 6694401.793200001,
#    'commune': 'CHISSAY-EN-TOURAINE',
#    'voyageurs': 'O',
#    'code_uic': '87574848',
#    'geo_shape': {'coordinates': [1.133683878470543, 47.334955459962394],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Chissay-en-Touraine',
#    'pk': '275+526',
#    'idgaia': '28fc3e08-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'LOIR-ET-CHER',
#    'rg_troncon': 1,
#    'x_l93': 559077.6689999998,
#    'x_wgs84': 1.133683878470545,
#    'code_ligne': '593000',
#    'c_geo': [47.33495546093258, 1.1336838784705445],
#    'geo_point_2d': [47.334955459962394, 1.1336838784705427],
#    'y_wgs84': 47.33495546093258},
#   'geometry': {'type': 'Point',
#    'coordinates': [1.1336838784705445, 47.33495546093258]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'port fluvial de chalon sur saône': {'datasetid': 'liste-des-gares',
#   'recordid': 'dccece39ef573254b1de081f8b05793ab1f55f74',
#   'fields': {'idreseau': 81516,
#    'y_l93': 6635051.798999999,
#    'commune': 'CHALON-SUR-SAONE',
#    'voyageurs': 'N',
#    'code_uic': '87729210',
#    'geo_shape': {'coordinates': [4.846921199722042, 46.80078209746864],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Port-Fluvial-de-Chalon-sur-Saône',
#    'pk': '103+878',
#    'idgaia': 'e543809c-6667-11e3-a7ff-01f464e0362d',
# ...
#    'geo_shape': {'coordinates': [2.965051211539134, 47.28252848176941],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Pouilly-sur-Loire',
#    'pk': '214+004',
#    'idgaia': '297a4c76-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'NIEVRE',
#    'rg_troncon': 1,
#    'x_l93': 697358.253700003,
#    'x_wgs84': 2.965051211539136,
#    'code_ligne': '750000',
#    'c_geo': [47.28252848274005, 2.965051211539136],
#    'geo_point_2d': [47.28252848176941, 2.965051211539134],
#    'y_wgs84': 47.28252848274005},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.965051211539136, 47.28252848274005]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'la barre ormesson': {'datasetid': 'liste-des-gares',
#   'recordid': '9baf59ce6001bab80e0587459c332d61f4ecaef8',
#   'fields': {'idreseau': 4584,
#    'y_l93': 6874319.619100001,
#    'commune': 'DEUIL-LA-BARRE',
#    'voyageurs': 'O',
#    'code_uic': '87271171',
#    'geo_shape': {'coordinates': [2.315824843537353, 48.9668719643113],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'La Barre-Ormesson',
#    'pk': '010+380',
#    'idgaia': 'd9a243fc-6667-11e3-89ff-01f464e0362d',
#    'departemen': "VAL-D'OISE",
#    'rg_troncon': 1,
#    'x_l93': 649906.3825000003,
#    'x_wgs84': 2.315824843537354,
#    'code_ligne': '330000',
#    'c_geo': [48.96687196526681, 2.3158248435373543],
#    'geo_point_2d': [48.9668719643113, 2.3158248435373534],
#    'y_wgs84': 48.96687196526681},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.3158248435373543, 48.96687196526681]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rozières sur mouzon': {'datasetid': 'liste-des-gares',
#   'recordid': '4b8ddf7368488d6a81e9144262a98756b31f4f45',
#   'fields': {'idreseau': 6329,
#    'y_l93': 6783508.307300001,
#    'commune': 'ROZIÈRES-SUR-MOUZON',
#    'voyageurs': 'O',
#    'code_uic': '87144311',
#    'geo_shape': {'coordinates': [5.705525159209667, 48.12090780369433],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Rozières-sur-Mouzon',
#    'pk': '042+056',
#    'idgaia': '2924a5ac-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'VOSGES',
#    'rg_troncon': 1,
#    'x_l93': 901277.2006999999,
#    'x_wgs84': 5.705525159209666,
#    'code_ligne': '035000',
#    'c_geo': [48.120907804657705, 5.705525159209666],
#    'geo_point_2d': [48.12090780369433, 5.7055251592096665],
#    'y_wgs84': 48.120907804657705},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.705525159209666, 48.120907804657705]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'luc en diois': {'datasetid': 'liste-des-gares',
#   'recordid': 'e555bdf6a6182de2d869ab69bfa7d3a744d2d091',
#   'fields': {'idreseau': 5258,
#    'y_l93': 6393576.897100002,
#    'commune': 'LUC-EN-DIOIS',
#    'voyageurs': 'O',
#    'code_uic': '87761874',
#    'geo_shape': {'coordinates': [5.454832629017519, 44.61403808756079],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Luc-en-Diois',
#    'pk': '073+609',
#    'idgaia': 'd9dde0c8-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'DROME',
#    'rg_troncon': 1,
#    'x_l93': 894740.6542000026,
#    'x_wgs84': 5.454832629017519,
#    'code_ligne': '912000',
#    'c_geo': [44.61403808852461, 5.454832629017519],
#    'geo_point_2d': [44.61403808756079, 5.454832629017519],
#    'y_wgs84': 44.61403808852461},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.454832629017519, 44.61403808852461]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  "sèvres ville d'avray": {'datasetid': 'liste-des-gares',
#   'recordid': 'a0b89b92e8d12c94a56a8b4e4f8b027a9a8ca0ab',
#   'fields': {'idreseau': 6848,
#    'y_l93': 6858891.674600001,
#    'commune': 'SEVRES',
#    'voyageurs': 'O',
#    'code_uic': '87382341',
#    'geo_shape': {'coordinates': [2.200787293018456, 48.82741175938357],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': "Sèvres-Ville-d'Avray",
#    'pk': '016+583',
#    'idgaia': 'd994cc5e-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'HAUTS-DE-SEINE',
#    'rg_troncon': 1,
#    'x_l93': 641326.9248000011,
#    'x_wgs84': 2.200787293018457,
#    'code_ligne': '973000',
#    'c_geo': [48.82741176034041, 2.200787293018457],
#    'geo_point_2d': [48.82741175938357, 2.2007872930184558],
#    'y_wgs84': 48.82741176034041},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.200787293018457, 48.82741176034041]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'rungis (min)': {'datasetid': 'liste-des-gares',
#   'recordid': 'cfa833fdbb82e069f9e14f703778894ffe799e22',
#   'fields': {'idreseau': 8421,
#    'y_l93': 6849483.3902,
#    'commune': 'RUNGIS',
#    'voyageurs': 'N',
#    'code_uic': '87546002',
#    'geo_shape': {'coordinates': [2.361965873313875, 48.74376154309177],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Rungis (MIN)',
#    'pk': '017+250',
#    'idgaia': 'e54182ee-6667-11e3-a7ff-01f464e0362d',
#    'departemen': 'VAL-DE-MARNE',
#    'rg_troncon': 1,
#    'x_l93': 653084.1806999967,
#    'x_wgs84': 2.361965873313876,
#    'code_ligne': '985000',
#    'c_geo': [48.7437615440494, 2.361965873313876],
#    'geo_point_2d': [48.74376154309177, 2.3619658733138746],
#    'y_wgs84': 48.7437615440494},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.361965873313876, 48.7437615440494]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'st cyr les lècques la cadière': {'datasetid': 'liste-des-gares',
#   'recordid': '64e1d9869a2df753c833a3025046cf6fcf4ed06e',
#   'fields': {'idreseau': 6416,
#    'y_l93': 6235558.805799998,
#    'commune': 'SAINT-CYR-SUR-MER',
#    'voyageurs': 'O',
#    'code_uic': '87755215',
#    'geo_shape': {'coordinates': [5.703752554715747, 43.18536670326795],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'St-Cyr-les-Lècques-La Cadière',
#    'pk': '043+156',
#    'idgaia': 'd98ffb24-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'VAR',
#    'rg_troncon': 1,
#    'x_l93': 919914.8907999992,
#    'x_wgs84': 5.703752554715746,
#    'code_ligne': '930000',
#    'c_geo': [43.18536670423366, 5.703752554715746],
#    'geo_point_2d': [43.18536670326795, 5.703752554715747],
#    'y_wgs84': 43.18536670423366},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.703752554715746, 43.18536670423366]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'plounérin': {'datasetid': 'liste-des-gares',
#   'recordid': 'acd711360a221682a97c80b25bfadb340e3e0a4d',
#   'fields': {'idreseau': 6029,
#    'y_l93': 6851376.614799999,
#    'commune': 'PLOUNÉRIN',
#    'voyageurs': 'O',
#    'code_uic': '87473199',
#    'geo_shape': {'coordinates': [-3.569159217575644, 48.58130509627217],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Plounérin',
#    'pk': '539+121',
#    'idgaia': 'd98c42a6-6667-11e3-89ff-01f464e0362d',
#    'departemen': "COTES-D'ARMOR",
#    'rg_troncon': 1,
#    'x_l93': 216008.58569999784,
#    'x_wgs84': -3.56915921757564,
#    'code_ligne': '420000',
#    'c_geo': [48.58130509723133, -3.5691592175756397],
#    'geo_point_2d': [48.58130509627217, -3.5691592175756437],
#    'y_wgs84': 48.58130509723133},
#   'geometry': {'type': 'Point',
#    'coordinates': [-3.5691592175756397, 48.58130509723133]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'chambéry challes les eaux': {'datasetid': 'liste-des-gares',
#   'recordid': '70b81d8981f35030950d6da611ab46a24fb6ba23',
#   'fields': {'idreseau': 3570,
#    'y_l93': 6501142.5605,
#    'commune': 'CHAMBERY',
#    'voyageurs': 'O',
#    'code_uic': '87741009',
#    'geo_shape': {'coordinates': [5.919644744721904, 45.57190136255774],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Chambéry-Challes-les-Eaux',
#    'pk': '137+673',
#    'idgaia': 'e19e2b92-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'SAVOIE',
#    'rg_troncon': 1,
#    'x_l93': 927665.8559999987,
#    'x_wgs84': 5.919644744721905,
#    'code_ligne': '900000',
#    'c_geo': [45.57190136351876, 5.9196447447219045],
#    'geo_point_2d': [45.57190136255774, 5.9196447447219045],
#    'y_wgs84': 45.57190136351876},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.9196447447219045, 45.57190136351876]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'la ville gozet': {'datasetid': 'liste-des-gares',
#   'recordid': '8096e46f8deff3f3ccec8faf938b3928aa64f489',
#   'fields': {'idreseau': 4783,
#    'y_l93': 6583399.629099999,
#    'commune': 'MONTLUCON',
#    'voyageurs': 'O',
#    'code_uic': '87641191',
#    'geo_shape': {'coordinates': [2.591782416405333, 46.349789566501364],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'La Ville-Gozet',
#    'pk': '364+891',
#    'idgaia': 'd993097c-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'ALLIER',
#    'rg_troncon': 1,
#    'x_l93': 668607.7950000018,
#    'x_wgs84': 2.591782416405334,
#    'code_ligne': '696000',
#    'c_geo': [46.34978956745922, 2.5917824164053336],
#    'geo_point_2d': [46.349789566501364, 2.591782416405333],
#    'y_wgs84': 46.34978956745922},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.5917824164053336, 46.34978956745922]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'port sec de pacy': {'datasetid': 'liste-des-gares',
#   'recordid': '89ccb168ce7b46d8b7e4291bc96d6ce6b6ed5f53',
#   'fields': {'idreseau': 6125,
#    'y_l93': 6742662.149099998,
#    'commune': 'PACY-SUR-ARMANÇON',
#    'voyageurs': 'N',
#    'code_uic': '87712588',
#    'geo_shape': {'coordinates': [4.107603239235026, 47.77911745489069],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Port-Sec-de-Pacy',
#    'pk': '213+000',
#    'idgaia': 'e53f12a2-6667-11e3-a7ff-01f464e0362d',
#    'departemen': 'YONNE',
#    'rg_troncon': 1,
#    'x_l93': 782946.141900003,
#    'x_wgs84': 4.107603239235026,
#    'code_ligne': '830000',
#    'c_geo': [47.7791174558571, 4.107603239235026],
#    'geo_point_2d': [47.77911745489069, 4.107603239235026],
#    'y_wgs84': 47.7791174558571},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.107603239235026, 47.7791174558571]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'bougival': {'datasetid': 'liste-des-gares',
#   'recordid': 'd8760fad7222f1eee28cac51eef009fc7f98c55e',
#   'fields': {'idreseau': 3315,
#    'y_l93': 6861927.890700001,
#    'commune': 'CELLE-SAINT-CLOUD (LA )',
#    'voyageurs': 'O',
#    'code_uic': '87382440',
#    'geo_shape': {'coordinates': [2.132167367768377, 48.85424085483922],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Bougival',
#    'pk': '022+174',
#    'idgaia': 'e14236a4-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'YVELINES',
#    'rg_troncon': 1,
#    'x_l93': 636322.2707000002,
#    'x_wgs84': 2.132167367768379,
#    'code_ligne': '974000',
#    'c_geo': [48.85424085579581, 2.1321673677683792],
#    'geo_point_2d': [48.85424085483922, 2.1321673677683775],
#    'y_wgs84': 48.85424085579581},
#   'geometry': {'type': 'Point',
#    'coordinates': [2.1321673677683792, 48.85424085579581]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'peyrehorade': {'datasetid': 'liste-des-gares',
#   'recordid': '405d61ba13fe6297e7db171e0e01d08eddc4f9bf',
#   'fields': {'idreseau': 5986,
#    'y_l93': 6280638.006299999,
#    'commune': 'PEYREHORADE',
#    'voyageurs': 'O',
#    'code_uic': '87672337',
#    'geo_shape': {'coordinates': [-1.11536113027523, 43.54680048626475],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Peyrehorade',
#    'pk': '287+827',
#    'idgaia': 'd98c6232-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'LANDES',
#    'rg_troncon': 1,
#    'x_l93': 367448.33039999753,
#    'x_wgs84': -1.115361130275228,
#    'code_ligne': '650000',
#    'c_geo': [43.54680048723023, -1.115361130275228],
#    'geo_point_2d': [43.54680048626475, -1.1153611302752302],
#    'y_wgs84': 43.54680048723023},
#   'geometry': {'type': 'Point',
#    'coordinates': [-1.115361130275228, 43.54680048723023]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'monsempron libos': {'datasetid': 'liste-des-gares',
#   'recordid': '3c1754b8d3aaef7762436df0ddf75b9d01817de9',
#   'fields': {'idreseau': 5558,
#    'y_l93': 6378690.857299998,
#    'commune': 'MONSEMPRON-LIBOS',
#    'voyageurs': 'O',
#    'code_uic': '87586453',
#    'geo_shape': {'coordinates': [0.943445225212705, 44.488111504048916],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Monsempron-Libos',
#    'pk': '608+230',
#    'idgaia': '29bc606e-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'LOT-ET-GARONNE',
#    'rg_troncon': 1,
#    'x_l93': 536482.4166999981,
#    'x_wgs84': 0.943445225212706,
#    'code_ligne': '632000',
#    'c_geo': [44.48811150501302, 0.9434452252127062],
#    'geo_point_2d': [44.488111504048916, 0.9434452252127049],
#    'y_wgs84': 44.48811150501302},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.9434452252127062, 44.48811150501302]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'frénouville cagny': {'datasetid': 'liste-des-gares',
#   'recordid': '81fdffb380cb88cac8c677746475d1f1a1f18531',
#   'fields': {'idreseau': 4231,
#    'y_l93': 6898394.578200001,
#    'commune': 'CAGNY',
#    'voyageurs': 'O',
#    'code_uic': '87444182',
#    'geo_shape': {'coordinates': [-0.260107811928258, 49.14114275200297],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Frénouville-Cagny',
#    'pk': '231+219',
#    'idgaia': '2972de48-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'CALVADOS',
#    'rg_troncon': 1,
#    'x_l93': 462167.74660000205,
#    'x_wgs84': -0.260107811928255,
#    'code_ligne': '366000',
#    'c_geo': [49.14114275295679, -0.2601078119282554],
#    'geo_point_2d': [49.14114275200297, -0.2601078119282581],
#    'y_wgs84': 49.14114275295679},
#   'geometry': {'type': 'Point',
#    'coordinates': [-0.2601078119282554, 49.14114275295679]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'champagne ardenne tgv': {'datasetid': 'liste-des-gares',
#   'recordid': 'c387719e1e767c56b05c3fa7eb8e6b99fb5d7e25',
#   'fields': {'idreseau': 92610,
#    'y_l93': 6902105.835499998,
#    'commune': 'BEZANNES',
#    'voyageurs': 'O',
#    'code_uic': '87171926',
#    'geo_shape': {'coordinates': [3.993655995605393, 49.21455924106243],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Champagne-Ardenne-TGV',
#    'pk': '001+536',
#    'idgaia': '293c6028-dfbc-11e3-a2ff-01a464e0362d',
#    'departemen': 'MARNE',
#    'rg_troncon': 1,
#    'x_l93': 772405.3835000023,
#    'x_wgs84': 3.993655995605394,
#    'code_ligne': '005317',
#    'c_geo': [49.21455924201552, 3.9936559956053936],
#    'geo_point_2d': [49.21455924106243, 3.9936559956053928],
#    'y_wgs84': 49.21455924201552},
#   'geometry': {'type': 'Point',
#    'coordinates': [3.9936559956053936, 49.21455924201552]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'onville': {'datasetid': 'liste-des-gares',
#   'recordid': '8a1aac1c4c5538d1331bd9e71afcf34953f5784f',
#   'fields': {'idreseau': 5860,
#    'y_l93': 6883365.974599998,
#    'commune': 'ONVILLE',
#    'voyageurs': 'O',
#    'code_uic': '87192435',
#    'geo_shape': {'coordinates': [5.978985724179793, 49.01320943603552],
#     'type': 'Point'},
#    'fret': 'N',
#    'libelle': 'Onville',
#    'pk': '066+022',
#    'idgaia': 'e1aa71a0-19bf-11e5-a6ff-01fc64e0362d',
#    'departemen': 'MEURTHE-ET-MOSELLE',
#    'rg_troncon': 1,
#    'x_l93': 917870.6154000014,
#    'x_wgs84': 5.978985724179793,
#    'code_ligne': '095000',
#    'c_geo': [49.013209436990586, 5.978985724179793],
#    'geo_point_2d': [49.01320943603552, 5.978985724179793],
#    'y_wgs84': 49.013209436990586},
#   'geometry': {'type': 'Point',
#    'coordinates': [5.978985724179793, 49.013209436990586]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  'nérac': {'datasetid': 'liste-des-gares',
#   'recordid': 'c4e94691340d196bbb1dfa76ee25a296afc238de',
#   'fields': {'idreseau': 5754,
#    'y_l93': 6340533.662799999,
#    'commune': 'NÉRAC',
#    'voyageurs': 'N',
#    'code_uic': '87586735',
#    'geo_shape': {'coordinates': [0.335501463381547, 44.13143491210546],
#     'type': 'Point'},
#    'fret': 'O',
#    'libelle': 'Nérac',
#    'pk': '134+572',
#    'idgaia': 'd986399e-6667-11e3-89ff-01f464e0362d',
#    'departemen': 'LOT-ET-GARONNE',
#    'rg_troncon': 1,
#    'x_l93': 486823.9548000023,
#    'x_wgs84': 0.335501463381548,
#    'code_ligne': '643000',
#    'c_geo': [44.13143491307024, 0.33550146338154807],
#    'geo_point_2d': [44.13143491210546, 0.3355014633815468],
#    'y_wgs84': 44.13143491307024},
#   'geometry': {'type': 'Point',
#    'coordinates': [0.33550146338154807, 44.13143491307024]},
#   'record_timestamp': '2022-03-18T16:33:05.662+01:00'},
#  ...}

# %%
stations.keys()
# Out:
# dict_keys(['roubaix wattrelos', 'hellemmes', 'rivarennes', 'rothau', 'is sur tille', 'dordives', 'jardres', 'donchery', 'st germain st rémy', 'le douhet écoyeux', 'la brigue', 'belleville', 'commentry', 'hesdin', 'port ste marie', 'marne la vallée chessy', 'dijon ville', 'frévin capelle', 'villars les dombes', 'la bohalle', 'albias', 'mont sur meurthe', 'nurieux', 'ponthierry pringy', 'capdenac', 'tarbes', 'lathus', 'thann st jacques', 'sérézin', 'sarreguemines', 'chaville rive gauche', 'le pouzin', 'noyon', 'pignans', 'bossey veyrier', 'nogent le rotrou', 'marseille en beauvaisis', 'rezé pont rousseau', 'rougebarre', 'chabenet', 'langeais', 'metz ville', 'lamballe', 'labarthe avezac', 'viry châtillon', 'dompierre sept fons', 'vorey', 'aéroport charles de gaulle 2 tgv', 'ronchin', 'teting', 'st brieuc', 'montreux vieux', 'chissay en touraine', 'port fluvial de chalon sur saône', 'marseille st charles', 'st pierre le moûtier', 'cergy préfecture', 'amplepuis', 'coudekerque branche', 'égletons', 'corbeil essonnes', 'cercy la tour', 'le pouliguen', 'valergues lansargues', 'foix', 'tergnier', 'figeac', 'bazoches', 'nantiat', 'boran sur oise', 'le dramont', 'marmande', 'arras', 'lancerf', 'livron', 'fegersheim lipsheim', 'villefranche de lauragais', 'plestan', 'hombourg haut', 'villiers neauphle pontchartrain', 'bolbec nointot', 'fresnoy le grand', 'sélestat', 'monthois', 'pont remy', 'béthune rivage', 'niort', 'lunery', 'jonchery sur vesle', 'reims', 'fos mole central', 'bedous', 'bénestroff', 'haussmann st lazare', 'la méaugon', 'parthenay', 'grasse', 'le grau du roi', 'roumazières loubert', 'la levade', 'breuillet village', 'avignon centre', 'versailles chantiers', 'st vincent le château', 'castelsarrasin', 'cavaillon', 'ceyzériat', 'entressen', 'bellignat', 'pagny sur moselle', 'ranspach', 'st varent', 'neuville université', 'gondrecourt le château', 'lézignan la cèbe', 'lourches', 'mionnay', 'la brohinière', 'vaulry', 'mâlain', 'val de fontenay', 'gardanne', 'soissons', 'st hilaire au temple', 'raves ban de laveline', 'mantes la jolie', 'dole', 'vendenheim', 'lavoûte sur loire', 'gujan mestras', 'st quentin en yvelines', 'les eyzies', 'ste pazanne', 'plerguer', 'neuillé pont pierre', 'franois', 'st dizier', 'maresquel', 'grand bourg', 'vendeuvre jort', 'martres tolosane', 'hargicourt pierrepont', 'gien', 'bitschwiller (haut rhin)', 'wallers', 'alet les bains', 'reichstett', 'douai', 'gisors', 'maisse', 'peyrilhac st jouvent', 'paris gare de lyon', 'noisy le roi', 'st victor thizy', 'les cauquillous', 'les deux jumeaux', 'frouard', 'châteaubriant tram train', 'st andré de corcy', 'revin', 'eurville bienville', 'malesherbes', 'artenay', 'clonas', 'suippes', 'rennes', 'courcay tauxigny', 'st léger sur dheune', 'chantenay', 'ermont eaubonne', 'bourron marlotte grez', 'capvern', 'dangé', 'dégagnac', 'remiremont', 'loulay', 'st julien en genevois', 'ermont eaubonne (psl)', 'st pol de léon', 'crouy sur ourcq', 'yvetot', 'marignac st béat', 'melun', 'la garenne colombes', 'fère champenoise', 'montbartier', 'villennes sur seine', 'cassel', 'sanry sur nied', 'docelles cheniménil', 'tanus', 'sèvres rive gauche', 'haguenau', 'le buisson', 'la ricamarie', 'magenta', 'xeuilley', 'lozanne', 'la motte ste rosseline', 'seurre', 'la chapelle sur loire', 'nîmes pont du gard', 'couiza montazels', 'mehun sur yèvre', 'le perray', 'saverdun', 'vernaison', 'cavignac', 'sarralbe', 'denain', 'st sébastien', 'merrey', 'montereau', 'lérouville', "st martin d'étampes", 'bar le duc', 'puybrun', 'oissel', 'nuits sous ravières', 'goxwiller', 'la chaussée st victor', 'mommenheim', 'barsac', 'sillery', 'chapeauroux', 'aytré plage', 'st victor', 'cahors', "st rambert d'albon", 'russ hersbach', 'sorgues châteauneuf du pape', 'connantre', 'collioure', 'empalot', 'menton garavan', 'le monastier', 'douzillac', 'gresswiller', 'blainville damelevières', 'dannes camiers', 'valmondois', 'toul', 'jessains', "dijon porte d'ouche perrigny", 'guillaucourt', 'laval', 'rodez' ...

# %%
df['Gare de départ'].value_counts()
# Out:
# PARIS LYON                        1020
# PARIS MONTPARNASSE                 816
# LYON PART DIEU                     306
# MARSEILLE ST CHARLES               254
# PARIS NORD                         204
# PARIS EST                          204
# LILLE                              153
# RENNES                             114
# NANTES                             114
# BORDEAUX ST JEAN                   113
# MARNE LA VALLEE                    102
# MONTPELLIER                        102
# STRASBOURG                         102
# TOURCOING                           62
# MACON LOCHE                         51
# BREST                               51
# LE CREUSOT MONTCEAU MONTCHANIN      51
# ST PIERRE DES CORPS                 51
# VALENCE ALIXAN TGV                  51
# METZ                                51
# ANGERS SAINT LAUD                   51
# REIMS                               51
# NANCY                               51
# MULHOUSE VILLE                      51
# AIX EN PROVENCE TGV                 51
# ST MALO                             51
# DIJON VILLE                         51
# NICE VILLE                          51
# POITIERS                            51
# LE MANS                             51
# GRENOBLE                            51
# BELLEGARDE (AIN)                    51
# ARRAS                               51
# TOULON                              51
# NIMES                               51
# DUNKERQUE                           51
# TOURS                               51
# DOUAI                               51
# LAVAL                               51
# AVIGNON TGV                         51
# ANGOULEME                           51
# BESANCON FRANCHE COMTE TGV          51
# ANNECY                              51
# LA ROCHELLE VILLE                   51
# CHAMBERY CHALLES LES EAUX           51
# VANNES                              51
# PERPIGNAN                           51
# TOULOUSE MATABIAU                   51
# QUIMPER                             51
# SAINT ETIENNE CHATEAUCREUX          51
# PARIS VAUGIRARD                     36
# Name: Gare de départ, dtype: int64

# %%
[k for k in df['Gare de départ'].value_counts().keys() if k.lower() not in stations]
# Out:
# ['PARIS LYON',
#  'LILLE',
#  'MARNE LA VALLEE',
#  'MONTPELLIER',
#  'STRASBOURG',
#  'MACON LOCHE',
#  'VALENCE ALIXAN TGV',
#  'METZ',
#  'ANGERS SAINT LAUD',
#  'NANCY',
#  'BELLEGARDE (AIN)',
#  'NIMES',
#  'ANGOULEME',
#  'BESANCON FRANCHE COMTE TGV',
#  'CHAMBERY CHALLES LES EAUX',
#  'SAINT ETIENNE CHATEAUCREUX']

# %%
REMAP = {
    'PARIS LYON': 'paris gare de lyon souterrain',
    'LILLE': 'lille champ de mars',
    'MONTPELLIER': 'montpellier st roch',
    'MARNE LA VALLEE': 'marne la vallée chessy',
    'STRASBOURG': 'strasbourg neudorf',
    'ANGERS SAINT LAUD': 'angers st laud',
    'SAINT ETIENNE CHATEAUCREUX': 'st étienne châteaucreux',
    'BESANCON FRANCHE COMTE TGV': 'besançon franche comté tgv',
    'VALENCE ALIXAN TGV': 'valence tgv',
    'NIMES': 'nîmes',
    'BELLEGARDE (AIN)': 'bellegarde',
    'ANGOULEME': 'angoulême',
    'NANCY': 'nancy ville',
    'CHAMBERY CHALLES LES EAUX': 'chambéry challes les eaux',
    'METZ': 'metz ville',
    'MACON LOCHE': 'mâcon loché tgv',
}
def remap(g):
    return REMAP[g] if g in REMAP else g.lower().replace('-', ' ')

# %%
[k for k in df['Gare de départ'].value_counts().keys() if remap(k) not in stations]
# Out:
# []

# %%
df
# Out:
#          Date   Service              Gare de départ      Gare d'arrivée  \
# 0     2018-01  National           ANGERS SAINT LAUD  PARIS MONTPARNASSE
# 1     2018-01  National           LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 2     2018-01  National          PARIS MONTPARNASSE    BORDEAUX ST JEAN
# 3     2018-01  National          PARIS MONTPARNASSE               LAVAL
# 4     2018-01  National          PARIS MONTPARNASSE              NANTES
# ...       ...       ...                         ...                 ...
# 6319  2022-03  National                  PARIS NORD               DOUAI
# 6320  2022-03  National                    POITIERS  PARIS MONTPARNASSE
# 6321  2022-03  National                      RENNES      LYON PART DIEU
# 6322  2022-03  National  SAINT ETIENNE CHATEAUCREUX          PARIS LYON
# 6323  2022-03  National                  STRASBOURG              NANTES
#
#       Durée moyenne du trajet  Nombre de circulations prévues  \
# 0                          91                             393
# 1                         165                             222
# 2                         143                             775
# 3                          84                             217
# 4                         124                             508
# ...                       ...                             ...
# 6319                       70                             140
# 6320                       99                             476
# 6321                      234                              75
# 6322                      168                             115
# 6323                      315                              58
#
#       Nombre de trains annulés  Commentaire annulations  \
# 0                            2                      NaN
# 1                            0                      NaN
# 2                            7                      NaN
# 3                            0                      NaN
# 4                            3                      NaN
# ...                        ...                      ...
# 6319                         0                      NaN
# 6320                         8                      NaN
# 6321                         0                      NaN
# 6322                         0                      NaN
# 6323                         1                      NaN
#
#       Nombre de trains en retard au départ  \
# 0                                      204
# 1                                        8
# 2                                      148
# 3                                       32
# 4                                       71
# ...                                    ...
# 6319                                    10
# 6320                                   162
# 6321                                    20
# 6322                                    23
# 6323                                     7
#
#       Retard moyen des trains en retard au départ  ...  \
# 0                                        6.400490  ...
# 1                                        2.875000  ...
# 2                                        9.377815  ...
# 3                                       11.609375  ...
# 4                                        7.235211  ...
# ...                                           ...  ...
# 6319                                    23.931667  ...
# 6320                                     6.578498  ...
# 6321                                     7.215000  ...
# 6322                                     2.039130  ...
# 6323                                     1.792857  ...
#
#       Nombre trains en retard > 15min  \
# 0                                  35
# 1                                  22
# 2                                  45
# 3                                  16
# 4                                  39
# ...                               ...
# 6319                                8
# 6320                               38
# 6321                                5
# 6322                                5
# 6323                                2
#
#       Retard moyen trains en retard > 15 (si liaison concurrencée par vol)  \
# 0                                              6.072847
# 1                                              5.696096
# 2                                              2.546962
# 3                                              5.822811
# 4                                              5.292211
# ...                                                 ...
# 6319                                          45.275000
# 6320                                          31.825000
# 6321                                          50.123333
# 6322                                          33.846667
# 6323                                          35.875000
#
#       Nombre trains en retard > 30min  Nombre trains en retard > 60min  \
# 0                                  19                                4
# 1                                   5                                0
# 2                                  21                                4
# 3                                   5                                2
# 4                                  18                                8
# ...                               ...                              ...
# 6319                                5                                2
# 6320                               15                                3
# 6321                                3                                2
# 6322                                2                                1
# 6323                                1                                0
#
#       Prct retard pour causes externes Prct retard pour cause infrastructure  \
# 0                            37.500000                             37.500000
# 1                            15.384615                             30.769231
# 2                            21.666667                             25.000000
# 3                            24.242424                             54.545455
# 4                            33.333333                             22.222222
# ...                                ...                                   ...
# 6319                         25.000000                             16.666667
# 6320                         17.187500                             37.500000
# 6321                         20.000000                              0.000000
# 6322                         12.500000                             12.500000
# 6323                         50.000000                              0.000000
#
#       Prct retard pour cause gestion trafic  \
# 0                                  8.928571
# 1                                 38.461538
# 2                                 11.666667
# 3                                  3.030303
# 4                                 16.666667
# ...                                     ...
# 6319                              16.666667
# 6320                              12.500000
# 6321                              40.000000
# 6322                              12.500000
# 6323                               0.000000
#
#       Prct retard pour cause matériel roulant  \
# 0                                    5.357143
# 1                                   11.538462
# 2                                   40.000000
# 3                                   12.121212
# 4                                   20.370370
# ...                                       ...
# 6319                                 8.333333
# 6320                                14.062500
# 6321                                 0.000000
# 6322                                50.000000
# 6323                                50.000000
#
#       Prct retard pour cause gestion en gare et réutilisation de matériel  \
# 0                                              8.928571
# 1                                              3.846154
# 2                                              1.666667
# 3                                              3.030303
# 4                                              5.555556
# ...                                                 ...
# 6319                                           8.333333
# 6320                                           7.812500
# 6321                                           0.000000
# 6322                                           0.000000
# 6323                                           0.000000
#
#       Prct retard pour cause prise en compte voyageurs (affluence, gestions PSH, correspondances)
# 0                                              1.785714
# 1                                              0.000000
# 2                                              0.000000
# 3                                              3.030303
# 4                                              1.851852
# ...                                                 ...
# 6319                                          25.000000
# 6320                                          10.937500
# 6321                                          40.000000
# 6322                                          12.500000
# 6323                                           0.000000
#
# [5538 rows x 26 columns]

# %%
# df['start_lat'] = df['Gare de départ'].apply(lambda g: stations[remap(g)]['fields']['c_geo'][0])
# df['start_lon'] = df['Gare de départ'].apply(lambda g: stations[remap(g)]['fields']['c_geo'][1])
# df['end_lat'] = df['Gare d\'arrivée'].apply(lambda g: stations[remap(g)]['fields']['c_geo'][0])
# df['end_lon'] = df['Gare d\'arrivée'].apply(lambda g: stations[remap(g)]['fields']['c_geo'][1])

# %%
def __grr(r):
    a = r['Gare de départ']
    b = r['Gare d\'arrivée']
    return f'{a}→{b}'
df['connid'] = df.apply(lambda r: __grr(r), axis=1)
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
[r['connid'] for (i, r) in df.groupby('connid', as_index=False).first().iterrows()]
# Out:
# ['AIX EN PROVENCE TGV→PARIS LYON',
#  'ANGERS SAINT LAUD→PARIS MONTPARNASSE',
#  'ANGOULEME→PARIS MONTPARNASSE',
#  'ANNECY→PARIS LYON',
#  'ARRAS→PARIS NORD',
#  'AVIGNON TGV→PARIS LYON',
#  'BELLEGARDE (AIN)→PARIS LYON',
#  'BESANCON FRANCHE COMTE TGV→PARIS LYON',
#  'BORDEAUX ST JEAN→PARIS MONTPARNASSE',
#  'BORDEAUX ST JEAN→PARIS VAUGIRARD',
#  'BORDEAUX ST JEAN→TOURCOING',
#  'BREST→PARIS MONTPARNASSE',
#  'CHAMBERY CHALLES LES EAUX→PARIS LYON',
#  'DIJON VILLE→PARIS LYON',
#  'DOUAI→PARIS NORD',
#  'DUNKERQUE→PARIS NORD',
#  'GRENOBLE→PARIS LYON',
#  'LA ROCHELLE VILLE→PARIS MONTPARNASSE',
#  'LAVAL→PARIS MONTPARNASSE',
#  'LE CREUSOT MONTCEAU MONTCHANIN→PARIS LYON',
#  'LE MANS→PARIS MONTPARNASSE',
#  'LILLE→LYON PART DIEU',
#  'LILLE→MARSEILLE ST CHARLES',
#  'LILLE→PARIS NORD',
#  'LYON PART DIEU→LILLE',
#  'LYON PART DIEU→MARNE LA VALLEE',
#  'LYON PART DIEU→MARSEILLE ST CHARLES',
#  'LYON PART DIEU→MONTPELLIER',
#  'LYON PART DIEU→PARIS LYON',
#  'LYON PART DIEU→RENNES',
#  'MACON LOCHE→PARIS LYON',
#  'MARNE LA VALLEE→LYON PART DIEU',
#  'MARNE LA VALLEE→MARSEILLE ST CHARLES',
#  'MARSEILLE ST CHARLES→LILLE',
#  'MARSEILLE ST CHARLES→LYON PART DIEU',
#  'MARSEILLE ST CHARLES→MARNE LA VALLEE',
#  'MARSEILLE ST CHARLES→PARIS LYON',
#  'MARSEILLE ST CHARLES→TOURCOING',
#  'METZ→PARIS EST',
#  'MONTPELLIER→LYON PART DIEU',
#  'MONTPELLIER→PARIS LYON',
#  'MULHOUSE VILLE→PARIS LYON',
#  'NANCY→PARIS EST',
#  'NANTES→PARIS MONTPARNASSE',
#  'NANTES→PARIS VAUGIRARD',
#  'NANTES→STRASBOURG',
#  'NICE VILLE→PARIS LYON',
#  'NIMES→PARIS LYON',
#  'PARIS EST→METZ',
#  'PARIS EST→NANCY',
#  'PARIS EST→REIMS',
#  'PARIS EST→STRASBOURG',
#  'PARIS LYON→AIX EN PROVENCE TGV',
#  'PARIS LYON→ANNECY',
#  'PARIS LYON→AVIGNON TGV',
#  'PARIS LYON→BELLEGARDE (AIN)',
#  'PARIS LYON→BESANCON FRANCHE COMTE TGV',
#  'PARIS LYON→CHAMBERY CHALLES LES EAUX',
#  'PARIS LYON→DIJON VILLE',
#  'PARIS LYON→GRENOBLE',
#  'PARIS LYON→LE CREUSOT MONTCEAU MONTCHANIN',
#  'PARIS LYON→LYON PART DIEU',
#  'PARIS LYON→MACON LOCHE',
#  'PARIS LYON→MARSEILLE ST CHARLES',
#  'PARIS LYON→MONTPELLIER',
#  'PARIS LYON→MULHOUSE VILLE',
#  'PARIS LYON→NICE VILLE',
#  'PARIS LYON→NIMES',
#  'PARIS LYON→PERPIGNAN',
#  'PARIS LYON→SAINT ETIENNE CHATEAUCREUX',
#  'PARIS LYON→TOULON',
#  'PARIS LYON→VALENCE ALIXAN TGV',
#  'PARIS MONTPARNASSE→ANGERS SAINT LAUD',
#  'PARIS MONTPARNASSE→ANGOULEME',
#  'PARIS MONTPARNASSE→BORDEAUX ST JEAN',
#  'PARIS MONTPARNASSE→BREST',
#  'PARIS MONTPARNASSE→LA ROCHELLE VILLE',
#  'PARIS MONTPARNASSE→LAVAL',
#  'PARIS MONTPARNASSE→LE MANS',
#  'PARIS MONTPARNASSE→NANTES',
#  'PARIS MONTPARNASSE→POITIERS',
#  'PARIS MONTPARNASSE→QUIMPER',
#  'PARIS MONTPARNASSE→RENNES',
#  'PARIS MONTPARNASSE→ST MALO',
#  'PARIS MONTPARNASSE→ST PIERRE DES CORPS',
#  'PARIS MONTPARNASSE→TOULOUSE MATABIAU',
#  'PARIS MONTPARNASSE→TOURS',
#  'PARIS MONTPARNASSE→VANNES',
#  'PARIS NORD→ARRAS',
#  'PARIS NORD→DOUAI',
#  'PARIS NORD→DUNKERQUE',
#  'PARIS NORD→LILLE',
#  'PARIS VAUGIRARD→BORDEAUX ST JEAN',
#  'PARIS VAUGIRARD→NANTES',
#  'PARIS VAUGIRARD→RENNES',
#  'PERPIGNAN→PARIS LYON',
#  'POITIERS→PARIS MONTPARNASSE',
#  'QUIMPER→PARIS MONTPARNASSE',
#  'REIMS→PARIS EST',
#  'RENNES→LYON PART DIEU',
#  'RENNES→PARIS MONTPARNASSE',
#  'RENNES→PARIS VAUGIRARD',
#  'SAINT ETIENNE CHATEAUCREUX→PARIS LYON',
#  'ST MALO→PARIS MONTPARNASSE',
#  'ST PIERRE DES CORPS→PARIS MONTPARNASSE',
#  'STRASBOURG→NANTES',
#  'STRASBOURG→PARIS EST',
#  'TOULON→PARIS LYON',
#  'TOULOUSE MATABIAU→PARIS MONTPARNASSE',
#  'TOURCOING→BORDEAUX ST JEAN',
#  'TOURCOING→MARSEILLE ST CHARLES',
#  'TOURS→PARIS MONTPARNASSE',
#  'VALENCE ALIXAN TGV→PARIS LYON',
#  'VANNES→PARIS MONTPARNASSE']

# %%
def _gen_geopoly(r):
    c1 = np.array(stations[remap(r['Gare de départ'])]['fields']['geo_shape']['coordinates'])
    c2 = np.array(stations[remap(r['Gare d\'arrivée'])]['fields']['geo_shape']['coordinates'])
    diff = np.array([0.01, 0.01])
    return {
        "type": "Polygon",
        "coordinates": np.array([[c1, c1 + diff, c2 + diff, c2, c2 - diff, c1 - diff, c1]]).tolist()
    }
def _gen_geopolys():
    def mkf(r):
        return {
            "type": "Feature",
            "properties": {
                "connid": r['connid'],
            },
            "geometry": _gen_geopoly(r),
        }
    feats = [mkf(r) for (i, r) in df.groupby('connid', as_index=False).first().iterrows()]
    return {
        "type": "FeatureCollection",
        "features": feats,
    }
def _():
    with open("connpolys.geojson", "w") as f:
        json.dump(_gen_geopolys(), f)
_()

# %%
df
# Out:
#          Date   Service              Gare de départ      Gare d'arrivée  \
# 0     2018-01  National           ANGERS SAINT LAUD  PARIS MONTPARNASSE
# 1     2018-01  National           LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 2     2018-01  National          PARIS MONTPARNASSE    BORDEAUX ST JEAN
# 3     2018-01  National          PARIS MONTPARNASSE               LAVAL
# 4     2018-01  National          PARIS MONTPARNASSE              NANTES
# ...       ...       ...                         ...                 ...
# 6319  2022-03  National                  PARIS NORD               DOUAI
# 6320  2022-03  National                    POITIERS  PARIS MONTPARNASSE
# 6321  2022-03  National                      RENNES      LYON PART DIEU
# 6322  2022-03  National  SAINT ETIENNE CHATEAUCREUX          PARIS LYON
# 6323  2022-03  National                  STRASBOURG              NANTES
#
#       Durée moyenne du trajet  Nombre de circulations prévues  \
# 0                          91                             393
# 1                         165                             222
# 2                         143                             775
# 3                          84                             217
# 4                         124                             508
# ...                       ...                             ...
# 6319                       70                             140
# 6320                       99                             476
# 6321                      234                              75
# 6322                      168                             115
# 6323                      315                              58
#
#       Nombre de trains annulés  Commentaire annulations  \
# 0                            2                      NaN
# 1                            0                      NaN
# 2                            7                      NaN
# 3                            0                      NaN
# 4                            3                      NaN
# ...                        ...                      ...
# 6319                         0                      NaN
# 6320                         8                      NaN
# 6321                         0                      NaN
# 6322                         0                      NaN
# 6323                         1                      NaN
#
#       Nombre de trains en retard au départ  \
# 0                                      204
# 1                                        8
# 2                                      148
# 3                                       32
# 4                                       71
# ...                                    ...
# 6319                                    10
# 6320                                   162
# 6321                                    20
# 6322                                    23
# 6323                                     7
#
#       Retard moyen des trains en retard au départ  ...  \
# 0                                        6.400490  ...
# 1                                        2.875000  ...
# 2                                        9.377815  ...
# 3                                       11.609375  ...
# 4                                        7.235211  ...
# ...                                           ...  ...
# 6319                                    23.931667  ...
# 6320                                     6.578498  ...
# 6321                                     7.215000  ...
# 6322                                     2.039130  ...
# 6323                                     1.792857  ...
#
#       Retard moyen trains en retard > 15 (si liaison concurrencée par vol)  \
# 0                                              6.072847
# 1                                              5.696096
# 2                                              2.546962
# 3                                              5.822811
# 4                                              5.292211
# ...                                                 ...
# 6319                                          45.275000
# 6320                                          31.825000
# 6321                                          50.123333
# 6322                                          33.846667
# 6323                                          35.875000
#
#       Nombre trains en retard > 30min  Nombre trains en retard > 60min  \
# 0                                  19                                4
# 1                                   5                                0
# 2                                  21                                4
# 3                                   5                                2
# 4                                  18                                8
# ...                               ...                              ...
# 6319                                5                                2
# 6320                               15                                3
# 6321                                3                                2
# 6322                                2                                1
# 6323                                1                                0
#
#       Prct retard pour causes externes  Prct retard pour cause infrastructure  \
# 0                            37.500000                              37.500000
# 1                            15.384615                              30.769231
# 2                            21.666667                              25.000000
# 3                            24.242424                              54.545455
# 4                            33.333333                              22.222222
# ...                                ...                                    ...
# 6319                         25.000000                              16.666667
# 6320                         17.187500                              37.500000
# 6321                         20.000000                               0.000000
# 6322                         12.500000                              12.500000
# 6323                         50.000000                               0.000000
#
#      Prct retard pour cause gestion trafic  \
# 0                                 8.928571
# 1                                38.461538
# 2                                11.666667
# 3                                 3.030303
# 4                                16.666667
# ...                                    ...
# 6319                             16.666667
# 6320                             12.500000
# 6321                             40.000000
# 6322                             12.500000
# 6323                              0.000000
#
#       Prct retard pour cause matériel roulant  \
# 0                                    5.357143
# 1                                   11.538462
# 2                                   40.000000
# 3                                   12.121212
# 4                                   20.370370
# ...                                       ...
# 6319                                 8.333333
# 6320                                14.062500
# 6321                                 0.000000
# 6322                                50.000000
# 6323                                50.000000
#
#       Prct retard pour cause gestion en gare et réutilisation de matériel  \
# 0                                              8.928571
# 1                                              3.846154
# 2                                              1.666667
# 3                                              3.030303
# 4                                              5.555556
# ...                                                 ...
# 6319                                           8.333333
# 6320                                           7.812500
# 6321                                           0.000000
# 6322                                           0.000000
# 6323                                           0.000000
#
#       Prct retard pour cause prise en compte voyageurs (affluence, gestions PSH, correspondances)  \
# 0                                              1.785714
# 1                                              0.000000
# 2                                              0.000000
# 3                                              3.030303
# 4                                              1.851852
# ...                                                 ...
# 6319                                          25.000000
# 6320                                          10.937500
# 6321                                          40.000000
# 6322                                          12.500000
# 6323                                           0.000000
#
#                                      connid
# 0      ANGERS SAINT LAUD→PARIS MONTPARNASSE
# 1      LA ROCHELLE VILLE→PARIS MONTPARNASSE
# 2       PARIS MONTPARNASSE→BORDEAUX ST JEAN
# 3                  PARIS MONTPARNASSE→LAVAL
# 4                 PARIS MONTPARNASSE→NANTES
# ...                                     ...
# 6319                       PARIS NORD→DOUAI
# 6320            POITIERS→PARIS MONTPARNASSE
# 6321                  RENNES→LYON PART DIEU
# 6322  SAINT ETIENNE CHATEAUCREUX→PARIS LYON
# 6323                      STRASBOURG→NANTES
#
# [5538 rows x 27 columns]

# %%
df.to_pickle("df.pkl")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7e46125d-adbf-4cf0-96eb-66e11deefb3b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
