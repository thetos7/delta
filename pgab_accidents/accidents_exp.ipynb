# %% [markdown]
# # Accidents analysis and experimentation notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
# %matplotlib inline

# %%
accidents = pd.read_csv('data/immatriculation-2018.csv', sep=';')
accidents
# Out:
#        Unnamed: 0 Id_accident Lettre Conventionnelle Véhicule  Année  \
# 0               0     640 421                               A   2018
# 1               1     640 422                               A   2018
# 2               2     640 422                               B   2018
# 3               3     640 423                               A   2018
# 4               4     640 423                               B   2018
# ...           ...         ...                             ...    ...
# 94579       94579     698 769                               D   2018
# 94580       94580     698 770                               A   2018
# 94581       94581     698 771                               A   2018
# 94582       94582     698 771                               B   2018
# 94583       94583     698 772                               A   2018
#
#       Lieu Admin Actuel - Territoire Nom    Type Accident - Libellé  \
# 0                              Métropole            Accident mortel
# ...

# %%
lieux = pd.read_csv('data/lieux-2018.csv', sep=',')
lieux
# Out:
# /tmp/ipykernel_3498/2820579120.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   lieux = pd.read_csv('data/lieux-2018.csv', sep=',')
#        Unnamed: 0       Num_Acc  catr voie  v1   v2  circ  nbv   pr    pr1  \
# 0               0  201800000001     3   41 NaN    C   2.0  2.0  NaN    NaN
# 1               1  201800000002     4   41 NaN    D   2.0  2.0  NaN    NaN
# 2               2  201800000003     3   39 NaN    D   2.0  2.0  NaN    NaN
# 3               3  201800000004     3   39 NaN  NaN   2.0  2.0  NaN    NaN
# 4               4  201800000005     4  NaN NaN  NaN   1.0  1.0  NaN    NaN
# ...           ...           ...   ...  ...  ..  ...   ...  ...  ...    ...
# 57778       57778  201800057779     4  NaN NaN  NaN   1.0  1.0  0.0    0.0
# 57779       57779  201800057780     2  2.0 NaN  NaN   0.0  2.0  0.0    0.0
# 57780       57780  201800057781     2  1.0 NaN  NaN   2.0  2.0  0.0    0.0
# ...

# %%
usagers = pd.read_csv('data/usagers-2018.csv')
usagers
# Out:
#         Unnamed: 0       Num_Acc  place  catu  grav  sexe  trajet  secu  locp  \
# 0                0  201800000001    1.0     1     3     1     0.0  11.0   0.0
# 1                1  201800000001    1.0     1     1     1     5.0  11.0   0.0
# 2                2  201800000002    1.0     1     1     1     0.0  11.0   0.0
# 3                3  201800000002    NaN     3     4     1     0.0   2.0   2.0
# 4                4  201800000003    1.0     1     3     1     5.0  21.0   0.0
# ...            ...           ...    ...   ...   ...   ...     ...   ...   ...
# 130164      130164  201800057781    NaN     3     4     1     9.0   3.0   4.0
# 130165      130165  201800057782    1.0     1     4     2     9.0  11.0   NaN
# 130166      130166  201800057782    1.0     1     4     1     9.0  21.0   NaN
# 130167      130167  201800057783    1.0     1     4     1     9.0  11.0   NaN
# 130168      130168  201800057783    1.0     1     4     2     9.0  11.0   NaN
#
# ...

# %%
vehicules = pd.read_csv('data/vehicules-2018.csv')
vehicules
# Out:
#        Unnamed: 0       Num_Acc  senc  catv  occutc  obs  obsm  choc  manv  \
# 0               0  201800000001   0.0     7       0  0.0   2.0   3.0   1.0
# 1               1  201800000001   0.0     7       0  0.0   2.0   2.0  15.0
# 2               2  201800000002   0.0     7       0  0.0   1.0   0.0   1.0
# 3               3  201800000003   0.0    33       0  1.0   2.0   1.0   1.0
# 4               4  201800000003   0.0     7       0  0.0   2.0   8.0  15.0
# ...           ...           ...   ...   ...     ...  ...   ...   ...   ...
# 98871       98871  201800057781   1.0     7       0  0.0   1.0   7.0  19.0
# 98872       98872  201800057782   1.0     7       0  0.0   2.0   1.0   0.0
# 98873       98873  201800057782   2.0    31       0  0.0   2.0   1.0   0.0
# 98874       98874  201800057783   2.0    10       0  0.0   2.0   1.0   0.0
# 98875       98875  201800057783   1.0    10       0  0.0   2.0   0.0   0.0
#
#       num_veh
# 0         B01
# 1         A01
# 2         A01
# ...

# %%
caracs = pd.read_csv('data/caracteristiques-2018.csv', encoding='iso-8859-1')
caracs
# Out:
#        Unnamed: 0       Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  \
# 0               0  201800000001  18     1    24  1505    1    1    4  1.0
# 1               1  201800000002  18     2    12  1015    1    2    7  7.0
# 2               2  201800000003  18     3     4  1135    1    2    3  1.0
# 3               3  201800000004  18     5     5  1735    1    2    1  7.0
# 4               4  201800000005  18     6    26  1605    1    2    1  1.0
# ...           ...           ...  ..   ...   ...   ...  ...  ...  ...  ...
# 57778       57778  201800057779  18    12    15  1050    1    2    1  1.0
# 57779       57779  201800057780  18    12    16   610    2    2    1  1.0
# 57780       57780  201800057781  18    12    22  2150    5    2    1  1.0
# 57781       57781  201800057782  18    12    23  1945    5    2    1  1.0
# 57782       57782  201800057783  18    12    28  1425    1    2    1  1.0
#
#        col  com                         adr gps        lat       long  dep
# ...

# %%
positions = caracs[['lat', 'long']].dropna() / 100000
positions
# Out:
#             lat      long
# 0      50.55737   2.94992
# 1      50.52936   2.93151
# 2      50.51243   2.91714
# 3      50.51974   2.89123
# 4      50.51607   2.90605
# ...         ...       ...
# 57778  12.80217  45.21356
# 57779  12.78120  45.23436
# 57780  12.76930  45.22409
# 57781  12.78622  45.22036
# 57782  12.78943  45.22408
#
# [55960 rows x 2 columns]

# %%
france_pos=[46.7111,1.7191]
france_zoom=6

# %%
from folium import plugins
m = folium.Map(location=france_pos, zoom_start=france_zoom)
m.add_child(plugins.HeatMap(positions, radius=7))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m = folium.Map(location=france_pos, zoom_start=france_zoom)
positions.apply(lambda row: folium.Marker(location=(row['lat'],row['long'])).add_to(m), axis=1)
m
