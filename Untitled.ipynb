# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format='retina'

# %%
PATH_RESOURCES = Path("TBGT_population_vs_train_speed/data")

# %%
train_df = pd.read_csv(PATH_RESOURCES / "meilleurs-temps-des-parcours-des-trains.csv", sep=";")
train_df.sort_values("Année", inplace=True)
train_df
# Out:
#                 Relations  Année  Temps estimé en minutes
# 0           PARIS - ARRAS   1920                      NaN
# 29      LYON - STRASBOURG   1920                      NaN
# 30       PARIS - BOULOGNE   1920                      NaN
# 32    PARIS - LA ROCHELLE   1920                      NaN
# 34         PARIS - AMIENS   1920                      NaN
# ...                   ...    ...                      ...
# 3947     PARIS - TOULOUSE   2019                    245.0
# 3948     PARIS - POITIERS   2019                     76.0
# 3951        PARIS - TOURS   2019                     64.0
# 3955   PARIS - ST ETIENNE   2019                    168.0
# 3998       PARIS - RENNES   2019                     85.0
#
# [3999 rows x 3 columns]

# %%
len(pd.unique(train_df["Relations"]))
# Out:
# 43

# %%
train_df.set_index("Relations", inplace=True)
train_df.set_index("Année", append=True)
# Out:
#                            Temps estimé en minutes
# Relations           Année
# PARIS - ARRAS       1920                       NaN
# LYON - STRASBOURG   1920                       NaN
# PARIS - BOULOGNE    1920                       NaN
# PARIS - LA ROCHELLE 1920                       NaN
# PARIS - AMIENS      1920                       NaN
# ...                                            ...
# PARIS - TOULOUSE    2019                     245.0
# PARIS - POITIERS    2019                      76.0
# PARIS - TOURS       2019                      64.0
# PARIS - ST ETIENNE  2019                     168.0
# PARIS - RENNES      2019                      85.0
#
# [3999 rows x 1 columns]

# %%
train_df.loc["PARIS - ARRAS"]
# Out:
#                Année  Temps estimé en minutes
# Relations
# PARIS - ARRAS   1920                      NaN
# PARIS - ARRAS   1928                      NaN
# PARIS - ARRAS   1929                      NaN
# PARIS - ARRAS   1930                      NaN
# PARIS - ARRAS   1931                      NaN
# ...              ...                      ...
# PARIS - ARRAS   2015                     49.0
# PARIS - ARRAS   2016                     49.0
# PARIS - ARRAS   2017                     49.0
# PARIS - ARRAS   2018                     48.0
# PARIS - ARRAS   2019                     48.0
#
# [93 rows x 2 columns]

# %%
my_line = "PARIS - BAYONNE"
my_line_df = train_df[train_df["Relations"] == my_line]
my_line_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Relations'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 my_line = "PARIS - BAYONNE"
# ----> 2 my_line_df = train_df[train_df["Relations"] == my_line]
#       3 my_line_df
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3506, in DataFrame.__getitem__(self, key)
#    3504 if self.columns.nlevels > 1:
#    3505     return self._getitem_multilevel(key)
# -> 3506 indexer = self.columns.get_loc(key)
#    3507 if is_integer(indexer):
#    3508     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Relations'

# %%
plt.plot(my_line_df["Année"], my_line_df["Temps estimé en minutes"].tolist())

# %%
na_size = train_df[train_df["Temps estimé en minutes"].isna()].groupby("Année").size()

plt.rcParams["figure.figsize"] = (20,5)
plt.bar(na_size.index, na_size.tolist())

# %%
train_nb = train_df.groupby("Année").size()
plt.bar(train_nb.index, )

# %%
base-pop-historiques-1876-2019.xlsx
