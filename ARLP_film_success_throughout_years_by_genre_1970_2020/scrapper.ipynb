# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import re
from rotten_tomatoes_scraper.rt_scraper import MovieScraper

# %%
url = ('http://www.imdb.com/search/title?count={batch_size}&view=simple&title_type=feature&release_date={year}&start={start}&countries=us')

headers = {
    'Accept-Language': 'en-US',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

# %%
def get_movies(year, start = 1, batch_size = 50):
    '''Get list of movies released in <year>.'''
    movies_html = requests.get(url.format(batch_size=batch_size, start=start, year=year), headers=headers, timeout=15).content
    soup = BeautifulSoup(movies_html, 'html.parser')
    movies = soup.find_all('a', href=re.compile('adv_li_tt'))

    return [('http://www.imdb.com' + m['href'], m.text) for m in movies]

# %%
def get_all_movies(year):
  batch_size = 250
  all_movies = []
  i = 0
  while True:
    movies = get_movies(year, batch_size * i + 1, batch_size)
    all_movies += movies
    i += 1
    if len(movies) == 0:
      break
    print(i * batch_size + 1)
    time.sleep(1)
  return all_movies

# %%
def go_to_movie(url):
    '''Get IMDb page of a movie.'''
    movie_html = requests.get(url, headers=headers).content

    return movie_html

# %%
def get_country(soup):
    wrapper = soup.find('span', text='Country of origin')
    if not wrapper:
        wrapper = soup.find('span', text='Countries of origin')

    try:
        wrapper = wrapper.findNext('div')
    except AttributeError:
        return []

    try:
        countries = []
        wrappers = wrapper.find_all('a')
        for e in wrappers:
          countries.append(e.text)
        return countries
    except AttributeError:
        return []

# %%
def get_genre(soup):
    try:
      wrapper = soup.find('span', text="Genres").find_next('div')
      wrappers = wrapper.find_all('a')
      genres = []
      for e in wrappers:
        genres.append(e.text)
      return genres
    except:
      try:
        wrapper = soup.find('span', text="Genre").find_next('div')
        return [wrapper.find('a').text]
      except:
        return []

# %%
def get_votes(soup):
    try:
        wrapper = soup.find('div', {'class': re.compile('sc-7ab21ed2-3 dPVcnq')}).text
    except AttributeError:
        return 0
    
    if 'K' in wrapper:
        votes = float(wrapper.replace('K', '')) * 1000
    elif 'M' in wrapper:
        votes = float(wrapper.replace('M', '')) * 1000000
    else:
        votes = float(wrapper)
    return votes

# %%
def get_money(soup, type):
    try:
        wrapper = soup.find('span', text=type).findNext('div')
        money = wrapper.find('span').text
        
        return money
    except AttributeError:
        return None

# %%
def get_company(soup):
    wrapper = soup.find('a', text='Production companies')

    if not wrapper:
        wrapper = soup.find('a', text='Production company')

    companies = []
    try:
        companies_wrapper = wrapper.findNext('div').find_all('a')
        for e in companies_wrapper:
          companies.append(e.text)
    except AttributeError:
        return []

    return companies

# %%
def get_release_date(soup):
    try:
        wrapper = soup.find('a', text='Release date').findNext('div')
        release_date = wrapper.find('a').text
    except AttributeError:
        return None

    for i in range(len(release_date)):
      if release_date[i] == '(':
        release_date = release_date[:i]
        break
    return pd.to_datetime(release_date)

# %%
def get_runtime(soup):
    try:
        wrapper = soup.find('span', text='Runtime').findNext('div')
    except AttributeError:
        return None
    runtime = wrapper.text.split()

    if len(runtime) == 4:
        hours = int(runtime[0])
        minutes = int(runtime[2])        
        return hours * 60 + minutes
    elif runtime[1] == "minutes":
        return int(runtime[0])
    else:
        return int(runtime[0]) * 60

# %%
def get_star(soup):
  stars = []
  try:
    wrappers = soup.find_all('a', {'class': re.compile('sc-11eed019-1 jFeBIw')})
    for wrapper in wrappers:
      stars.append(wrapper.text)
    return stars
  except:
    return stars

# %%
def get_writer(soup):
    try:
        writer = soup.find('a', {'href': re.compile('tt_ov_wr')}).text
    except AttributeError:
        return []
    
    if writer == 'Writers':
        try:
            wrapper = soup.find('a', text=writer).findNext('div')
        except AttributeError:
            wrapper = soup.find('span', text=writer).findNext('div') 
        wrappers = wrapper.find_all('a')

        writers = []
        for e in wrappers:
          writers.append(e.text)

        return writers
    else:
      return [writer]

# %%
def get_imdb_score(soup):
    wrapper = soup.find('span', {'class': re.compile('sc-7ab21ed2-1 jGRxWM')})
    if not wrapper:
        return None
    else:
        return float(wrapper.text)

# %%
def get_rotten_score(title):
    try:
      movie_scraper = MovieScraper(movie_title=title)
      movie_scraper.extract_metadata()
      metadata = movie_scraper.metadata
      score = int(metadata['Score_Audience'])
    except:
      score = None

    return score

# %%
def scrap_titlebar(soup, movie_title, year):
    '''Get name, rating, genre, year, release date, score and votes of a movie.'''
    try:
      name = soup.find('h1', {'data-testid': re.compile('hero-title-block__title')}).text.strip()
    except:
      name = None
    genre = get_genre(soup)
    imdb_score = get_imdb_score(soup)
    rotten_score = get_rotten_score(name)
    votes = get_votes(soup)
    released = get_release_date(soup)
    if released != None and not pd.isnull(released):
      year = released.year
    try:
        rating = soup.find('a', {'href': re.compile('tt_ov_pg')}).text
    except AttributeError:
        rating = None

    titlebar = {
        'name': movie_title,
        'rating': rating,
        'genre': genre,
        'released': released,
        'year': year,
        'imdb_score': imdb_score,
        'rotten_score': rotten_score,
        'votes': votes
    }

    return titlebar

# %%
def scrap_crew(soup):
    '''Get director, writer and star of a movie.'''
    directors = []
    try:
        wrapper = soup.find('div',{'class': 'sc-fa02f843-0 fjLeDR'})
        directors_wrapper = wrapper.find_all('a', {'href': re.compile('tt_ov_dr')})
        for director_wrapper in directors_wrapper:
          directors.append(director_wrapper.text)
    except:
      directors = []
    writer = get_writer(soup)
    star = get_star(soup)

    crew = {
        'director': directors,
        'writer': writer,
        'star': star
    }

    return crew

# %%
def scrap_details(soup):
    '''Get country, budget, gross, production co. and runtime of a movie.'''
    countries = get_country(soup)
    gross = get_money(soup, type='Gross worldwide')
    budget = get_money(soup, type='Budget')
    company = get_company(soup)
    runtime = get_runtime(soup)
    if budget:
        if not '$' in budget:
            budget = None
        else:
            try:
                budget = float(budget.split()[0].replace('$','').replace(',',''))
            except ValueError:
                budget = None

    if gross:
      if not '$' in gross:
        gross = None
      else:
        try:
          gross = float(gross.replace('$','').replace(',',''))
        except:
          gross = None

    details = {
        'country': countries,
        'budget': budget,
        'gross': gross,
        'company': company,
        'runtime': runtime
    }

    return details

# %%
def try_open_csv(year):
  try:
    df = pd.read_pickle("PYBD/projet/data/" + str(year) + ".pkl") 
  except:
    df = pd.DataFrame()

  movies = pd.read_csv("PYBD/projet/data/" + str(year) + "_links.csv")
  return (df, movies)

# %%
def write_csv(data, name, df):
    '''Write list of dicts to csv.'''
    df = pd.concat([df, pd.DataFrame(data)])
    df.to_pickle("PYBD/projet/data/" + str(name) + ".pkl")
    print("Saved!")
    return df

# %%
def scrap_links(year):
  all_movie_links = []
  links_and_title = get_all_movies(year)
  for (url, title) in links_and_title:
    all_movie_links.append({ 'url':url, 'title':title })
  df = pd.DataFrame(all_movie_links)
  df.to_csv("PYBD/projet/data/" + str(year) + "_links.csv", index=False)

# %%
def scrap(year, batch_size):
      all_movie_data = []
      (df, movies) = try_open_csv(year)
      for i in range(len(movies)):
          (movie_url, movie_title) = (movies.iloc[i]['url'], movies.iloc[i]['title'])
          if not df.empty and len(df[df['name'] == movie_title]) > 0:
            continue
          print("starting: " + movie_title + " " + movie_url, end='')
          movie_data = {}
          movie_html = go_to_movie(movie_url)
          soup = BeautifulSoup(movie_html, 'html.parser')
          movie_data.update(scrap_titlebar(soup, movie_title, year))
          if movie_data['name'] == None:
            with open("PYBD/projet/data/title_missing.txt", "a+") as file_:
              file_.write(movie_url + " " + str(year)  + " \n")
          movie_data.update(scrap_crew(soup))
          movie_data.update(scrap_details(soup))
          all_movie_data.append(movie_data)
          print(" - done")
          time.sleep(1)
          if (len(all_movie_data) >= batch_size):
            df = write_csv(all_movie_data, year, df)
            all_movie_data = []
            print("COMPLETION: " + str(round(i/len(movies) * 100, 1)) + "%")
      print(year, 'done.')
      write_csv(all_movie_data, year, df)

# %%
for i in range(1999, 1989, -1):
  scrap_links(i)

# %%
def scrap_all():
  for i in range(1999, 1969, -1):
    error = True
    while error:
      error = False
      try:
        scrap(i, 10)
      except KeyboardInterrupt:
        return
      except:
        error = True
        time.sleep(5)

# %%
scrap_all()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# starting: Mission Hill http://www.imdb.com/title/tt0084337/?ref_=adv_li_tt - done
# starting: Tennessee Stallion http://www.imdb.com/title/tt0078376/?ref_=adv_li_tt - done
# starting: Seraphita's Diary http://www.imdb.com/title/tt0081484/?ref_=adv_li_tt - done
# starting: Rude http://www.imdb.com/title/tt0362100/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 81.6%
# starting: Plainsong http://www.imdb.com/title/tt0084511/?ref_=adv_li_tt - done
# starting: Lenz http://www.imdb.com/title/tt8760392/?ref_=adv_li_tt - done
# starting: Boss Lady http://www.imdb.com/title/tt0310791/?ref_=adv_li_tt - done
# starting: A Different Image http://www.imdb.com/title/tt0180645/?ref_=adv_li_tt - done
# starting: Greater Than Gold http://www.imdb.com/title/tt1229782/?ref_=adv_li_tt - done
# starting: Uncensored Cartoons http://www.imdb.com/title/tt0158300/?ref_=adv_li_tt - done
# starting: Whitewater Sam http://www.imdb.com/title/tt0076917/?ref_=adv_li_tt - done
# starting: Desire http://www.imdb.com/title/tt0085429/?ref_=adv_li_tt - done
# starting: Face in the Mirror http://www.imdb.com/title/tt1651122/?ref_=adv_li_tt - done
# starting: The Role of the Observer http://www.imdb.com/title/tt0439788/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 84.9%
# starting: World War Mud http://www.imdb.com/title/tt8147030/?ref_=adv_li_tt - done
# starting: Vis-a-Vis http://www.imdb.com/title/tt0129551/?ref_=adv_li_tt - done
# starting: The Answer http://www.imdb.com/title/tt3208842/?ref_=adv_li_tt - done
# starting: Catharsis http://www.imdb.com/title/tt1810554/?ref_=adv_li_tt - done
# starting: Him and Me http://www.imdb.com/title/tt0206808/?ref_=adv_li_tt - done
# starting: Dan's Motel http://www.imdb.com/title/tt0083785/?ref_=adv_li_tt - done
# starting: Nightsongs http://www.imdb.com/title/tt4183490/?ref_=adv_li_tt - done
# starting: Green Card: An American Romance http://www.imdb.com/title/tt3043786/?ref_=adv_li_tt - done
# starting: Watchwords of the Eighties http://www.imdb.com/title/tt4527164/?ref_=adv_li_tt - done
# starting: Kiss of Medusa http://www.imdb.com/title/tt0202442/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 88.2%
# starting: Dorothy and Alan at Norma Place http://www.imdb.com/title/tt10151090/?ref_=adv_li_tt - done
# starting: Illegal Alien http://www.imdb.com/title/tt0264701/?ref_=adv_li_tt - done
# starting: The Mediterranean http://www.imdb.com/title/tt0160520/?ref_=adv_li_tt - done
# starting: Blinds http://www.imdb.com/title/tt5068230/?ref_=adv_li_tt - done
# starting: The Cotton Club http://www.imdb.com/title/tt0180620/?ref_=adv_li_tt - done
# starting: The American Adventure http://www.imdb.com/title/tt0219494/?ref_=adv_li_tt - done
# starting: Is That Jazz: A Mug-Shot Afterthought http://www.imdb.com/title/tt0269373/?ref_=adv_li_tt - done
# starting: Reasons for Knocking at an Empty House (In Situ Installation) http://www.imdb.com/title/tt10528072/?ref_=adv_li_tt - done
# starting: When I Am King http://www.imdb.com/title/tt0136614/?ref_=adv_li_tt - done
# starting: 10 Speed http://www.imdb.com/title/tt14604058/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 91.5%
# starting: Mountain Charlie http://www.imdb.com/title/tt0312980/?ref_=adv_li_tt - done
# starting: Rimbaud in L.A. http://www.imdb.com/title/tt10256536/?ref_=adv_li_tt - done
# starting: A Hunger Artist http://www.imdb.com/title/tt0084102/?ref_=adv_li_tt - done
# starting: The Body Politic http://www.imdb.com/title/tt0083672/?ref_=adv_li_tt - done
# starting: Forbidden Lessons http://www.imdb.com/title/tt11088128/?ref_=adv_li_tt - done
# starting: The Gordimer Stories http://www.imdb.com/title/tt0162350/?ref_=adv_li_tt - done
# starting: Mia http://www.imdb.com/title/tt0361906/?ref_=adv_li_tt - done
# starting: The Who Rocks America http://www.imdb.com/title/tt0134214/?ref_=adv_li_tt - done
# starting: Don't Touch That Dial http://www.imdb.com/title/tt0228228/?ref_=adv_li_tt - done
# starting: Dance of the Cookoos http://www.imdb.com/title/tt0366336/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 94.8%
# starting: Hell for a Bounty Hunter http://www.imdb.com/title/tt14127532/?ref_=adv_li_tt - done
# starting: Eva's Dreams http://www.imdb.com/title/tt13046904/?ref_=adv_li_tt - done
# starting: King's Bane http://www.imdb.com/title/tt2017719/?ref_=adv_li_tt - done
# starting: Jane http://www.imdb.com/title/tt0084166/?ref_=adv_li_tt - done
# starting: Sto koni http://www.imdb.com/title/tt0084733/?ref_=adv_li_tt - done
# starting: Invasions http://www.imdb.com/title/tt0222041/?ref_=adv_li_tt - done
# starting: Botero http://www.imdb.com/title/tt0215578/?ref_=adv_li_tt - done
# starting: Mademoiselle http://www.imdb.com/title/tt0077885/?ref_=adv_li_tt - done
# starting: The Dove & The Jr. Rogues http://www.imdb.com/title/tt11036060/?ref_=adv_li_tt - done
# starting: Spirit of the Dream-House http://www.imdb.com/title/tt0194397/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 98.0%
# starting: The Quiet Collector: Andrew Mellon Remembered http://www.imdb.com/title/tt3681638/?ref_=adv_li_tt - done
# starting: The Ghost of the Great Salt Lake http://www.imdb.com/title/tt0402214/?ref_=adv_li_tt - done
# starting: Le incredibili avventure della Piccola Lulu http://www.imdb.com/title/tt18690572/?ref_=adv_li_tt - done
# starting: Rent a Wreck http://www.imdb.com/title/tt0217760/?ref_=adv_li_tt - done
# starting: Who's Killing the Cities http://www.imdb.com/title/tt0084900/?ref_=adv_li_tt - done
# 1982 done.
# Saved!
# starting: Indiana Jones and the Raiders of the Lost Ark http://www.imdb.com/title/tt0082971/?ref_=adv_li_tt - done
# starting: The Evil Dead http://www.imdb.com/title/tt0083907/?ref_=adv_li_tt - done
# starting: Body Heat http://www.imdb.com/title/tt0082089/?ref_=adv_li_tt - done
# starting: Excalibur http://www.imdb.com/title/tt0082348/?ref_=adv_li_tt - done
# starting: Stripes http://www.imdb.com/title/tt0083131/?ref_=adv_li_tt - done
# starting: On Golden Pond http://www.imdb.com/title/tt0082846/?ref_=adv_li_tt - done
# starting: An American Werewolf in London http://www.imdb.com/title/tt0082010/?ref_=adv_li_tt - done
# starting: Clash of the Titans http://www.imdb.com/title/tt0082186/?ref_=adv_li_tt - done
# starting: Endless Love http://www.imdb.com/title/tt0082329/?ref_=adv_li_tt - done
# starting: Arthur http://www.imdb.com/title/tt0082031/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 3.2%
# starting: Escape from New York http://www.imdb.com/title/tt0082340/?ref_=adv_li_tt - done
# starting: The Cannonball Run http://www.imdb.com/title/tt0082136/?ref_=adv_li_tt - done
# starting: Thief http://www.imdb.com/title/tt0083190/?ref_=adv_li_tt - done
# starting: The Fox and the Hound http://www.imdb.com/title/tt0082406/?ref_=adv_li_tt - done
# starting: Mommie Dearest http://www.imdb.com/title/tt0082766/?ref_=adv_li_tt - done
# starting: Reds http://www.imdb.com/title/tt0082979/?ref_=adv_li_tt - done
# starting: The Howling http://www.imdb.com/title/tt0082533/?ref_=adv_li_tt - done
# starting: Friday the 13th Part 2 http://www.imdb.com/title/tt0082418/?ref_=adv_li_tt - done
# starting: History of the World: Part I http://www.imdb.com/title/tt0082517/?ref_=adv_li_tt - done
# starting: Halloween II http://www.imdb.com/title/tt0082495/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 6.8%
# starting: Blow Out http://www.imdb.com/title/tt0082085/?ref_=adv_li_tt - done
# starting: The Burning http://www.imdb.com/title/tt0082118/?ref_=adv_li_tt - done
# starting: Taps http://www.imdb.com/title/tt0083169/?ref_=adv_li_tt - done
# starting: My Dinner with Andre http://www.imdb.com/title/tt0082783/?ref_=adv_li_tt - done
# starting: Ms .45 http://www.imdb.com/title/tt0082776/?ref_=adv_li_tt - done
# starting: Dead & Buried http://www.imdb.com/title/tt0082242/?ref_=adv_li_tt - done
# starting: The Postman Always Rings Twice http://www.imdb.com/title/tt0082934/?ref_=adv_li_tt - done
# starting: Deadly Blessing http://www.imdb.com/title/tt0082245/?ref_=adv_li_tt - done
# starting: Ghost Story http://www.imdb.com/title/tt0082449/?ref_=adv_li_tt - done
# starting: Dragonslayer http://www.imdb.com/title/tt0082288/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 10.3%
# starting: The Funhouse http://www.imdb.com/title/tt0082427/?ref_=adv_li_tt - done
# starting: Victory http://www.imdb.com/title/tt0083284/?ref_=adv_li_tt - done
# starting: Tarzan the Ape Man http://www.imdb.com/title/tt0083170/?ref_=adv_li_tt - done
# starting: Galaxy of Terror http://www.imdb.com/title/tt0082431/?ref_=adv_li_tt - done
# starting: Ragtime http://www.imdb.com/title/tt0082970/?ref_=adv_li_tt - done
# starting: Nighthawks http://www.imdb.com/title/tt0082817/?ref_=adv_li_tt - done
# starting: Butterfly http://www.imdb.com/title/tt0082122/?ref_=adv_li_tt - done
# starting: Roar http://www.imdb.com/title/tt0083001/?ref_=adv_li_tt - done
# starting: X-Ray http://www.imdb.com/title/tt0082527/?ref_=adv_li_tt - done
# starting: Private Lessons http://www.imdb.com/title/tt0082948/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 13.9%
# starting: Southern Comfort http://www.imdb.com/title/tt0083111/?ref_=adv_li_tt - done
# starting: Piranha II: The Spawning http://www.imdb.com/title/tt0082910/?ref_=adv_li_tt - done
# starting: Caveman http://www.imdb.com/title/tt0082146/?ref_=adv_li_tt - done
# starting: Student Bodies http://www.imdb.com/title/tt0083133/?ref_=adv_li_tt - done
# starting: Eyewitness http://www.imdb.com/title/tt0082353/?ref_=adv_li_tt - done
# starting: The Great Muppet Caper http://www.imdb.com/title/tt0082474/?ref_=adv_li_tt - done
# starting: The Prowler http://www.imdb.com/title/tt0082951/?ref_=adv_li_tt - done
# starting: Hell Night http://www.imdb.com/title/tt0082511/?ref_=adv_li_tt - done
# starting: Polyester http://www.imdb.com/title/tt0082926/?ref_=adv_li_tt - done
# starting: S.O.B. http://www.imdb.com/title/tt0083015/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 17.4%
# starting: One from the Heart http://www.imdb.com/title/tt0084445/?ref_=adv_li_tt - done
# starting: Neighbors http://www.imdb.com/title/tt0082801/?ref_=adv_li_tt - done
# starting: Early Warning http://www.imdb.com/title/tt0350869/?ref_=adv_li_tt - done
# starting: Carbon Copy http://www.imdb.com/title/tt0082138/?ref_=adv_li_tt - done
# starting: Looker http://www.imdb.com/title/tt0082677/?ref_=adv_li_tt - done
# starting: Just Before Dawn http://www.imdb.com/title/tt0082592/?ref_=adv_li_tt - done
# starting: Graduation Day http://www.imdb.com/title/tt0082467/?ref_=adv_li_tt - done
# starting: They All Laughed http://www.imdb.com/title/tt0083189/?ref_=adv_li_tt - done
# starting: Pennies from Heaven http://www.imdb.com/title/tt0082894/?ref_=adv_li_tt - done
# starting: The Loveless http://www.imdb.com/title/tt0085872/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 21.0%
# starting: Butcher, Baker, Nightmare Maker http://www.imdb.com/title/tt0082813/?ref_=adv_li_tt - done
# starting: Cutter's Way http://www.imdb.com/title/tt0082220/?ref_=adv_li_tt - done
# starting: Absence of Malice http://www.imdb.com/title/tt0081974/?ref_=adv_li_tt - done
# starting: The Final Conflict http://www.imdb.com/title/tt0082377/?ref_=adv_li_tt - done
# starting: Prince of the City http://www.imdb.com/title/tt0082945/?ref_=adv_li_tt - done
# starting: Nice Dreams http://www.imdb.com/title/tt0082163/?ref_=adv_li_tt - done
# starting: Sharky's Machine http://www.imdb.com/title/tt0083064/?ref_=adv_li_tt - done
# starting: Modern Problems http://www.imdb.com/title/tt0082763/?ref_=adv_li_tt - done
# starting: Enter the Ninja http://www.imdb.com/title/tt0082332/?ref_=adv_li_tt - done
# starting: Bustin' Loose http://www.imdb.com/title/tt0082121/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 24.6%
# starting: Wolfen http://www.imdb.com/title/tt0083336/?ref_=adv_li_tt - done
# starting: The Hand http://www.imdb.com/title/tt0082497/?ref_=adv_li_tt - done
# starting: Nightmare http://www.imdb.com/title/tt0082818/?ref_=adv_li_tt - done
# starting: Madman http://www.imdb.com/title/tt0082696/?ref_=adv_li_tt - done
# starting: Zorro: The Gay Blade http://www.imdb.com/title/tt0083366/?ref_=adv_li_tt - done
# starting: Shock Treatment http://www.imdb.com/title/tt0083067/?ref_=adv_li_tt - done
# starting: Knightriders http://www.imdb.com/title/tt0082622/?ref_=adv_li_tt - done
# starting: ...All the Marbles http://www.imdb.com/title/tt0081964/?ref_=adv_li_tt - done
# starting: Bloody Birthday http://www.imdb.com/title/tt0082084/?ref_=adv_li_tt - done
# starting: So Fine http://www.imdb.com/title/tt0083099/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 28.1%
# starting: Under the Rainbow http://www.imdb.com/title/tt0083254/?ref_=adv_li_tt - done
# starting: Eyes of a Stranger http://www.imdb.com/title/tt0082352/?ref_=adv_li_tt - done
# starting: American Pop http://www.imdb.com/title/tt0082009/?ref_=adv_li_tt - done
# starting: The Four Seasons http://www.imdb.com/title/tt0082405/?ref_=adv_li_tt - done
# starting: Saturday the 14th http://www.imdb.com/title/tt0083033/?ref_=adv_li_tt - done
# starting: Death Hunt http://www.imdb.com/title/tt0082247/?ref_=adv_li_tt - done
# starting: The Incredible Shrinking Woman http://www.imdb.com/title/tt0082558/?ref_=adv_li_tt - done
# starting: Who Finds a Friend Finds a Treasure http://www.imdb.com/title/tt0085327/?ref_=adv_li_tt - done
# starting: True Confessions http://www.imdb.com/title/tt0083232/?ref_=adv_li_tt - done
# starting: Final Exam http://www.imdb.com/title/tt0082378/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 31.7%
# starting: Fort Apache the Bronx http://www.imdb.com/title/tt0082402/?ref_=adv_li_tt - done
# starting: The Fan http://www.imdb.com/title/tt0082362/?ref_=adv_li_tt - done
# starting: An Eye for an Eye http://www.imdb.com/title/tt0082350/?ref_=adv_li_tt - done
# starting: The Chosen http://www.imdb.com/title/tt0082175/?ref_=adv_li_tt - done
# starting: Heartbeeps http://www.imdb.com/title/tt0082507/?ref_=adv_li_tt - done
# starting: Evilspeak http://www.imdb.com/title/tt0082346/?ref_=adv_li_tt - done
# starting: Continental Divide http://www.imdb.com/title/tt0082200/?ref_=adv_li_tt - done
# starting: Fantasies http://www.imdb.com/title/tt0082363/?ref_=adv_li_tt - done
# starting: The Night the Lights Went Out in Georgia http://www.imdb.com/title/tt0082816/?ref_=adv_li_tt - done
# starting: Malibu Hot Summer http://www.imdb.com/title/tt0072173/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 35.2%
# starting: Zoot Suit http://www.imdb.com/title/tt0083365/?ref_=adv_li_tt - done
# starting: Inchon http://www.imdb.com/title/tt0084132/?ref_=adv_li_tt - done
# starting: The Boogens http://www.imdb.com/title/tt0082094/?ref_=adv_li_tt - done
# starting: The Legend of the Lone Ranger http://www.imdb.com/title/tt0082648/?ref_=adv_li_tt - done
# starting: The Last Chase http://www.imdb.com/title/tt0082642/?ref_=adv_li_tt - done
# starting: Night School http://www.imdb.com/title/tt0082812/?ref_=adv_li_tt - done
# starting: Buddy Buddy http://www.imdb.com/title/tt0082111/?ref_=adv_li_tt - done
# starting: The Last Shark http://www.imdb.com/title/tt0081677/?ref_=adv_li_tt - done
# starting: Liar's Moon http://www.imdb.com/title/tt0082656/?ref_=adv_li_tt - done
# starting: Four Friends http://www.imdb.com/title/tt0082404/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 38.8%
# starting: Modern Romance http://www.imdb.com/title/tt0082764/?ref_=adv_li_tt - done
# starting: The Being http://www.imdb.com/title/tt0085224/?ref_=adv_li_tt - done
# starting: Raggedy Man http://www.imdb.com/title/tt0082969/?ref_=adv_li_tt - done
# starting: Tattoo http://www.imdb.com/title/tt0083178/?ref_=adv_li_tt - done
# starting: Firecracker http://www.imdb.com/title/tt0067100/?ref_=adv_li_tt - done
# starting: Goin' All the Way! http://www.imdb.com/title/tt0084010/?ref_=adv_li_tt - done
# starting: Rich and Famous http://www.imdb.com/title/tt0082992/?ref_=adv_li_tt - done
# starting: Full Moon High http://www.imdb.com/title/tt0082425/?ref_=adv_li_tt - done
# starting: Don't Go in the Woods http://www.imdb.com/title/tt0182996/?ref_=adv_li_tt - done
# starting: All Night Long http://www.imdb.com/title/tt0082001/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 42.3%
# starting: The Nesting http://www.imdb.com/title/tt0082804/?ref_=adv_li_tt - done
# starting: Charlie Chan and the Curse of the Dragon Queen http://www.imdb.com/title/tt0082159/?ref_=adv_li_tt - done
# starting: Scream http://www.imdb.com/title/tt0086262/?ref_=adv_li_tt - done
# starting: Only When I Laugh http://www.imdb.com/title/tt0082853/?ref_=adv_li_tt - done
# starting: Back Roads http://www.imdb.com/title/tt0082042/?ref_=adv_li_tt - done
# starting: Separate Ways http://www.imdb.com/title/tt0083052/?ref_=adv_li_tt - done
# starting: Whose Life Is It Anyway? http://www.imdb.com/title/tt0083326/?ref_=adv_li_tt - done
# starting: Kill and Kill Again http://www.imdb.com/title/tt0082612/?ref_=adv_li_tt - done
# starting: The Pursuit of D.B. Cooper http://www.imdb.com/title/tt0082958/?ref_=adv_li_tt - done
# starting: Take This Job and Shove It http://www.imdb.com/title/tt0083163/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 45.9%
# starting: Lovely But Deadly http://www.imdb.com/title/tt0082685/?ref_=adv_li_tt - done
# starting: Amy http://www.imdb.com/title/tt0082017/?ref_=adv_li_tt - done
# starting: Savage Harvest http://www.imdb.com/title/tt0083034/?ref_=adv_li_tt - done
# starting: Love & Money http://www.imdb.com/title/tt0084274/?ref_=adv_li_tt - done
# starting: C.O.D. http://www.imdb.com/title/tt0082126/?ref_=adv_li_tt - done
# starting: Frankenstein Island http://www.imdb.com/title/tt0082410/?ref_=adv_li_tt - done
# starting: High Risk http://www.imdb.com/title/tt0082516/?ref_=adv_li_tt - done
# starting: Body and Soul http://www.imdb.com/title/tt0082090/?ref_=adv_li_tt - done
# starting: Rollover http://www.imdb.com/title/tt0083006/?ref_=adv_li_tt - done
# starting: The Bushido Blade http://www.imdb.com/title/tt0078918/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 49.5%
# starting: Tuck Everlasting http://www.imdb.com/title/tt0081664/?ref_=adv_li_tt - done
# starting: Image of the Beast http://www.imdb.com/title/tt0080915/?ref_=adv_li_tt - done
# starting: Choices http://www.imdb.com/title/tt0082172/?ref_=adv_li_tt - done
# starting: Fear No Evil http://www.imdb.com/title/tt0082367/?ref_=adv_li_tt - done
# starting: Treasure of the Yankee Zephyr http://www.imdb.com/title/tt0082968/?ref_=adv_li_tt - done
# starting: Force: Five http://www.imdb.com/title/tt0082399/?ref_=adv_li_tt - done
# starting: Honky Tonk Freeway http://www.imdb.com/title/tt0082525/?ref_=adv_li_tt - done
# starting: The Devil and Max Devlin http://www.imdb.com/title/tt0082263/?ref_=adv_li_tt - done
# starting: The Hot Touch http://www.imdb.com/title/tt0082530/?ref_=adv_li_tt - done
# starting: Jaws of Satan http://www.imdb.com/title/tt0082580/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 53.0%
# starting: Smokey Bites the Dust http://www.imdb.com/title/tt0083097/?ref_=adv_li_tt - done
# starting: Kiss Daddy Goodbye http://www.imdb.com/title/tt0082620/?ref_=adv_li_tt - done
# starting: First Monday in October http://www.imdb.com/title/tt0082382/?ref_=adv_li_tt - done
# starting: King of the Mountain http://www.imdb.com/title/tt0082619/?ref_=adv_li_tt - done
# starting: The Creature Wasn't Nice http://www.imdb.com/title/tt0082213/?ref_=adv_li_tt - done
# starting: Going Ape! http://www.imdb.com/title/tt0082457/?ref_=adv_li_tt - done
# starting: The Dark End of the Street http://www.imdb.com/title/tt0082234/?ref_=adv_li_tt - done
# starting: Home Sweet Home http://www.imdb.com/title/tt0082522/?ref_=adv_li_tt - done
# starting: Comin' at Ya! http://www.imdb.com/title/tt0082193/?ref_=adv_li_tt - done
# starting: Soggy Bottom, U.S.A. http://www.imdb.com/title/tt0081533/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 56.6%
# starting: Paternity http://www.imdb.com/title/tt0082886/?ref_=adv_li_tt - done
# starting: St. Helens http://www.imdb.com/title/tt0083117/?ref_=adv_li_tt - done
# starting: Dawn of the Mummy http://www.imdb.com/title/tt0082237/?ref_=adv_li_tt - done
# starting: The Looney, Looney, Looney Bugs Bunny Movie http://www.imdb.com/title/tt0082679/?ref_=adv_li_tt - done
# starting: Chanel Solitaire http://www.imdb.com/title/tt0082156/?ref_=adv_li_tt - done
# starting: Years of the Beast http://www.imdb.com/title/tt0243036/?ref_=adv_li_tt - done
# starting: The Man Who Saw Tomorrow http://www.imdb.com/title/tt0081109/?ref_=adv_li_tt - done
# starting: Gangster Wars http://www.imdb.com/title/tt0082434/?ref_=adv_li_tt - done
# starting: Nobody's Perfekt http://www.imdb.com/title/tt0082822/?ref_=adv_li_tt - done
# starting: Texas Lightning http://www.imdb.com/title/tt0083186/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 60.1%
# starting: Chu Chu and the Philly Flash http://www.imdb.com/title/tt0082177/?ref_=adv_li_tt - done
# starting: On the Right Track http://www.imdb.com/title/tt0082849/?ref_=adv_li_tt - done
# starting: Lunch Wagon http://www.imdb.com/title/tt0081088/?ref_=adv_li_tt - done
# starting: A Day of Judgment http://www.imdb.com/title/tt0221902/?ref_=adv_li_tt - done
# starting: Night of the Zombies http://www.imdb.com/title/tt0082815/?ref_=adv_li_tt - done
# starting: Documenteur http://www.imdb.com/title/tt0082275/?ref_=adv_li_tt - done
# starting: Longshot http://www.imdb.com/title/tt0082676/?ref_=adv_li_tt - done
# starting: Lifepod http://www.imdb.com/title/tt0125366/?ref_=adv_li_tt - done
# starting: Heartbreak High http://www.imdb.com/title/tt0081001/?ref_=adv_li_tt - done
# starting: Lovespell http://www.imdb.com/title/tt0079492/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 63.7%
# starting: Americana http://www.imdb.com/title/tt0082011/?ref_=adv_li_tt - done
# starting: Earthbound http://www.imdb.com/title/tt0082308/?ref_=adv_li_tt - done
# starting: Delusion http://www.imdb.com/title/tt0080607/?ref_=adv_li_tt - done
# starting: Rivals http://www.imdb.com/title/tt0079811/?ref_=adv_li_tt - done
# starting: The Instructor http://www.imdb.com/title/tt0187993/?ref_=adv_li_tt - done
# starting: Hollywood High Part II http://www.imdb.com/title/tt0082519/?ref_=adv_li_tt - done
# starting: Harry's War http://www.imdb.com/title/tt0082503/?ref_=adv_li_tt - done
# starting: The White Lions http://www.imdb.com/title/tt0083324/?ref_=adv_li_tt - done
# starting: The End of August http://www.imdb.com/title/tt0083884/?ref_=adv_li_tt - done
# starting: Night of Horror http://www.imdb.com/title/tt0202496/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 67.3%
# starting: Subway Riders http://www.imdb.com/title/tt0083138/?ref_=adv_li_tt - done
# starting: Dream on! http://www.imdb.com/title/tt0082291/?ref_=adv_li_tt - done
# starting: Underground Aces http://www.imdb.com/title/tt0081681/?ref_=adv_li_tt - done
# starting: Tulips http://www.imdb.com/title/tt0083236/?ref_=adv_li_tt - done
# starting: Rent Control http://www.imdb.com/title/tt0082985/?ref_=adv_li_tt - done
# starting: Deadly Vengeance http://www.imdb.com/title/tt0082246/?ref_=adv_li_tt - done
# starting: Beatlemania http://www.imdb.com/title/tt0082052/?ref_=adv_li_tt - done
# starting: The Woman Inside http://www.imdb.com/title/tt0083339/?ref_=adv_li_tt - done
# starting: Freddie of the Jungle http://www.imdb.com/title/tt0082465/?ref_=adv_li_tt - done
# starting: The Guns and the Fury http://www.imdb.com/title/tt0082488/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 70.8%
# starting: Adieu, Galaxy Express 999: Last Stop Andromeda http://www.imdb.com/title/tt0184881/?ref_=adv_li_tt - done
# starting: You Are Not I http://www.imdb.com/title/tt0193647/?ref_=adv_li_tt - done
# starting: Home Safe http://www.imdb.com/title/tt0082521/?ref_=adv_li_tt - done
# starting: Getting Over http://www.imdb.com/title/tt0080784/?ref_=adv_li_tt - done
# starting: Legend of the Wild http://www.imdb.com/title/tt0312901/?ref_=adv_li_tt - done
# starting: Madame Wang's http://www.imdb.com/title/tt0159544/?ref_=adv_li_tt - done
# starting: Christmas Mountain http://www.imdb.com/title/tt0080531/?ref_=adv_li_tt - done
# starting: The Case He Couldn't Crack http://www.imdb.com/title/tt0309422/?ref_=adv_li_tt - done
# starting: Moving http://www.imdb.com/title/tt0082774/?ref_=adv_li_tt - done
# starting: Street Music http://www.imdb.com/title/tt0083129/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 74.4%
# starting: The Weapons of Death http://www.imdb.com/title/tt0166016/?ref_=adv_li_tt - done
# starting: Fast Money http://www.imdb.com/title/tt0211362/?ref_=adv_li_tt - done
# starting: Sourdough http://www.imdb.com/title/tt0281217/?ref_=adv_li_tt - done
# starting: Broken English http://www.imdb.com/title/tt0173697/?ref_=adv_li_tt - done
# starting: Les jeunes adultes http://www.imdb.com/title/tt0082500/?ref_=adv_li_tt - done
# starting: Beyond the Universe http://www.imdb.com/title/tt0130503/?ref_=adv_li_tt - done
# starting: Dreams of Desire http://www.imdb.com/title/tt0136059/?ref_=adv_li_tt - done
# starting: A Face in the Crowd http://www.imdb.com/title/tt0350908/?ref_=adv_li_tt - done
# starting: Fat Chance http://www.imdb.com/title/tt0080721/?ref_=adv_li_tt - done
# starting: Hudson Taylor http://www.imdb.com/title/tt1206306/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 77.9%
# starting: Paydirt http://www.imdb.com/title/tt0079706/?ref_=adv_li_tt - done
# starting: Escape from DS-3 http://www.imdb.com/title/tt0123825/?ref_=adv_li_tt - done
# starting: Will http://www.imdb.com/title/tt0232951/?ref_=adv_li_tt - done
# starting: She Dances Alone http://www.imdb.com/title/tt0083065/?ref_=adv_li_tt - done
# starting: Atrapados http://www.imdb.com/title/tt3549250/?ref_=adv_li_tt - done
# starting: Stagefright http://www.imdb.com/title/tt0083120/?ref_=adv_li_tt - done
# starting: Strong Medicine http://www.imdb.com/title/tt0079959/?ref_=adv_li_tt - done
# starting: Greatest American Hero spoof http://www.imdb.com/title/tt8260740/?ref_=adv_li_tt - done
# starting: My Mother, My Daughter http://www.imdb.com/title/tt13046676/?ref_=adv_li_tt - done
# starting: Oklahoma Bound http://www.imdb.com/title/tt9586280/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 81.5%
# starting: Jet Lag http://www.imdb.com/title/tt0080955/?ref_=adv_li_tt - done
# starting: The Dozens http://www.imdb.com/title/tt0082286/?ref_=adv_li_tt - done
# starting: Romeo and Juliet http://www.imdb.com/title/tt11111564/?ref_=adv_li_tt - done
# starting: The Transformation of Sulka http://www.imdb.com/title/tt0195357/?ref_=adv_li_tt - done
# starting: Stark Raving Mad http://www.imdb.com/title/tt0084727/?ref_=adv_li_tt - done
# starting: Grad Night http://www.imdb.com/title/tt0080810/?ref_=adv_li_tt - done
# starting: The 'Ten' Girls http://www.imdb.com/title/tt11061826/?ref_=adv_li_tt - done
# starting: The Adventures of Huckleberry Finn http://www.imdb.com/title/tt1997552/?ref_=adv_li_tt - done
# starting: America Live in Central Park http://www.imdb.com/title/tt12700436/?ref_=adv_li_tt - done
# starting: Magnum Thrust http://www.imdb.com/title/tt0082698/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 85.1%
# starting: Beating the Lesbian Bitch http://www.imdb.com/title/tt0266311/?ref_=adv_li_tt - done
# starting: Enter Another Dragon http://www.imdb.com/title/tt0082331/?ref_=adv_li_tt - done
# starting: The Cop Killers http://www.imdb.com/title/tt0173744/?ref_=adv_li_tt - done
# starting: The Uppercrust http://www.imdb.com/title/tt0096349/?ref_=adv_li_tt - done
# starting: Fatal Encounter http://www.imdb.com/title/tt0082365/?ref_=adv_li_tt - done
# starting: Free Amerika Broadcasting http://www.imdb.com/title/tt0144938/?ref_=adv_li_tt - done
# starting: Teenage Suicide: Don't Try It! http://www.imdb.com/title/tt0250034/?ref_=adv_li_tt - done
# starting: Men Who Are Men http://www.imdb.com/title/tt0158773/?ref_=adv_li_tt - done
# starting: Fait Accompli http://www.imdb.com/title/tt5499854/?ref_=adv_li_tt - done
# starting: Getting Even http://www.imdb.com/title/tt0214715/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 88.6%
# starting: Brother Enemy http://www.imdb.com/title/tt2113628/?ref_=adv_li_tt - done
# starting: Incense and Peppermints http://www.imdb.com/title/tt0293279/?ref_=adv_li_tt - done
# starting: Uncle Scam http://www.imdb.com/title/tt0260470/?ref_=adv_li_tt - done
# starting: Maya http://www.imdb.com/title/tt0293407/?ref_=adv_li_tt - done
# starting: Raider Stone http://www.imdb.com/title/tt0199992/?ref_=adv_li_tt - done
# starting: Night City Angels http://www.imdb.com/title/tt7125814/?ref_=adv_li_tt - done
# starting: Tree of Knowledge http://www.imdb.com/title/tt10840626/?ref_=adv_li_tt - done
# starting: High Point http://www.imdb.com/title/tt3127230/?ref_=adv_li_tt - done
# starting: Amazing Graces http://www.imdb.com/title/tt0191778/?ref_=adv_li_tt - done
# starting: Stiletto http://www.imdb.com/title/tt13119074/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 92.2%
# starting: Machin http://www.imdb.com/title/tt0198678/?ref_=adv_li_tt - done
# starting: Chyornaya sobaka http://www.imdb.com/title/tt0082184/?ref_=adv_li_tt - done
# starting: Ritzville http://www.imdb.com/title/tt0212470/?ref_=adv_li_tt - done
# starting: Imperial Navy http://www.imdb.com/title/tt0082551/?ref_=adv_li_tt - done
# starting: Last Dance http://www.imdb.com/title/tt0206873/?ref_=adv_li_tt - done
# starting: The Living Word http://www.imdb.com/title/tt6244754/?ref_=adv_li_tt - done
# starting: The Cycle of Communication http://www.imdb.com/title/tt0273515/?ref_=adv_li_tt - done
# starting: Fela in Concert http://www.imdb.com/title/tt0417668/?ref_=adv_li_tt - done
# starting: Dostoevskiy http://www.imdb.com/title/tt0082283/?ref_=adv_li_tt - done
# starting: The Summerset Sisters http://www.imdb.com/title/tt7607934/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 95.7%
# starting: Margaret and Adele http://www.imdb.com/title/tt1874617/?ref_=adv_li_tt - done
# starting: Salt, Pepper and Soy Sauce http://www.imdb.com/title/tt0083026/?ref_=adv_li_tt - done
# starting: The Edison Adventures http://www.imdb.com/title/tt0219659/?ref_=adv_li_tt - done
# starting: Merry Wives of Windsor http://www.imdb.com/title/tt11109896/?ref_=adv_li_tt - done
# starting: Passing the Message http://www.imdb.com/title/tt0212416/?ref_=adv_li_tt - done
# starting: The Ninja Legacy http://www.imdb.com/title/tt0199834/?ref_=adv_li_tt - done
# starting: Widows Weeds http://www.imdb.com/title/tt0203202/?ref_=adv_li_tt - done
# starting: To Catch a Wave http://www.imdb.com/title/tt12524008/?ref_=adv_li_tt - done
# starting: The Hide Out http://www.imdb.com/title/tt0378036/?ref_=adv_li_tt - done
# starting: Unity Through Strength http://www.imdb.com/title/tt0142946/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 99.3%
# starting: Weekends http://www.imdb.com/title/tt0138928/?ref_=adv_li_tt - done
# 1981 done.
# Saved!
# starting: The Shining http://www.imdb.com/title/tt0081505/?ref_=adv_li_tt - done
# starting: The Blue Lagoon http://www.imdb.com/title/tt0080453/?ref_=adv_li_tt - done
# starting: Star Wars: Episode V - The Empire Strikes Back http://www.imdb.com/title/tt0080684/?ref_=adv_li_tt - done
# starting: Airplane! http://www.imdb.com/title/tt0080339/?ref_=adv_li_tt - done
# starting: Caddyshack http://www.imdb.com/title/tt0080487/?ref_=adv_li_tt - done
# starting: Raging Bull http://www.imdb.com/title/tt0081398/?ref_=adv_li_tt - done
# starting: Popeye http://www.imdb.com/title/tt0081353/?ref_=adv_li_tt - done
# starting: The Blues Brothers http://www.imdb.com/title/tt0080455/?ref_=adv_li_tt - done
# starting: The Elephant Man http://www.imdb.com/title/tt0080678/?ref_=adv_li_tt - done
# starting: Friday the 13th http://www.imdb.com/title/tt0080761/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 3.2%
# starting: Ordinary People http://www.imdb.com/title/tt0081283/?ref_=adv_li_tt - done
# starting: Flash Gordon http://www.imdb.com/title/tt0080745/?ref_=adv_li_tt - done
# starting: Altered States http://www.imdb.com/title/tt0080360/?ref_=adv_li_tt - done
# starting: Dressed to Kill http://www.imdb.com/title/tt0080661/?ref_=adv_li_tt - done
# starting: Superman II http://www.imdb.com/title/tt0081573/?ref_=adv_li_tt - done
# starting: 9 to 5 http://www.imdb.com/title/tt0080319/?ref_=adv_li_tt - done
# starting: Fame http://www.imdb.com/title/tt0080716/?ref_=adv_li_tt - done
# starting: Urban Cowboy http://www.imdb.com/title/tt0081696/?ref_=adv_li_tt - done
# starting: Somewhere in Time http://www.imdb.com/title/tt0081534/?ref_=adv_li_tt - done
# starting: Any Which Way You Can http://www.imdb.com/title/tt0080377/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 6.7%
# starting: The Fog http://www.imdb.com/title/tt0080749/?ref_=adv_li_tt - done
# starting: The Final Countdown http://www.imdb.com/title/tt0080736/?ref_=adv_li_tt - done
# starting: Cruising http://www.imdb.com/title/tt0080569/?ref_=adv_li_tt - done
# starting: Heaven's Gate http://www.imdb.com/title/tt0080855/?ref_=adv_li_tt - done
# starting: Alligator http://www.imdb.com/title/tt0080354/?ref_=adv_li_tt - done
# starting: Used Cars http://www.imdb.com/title/tt0081698/?ref_=adv_li_tt - done
# starting: American Gigolo http://www.imdb.com/title/tt0080365/?ref_=adv_li_tt - done
# starting: The Long Riders http://www.imdb.com/title/tt0081071/?ref_=adv_li_tt - done
# starting: Foxes http://www.imdb.com/title/tt0080756/?ref_=adv_li_tt - done
# starting: Stir Crazy http://www.imdb.com/title/tt0081562/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 10.2%
# starting: Galaxina http://www.imdb.com/title/tt0080771/?ref_=adv_li_tt - done
# starting: Little Darlings http://www.imdb.com/title/tt0081060/?ref_=adv_li_tt - done
# starting: Tom Horn http://www.imdb.com/title/tt0080031/?ref_=adv_li_tt - done
# starting: Xanadu http://www.imdb.com/title/tt0081777/?ref_=adv_li_tt - done
# starting: Humanoids from the Deep http://www.imdb.com/title/tt0080904/?ref_=adv_li_tt - done
# starting: The Sea Wolves http://www.imdb.com/title/tt0081470/?ref_=adv_li_tt - done
# starting: Smokey and the Bandit II http://www.imdb.com/title/tt0081529/?ref_=adv_li_tt - done
# starting: Kagemusha http://www.imdb.com/title/tt0080979/?ref_=adv_li_tt - done
# starting: Maniac http://www.imdb.com/title/tt0081114/?ref_=adv_li_tt - done
# starting: Superman II: The Richard Donner Cut http://www.imdb.com/title/tt0839995/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 13.7%
# starting: Battle Beyond the Stars http://www.imdb.com/title/tt0080421/?ref_=adv_li_tt - done
# starting: The Hollywood Knights http://www.imdb.com/title/tt0080881/?ref_=adv_li_tt - done
# starting: My Bodyguard http://www.imdb.com/title/tt0081207/?ref_=adv_li_tt - done
# starting: Private Benjamin http://www.imdb.com/title/tt0081375/?ref_=adv_li_tt - done
# starting: Coal Miner's Daughter http://www.imdb.com/title/tt0080549/?ref_=adv_li_tt - done
# starting: Motel Hell http://www.imdb.com/title/tt0081184/?ref_=adv_li_tt - done
# starting: The Ninth Configuration http://www.imdb.com/title/tt0081237/?ref_=adv_li_tt - done
# starting: Brubaker http://www.imdb.com/title/tt0080474/?ref_=adv_li_tt - done
# starting: The Big Red One http://www.imdb.com/title/tt0080437/?ref_=adv_li_tt - done
# starting: Seems Like Old Times http://www.imdb.com/title/tt0081480/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 17.3%
# starting: The Watcher in the Woods http://www.imdb.com/title/tt0081738/?ref_=adv_li_tt - done
# starting: Carny http://www.imdb.com/title/tt0080500/?ref_=adv_li_tt - done
# starting: Melvin and Howard http://www.imdb.com/title/tt0081150/?ref_=adv_li_tt - done
# starting: The Lion of the Desert http://www.imdb.com/title/tt0081059/?ref_=adv_li_tt - done
# starting: Midnight Madness http://www.imdb.com/title/tt0081159/?ref_=adv_li_tt - done
# starting: Raise the Titanic http://www.imdb.com/title/tt0081400/?ref_=adv_li_tt - done
# starting: The Jazz Singer http://www.imdb.com/title/tt0080948/?ref_=adv_li_tt - done
# starting: Gloria http://www.imdb.com/title/tt0080798/?ref_=adv_li_tt - done
# starting: Super Fuzz http://www.imdb.com/title/tt0082924/?ref_=adv_li_tt - done
# starting: He Knows You're Alone http://www.imdb.com/title/tt0080850/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 20.8%
# starting: The First Deadly Sin http://www.imdb.com/title/tt0080738/?ref_=adv_li_tt - done
# starting: Mother's Day http://www.imdb.com/title/tt0081186/?ref_=adv_li_tt - done
# starting: Can't Stop the Music http://www.imdb.com/title/tt0080492/?ref_=adv_li_tt - done
# starting: Fade to Black http://www.imdb.com/title/tt0080711/?ref_=adv_li_tt - done
# starting: Forbidden Zone http://www.imdb.com/title/tt0080752/?ref_=adv_li_tt - done
# starting: Night of the Demon http://www.imdb.com/title/tt0081229/?ref_=adv_li_tt - done
# starting: Without Warning http://www.imdb.com/title/tt0081764/?ref_=adv_li_tt - done
# starting: Cheech and Chong's Next Movie http://www.imdb.com/title/tt0080520/?ref_=adv_li_tt - done
# starting: Where the Buffalo Roam http://www.imdb.com/title/tt0081748/?ref_=adv_li_tt - done
# starting: The Hunter http://www.imdb.com/title/tt0080907/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 24.3%
# starting: Bad Timing: A Sensual Obsession http://www.imdb.com/title/tt0080408/?ref_=adv_li_tt - done
# starting: The Island http://www.imdb.com/title/tt0080934/?ref_=adv_li_tt - done
# starting: The Stunt Man http://www.imdb.com/title/tt0081568/?ref_=adv_li_tt - done
# starting: Bronco Billy http://www.imdb.com/title/tt0080472/?ref_=adv_li_tt - done
# starting: The Octagon http://www.imdb.com/title/tt0081259/?ref_=adv_li_tt - done
# starting: Schizoid http://www.imdb.com/title/tt0081459/?ref_=adv_li_tt - done
# starting: The Exterminator http://www.imdb.com/title/tt0080707/?ref_=adv_li_tt - done
# starting: Hopscotch http://www.imdb.com/title/tt0080889/?ref_=adv_li_tt - done
# starting: The Private Eyes http://www.imdb.com/title/tt0081376/?ref_=adv_li_tt - done
# starting: The Nude Bomb http://www.imdb.com/title/tt0081249/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 27.8%
# starting: Cattle Annie and Little Britches http://www.imdb.com/title/tt0082145/?ref_=adv_li_tt - done
# starting: A Change of Seasons http://www.imdb.com/title/tt0080515/?ref_=adv_li_tt - done
# starting: Stardust Memories http://www.imdb.com/title/tt0081554/?ref_=adv_li_tt - done
# starting: Up the Academy http://www.imdb.com/title/tt0081695/?ref_=adv_li_tt - done
# starting: The Children http://www.imdb.com/title/tt0080527/?ref_=adv_li_tt - done
# starting: How to Beat the High Cost of Living http://www.imdb.com/title/tt0080895/?ref_=adv_li_tt - done
# starting: The Mountain Men http://www.imdb.com/title/tt0081187/?ref_=adv_li_tt - done
# starting: Hangar 18 http://www.imdb.com/title/tt0080836/?ref_=adv_li_tt - done
# starting: Herbie Goes Bananas http://www.imdb.com/title/tt0080861/?ref_=adv_li_tt - done
# starting: Beyond Evil http://www.imdb.com/title/tt0080431/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 31.3%
# starting: When Time Ran Out... http://www.imdb.com/title/tt0081747/?ref_=adv_li_tt - done
# starting: Inside Moves http://www.imdb.com/title/tt0080928/?ref_=adv_li_tt - done
# starting: Blood Beach http://www.imdb.com/title/tt0082083/?ref_=adv_li_tt - done
# starting: The Competition http://www.imdb.com/title/tt0080556/?ref_=adv_li_tt - done
# starting: To All a Goodnight http://www.imdb.com/title/tt0086449/?ref_=adv_li_tt - done
# starting: Christmas Evil http://www.imdb.com/title/tt0081793/?ref_=adv_li_tt - done
# starting: The Earthling http://www.imdb.com/title/tt0080671/?ref_=adv_li_tt - done
# starting: Don't Answer the Phone! http://www.imdb.com/title/tt0080645/?ref_=adv_li_tt - done
# starting: The Unseen http://www.imdb.com/title/tt0083261/?ref_=adv_li_tt - done
# starting: Times Square http://www.imdb.com/title/tt0081635/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 34.9%
# starting: Battle Creek Brawl http://www.imdb.com/title/tt0080436/?ref_=adv_li_tt - done
# starting: The Boogey Man http://www.imdb.com/title/tt0080464/?ref_=adv_li_tt - done
# starting: The Fiendish Plot of Dr. Fu Manchu http://www.imdb.com/title/tt0080731/?ref_=adv_li_tt - done
# starting: Resurrection http://www.imdb.com/title/tt0081414/?ref_=adv_li_tt - done
# starting: Permanent Vacation http://www.imdb.com/title/tt0084488/?ref_=adv_li_tt - done
# starting: Fatso http://www.imdb.com/title/tt0080724/?ref_=adv_li_tt - done
# starting: Just Tell Me What You Want http://www.imdb.com/title/tt0080975/?ref_=adv_li_tt - done
# starting: Demented http://www.imdb.com/title/tt0188557/?ref_=adv_li_tt - done
# starting: Honeysuckle Rose http://www.imdb.com/title/tt0080888/?ref_=adv_li_tt - done
# starting: The Hearse http://www.imdb.com/title/tt0080853/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 38.4%
# starting: The Formula http://www.imdb.com/title/tt0080754/?ref_=adv_li_tt - done
# starting: Wholly Moses! http://www.imdb.com/title/tt0081751/?ref_=adv_li_tt - done
# starting: Scared to Death http://www.imdb.com/title/tt0081457/?ref_=adv_li_tt - done
# starting: Night Games http://www.imdb.com/title/tt0081228/?ref_=adv_li_tt - done
# starting: It's My Turn http://www.imdb.com/title/tt0080936/?ref_=adv_li_tt - done
# starting: The Idolmaker http://www.imdb.com/title/tt0080913/?ref_=adv_li_tt - done
# starting: Rough Cut http://www.imdb.com/title/tt0081439/?ref_=adv_li_tt - done
# starting: New Year's Evil http://www.imdb.com/title/tt0082806/?ref_=adv_li_tt - done
# starting: Roadie http://www.imdb.com/title/tt0081433/?ref_=adv_li_tt - done
# starting: Borderline http://www.imdb.com/title/tt0080465/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 41.9%
# starting: Windows http://www.imdb.com/title/tt0081759/?ref_=adv_li_tt - done
# starting: In God We Trust (or Gimme That Prime Time Religion) http://www.imdb.com/title/tt0080917/?ref_=adv_li_tt - done
# starting: Gorp http://www.imdb.com/title/tt0080809/?ref_=adv_li_tt - done
# starting: The Happy Hooker Goes Hollywood http://www.imdb.com/title/tt0080839/?ref_=adv_li_tt - done
# starting: The Last Flight of Noah's Ark http://www.imdb.com/title/tt0081031/?ref_=adv_li_tt - done
# starting: Oh Heavenly Dog http://www.imdb.com/title/tt0081269/?ref_=adv_li_tt - done
# starting: Defiance http://www.imdb.com/title/tt0080605/?ref_=adv_li_tt - done
# starting: Animalympics http://www.imdb.com/title/tt0078780/?ref_=adv_li_tt - done
# starting: The Man with Bogart's Face http://www.imdb.com/title/tt0081110/?ref_=adv_li_tt - done
# starting: Cabo Blanco http://www.imdb.com/title/tt0080485/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 45.4%
# starting: Heart Beat http://www.imdb.com/title/tt0080854/?ref_=adv_li_tt - done
# starting: Windwalker http://www.imdb.com/title/tt0081760/?ref_=adv_li_tt - done
# starting: Hero at Large http://www.imdb.com/title/tt0080863/?ref_=adv_li_tt - done
# starting: Serial http://www.imdb.com/title/tt0081485/?ref_=adv_li_tt - done
# starting: HealtH http://www.imdb.com/title/tt0079256/?ref_=adv_li_tt - done
# starting: Foolin' Around http://www.imdb.com/title/tt0080750/?ref_=adv_li_tt - done
# starting: Hardly Working http://www.imdb.com/title/tt0082501/?ref_=adv_li_tt - done
# starting: One-Trick Pony http://www.imdb.com/title/tt0081280/?ref_=adv_li_tt - done
# starting: Bon Voyage, Charlie Brown (and Don't Come Back!!) http://www.imdb.com/title/tt0080461/?ref_=adv_li_tt - done
# starting: The Black Marble http://www.imdb.com/title/tt0080442/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 48.9%
# starting: Middle Age Crazy http://www.imdb.com/title/tt0081157/?ref_=adv_li_tt - done
# starting: Union City http://www.imdb.com/title/tt0081687/?ref_=adv_li_tt - done
# starting: Night of the Juggler http://www.imdb.com/title/tt0081230/?ref_=adv_li_tt - done
# starting: Willie & Phil http://www.imdb.com/title/tt0081758/?ref_=adv_li_tt - done
# starting: Running Scared http://www.imdb.com/title/tt0081445/?ref_=adv_li_tt - done
# starting: The Return http://www.imdb.com/title/tt0081421/?ref_=adv_li_tt - done
# starting: The Gong Show Movie http://www.imdb.com/title/tt0080808/?ref_=adv_li_tt - done
# starting: Hide in Plain Sight http://www.imdb.com/title/tt0080868/?ref_=adv_li_tt - done
# starting: Loving Couples http://www.imdb.com/title/tt0081080/?ref_=adv_li_tt - done
# starting: The Attic http://www.imdb.com/title/tt0078806/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 52.5%
# starting: Toxic Zombies http://www.imdb.com/title/tt0080448/?ref_=adv_li_tt - done
# starting: The Alien Dead http://www.imdb.com/title/tt0080346/?ref_=adv_li_tt - done
# starting: Little Miss Marker http://www.imdb.com/title/tt0081063/?ref_=adv_li_tt - done
# starting: Sunday Lovers http://www.imdb.com/title/tt0081591/?ref_=adv_li_tt - done
# starting: Dr. Heckyl and Mr. Hype http://www.imdb.com/title/tt0080658/?ref_=adv_li_tt - done
# starting: Oh, God! Book II http://www.imdb.com/title/tt0081268/?ref_=adv_li_tt - done
# starting: The Last Married Couple in America http://www.imdb.com/title/tt0081032/?ref_=adv_li_tt - done
# starting: Touched by Love http://www.imdb.com/title/tt0081646/?ref_=adv_li_tt - done
# starting: Ruckus http://www.imdb.com/title/tt0084611/?ref_=adv_li_tt - done
# starting: Witches' Brew http://www.imdb.com/title/tt0081763/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 56.0%
# starting: Why Would I Lie? http://www.imdb.com/title/tt0081753/?ref_=adv_li_tt - done
# starting: Coast to Coast http://www.imdb.com/title/tt0080550/?ref_=adv_li_tt - done
# starting: Jane Austen in Manhattan http://www.imdb.com/title/tt0080945/?ref_=adv_li_tt - done
# starting: First Family http://www.imdb.com/title/tt0080739/?ref_=adv_li_tt - done
# starting: Die Laughing http://www.imdb.com/title/tt0080627/?ref_=adv_li_tt - done
# starting: Monstroid http://www.imdb.com/title/tt0079573/?ref_=adv_li_tt - done
# starting: Below the Belt http://www.imdb.com/title/tt0080427/?ref_=adv_li_tt - done
# starting: Nijinsky http://www.imdb.com/title/tt0081235/?ref_=adv_li_tt - done
# starting: Wolf Lake http://www.imdb.com/title/tt0078508/?ref_=adv_li_tt - done
# starting: Hot T-Shirts http://www.imdb.com/title/tt0079309/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 59.5%
# starting: S.H.E: Security Hazards Expert http://www.imdb.com/title/tt0081447/?ref_=adv_li_tt - done
# starting: A Small Circle of Friends http://www.imdb.com/title/tt0081528/?ref_=adv_li_tt - done
# starting: Simon http://www.imdb.com/title/tt0081518/?ref_=adv_li_tt - done
# starting: Those Lips, Those Eyes http://www.imdb.com/title/tt0081625/?ref_=adv_li_tt - done
# starting: The Baltimore Bullet http://www.imdb.com/title/tt0080412/?ref_=adv_li_tt - done
# starting: Island Claws http://www.imdb.com/title/tt0080933/?ref_=adv_li_tt - done
# starting: Second-Hand Hearts http://www.imdb.com/title/tt0083041/?ref_=adv_li_tt - done
# starting: Cheaper to Keep Her http://www.imdb.com/title/tt0080519/?ref_=adv_li_tt - done
# starting: Fiend http://www.imdb.com/title/tt0080730/?ref_=adv_li_tt - done
# starting: Cataclysm http://www.imdb.com/title/tt0080506/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 63.0%
# starting: The Return of Josey Wales http://www.imdb.com/title/tt0331327/?ref_=adv_li_tt - done
# starting: Falling in Love Again http://www.imdb.com/title/tt0080714/?ref_=adv_li_tt - done
# starting: The Pilot http://www.imdb.com/title/tt0079719/?ref_=adv_li_tt - done
# starting: Happy Birthday, Gemini http://www.imdb.com/title/tt0080837/?ref_=adv_li_tt - done
# starting: Rana: The Legend of Shadow Lake http://www.imdb.com/title/tt0073604/?ref_=adv_li_tt - done
# starting: Gilda Live http://www.imdb.com/title/tt0080790/?ref_=adv_li_tt - done
# starting: Challenge of the Tiger http://www.imdb.com/title/tt0077645/?ref_=adv_li_tt - done
# starting: L'enlèvement du président http://www.imdb.com/title/tt0080997/?ref_=adv_li_tt - done
# starting: The American Success Company http://www.imdb.com/title/tt0078765/?ref_=adv_li_tt - done
# starting: Blank Generation http://www.imdb.com/title/tt0078873/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 66.5%
# starting: Becoming Orgasmic: A Sexual Growth Program for Women http://www.imdb.com/title/tt0211230/?ref_=adv_li_tt - done
# starting: Bloodrage http://www.imdb.com/title/tt0078880/?ref_=adv_li_tt - done
# starting: Terror on Tour http://www.imdb.com/title/tt0081619/?ref_=adv_li_tt - done
# starting: The Killings at Outpost Zeta http://www.imdb.com/title/tt0168922/?ref_=adv_li_tt - done
# starting: Cloud Dancer http://www.imdb.com/title/tt0080545/?ref_=adv_li_tt - done
# starting: Hoodlums http://www.imdb.com/title/tt0079192/?ref_=adv_li_tt - done
# starting: Cuba Crossing http://www.imdb.com/title/tt0080580/?ref_=adv_li_tt - done
# starting: Seed of Innocence http://www.imdb.com/title/tt0081479/?ref_=adv_li_tt - done
# starting: I Go Pogo http://www.imdb.com/title/tt0087925/?ref_=adv_li_tt - done
# starting: Hotwire http://www.imdb.com/title/tt0080893/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 70.1%
# starting: Tell Me a Riddle http://www.imdb.com/title/tt0081611/?ref_=adv_li_tt - done
# starting: The Long Island Cannibal Massacre http://www.imdb.com/title/tt0307105/?ref_=adv_li_tt - done
# starting: Personal Problems http://www.imdb.com/title/tt0285891/?ref_=adv_li_tt - done
# ...
# starting: The Hot House http://www.imdb.com/title/tt0220530/?ref_=adv_li_tt - done
# starting: The Juggler of Notre Dame http://www.imdb.com/title/tt0194995/?ref_=adv_li_tt - done
# starting: Gregorio and His Angel http://www.imdb.com/title/tt0060477/?ref_=adv_li_tt - done
# starting: Sex Odyssey http://www.imdb.com/title/tt2597844/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 67.5%
# starting: Anomalies: A World of Dreams http://www.imdb.com/title/tt0210529/?ref_=adv_li_tt - done
# starting: Love Thy Neighbor and His Wife http://www.imdb.com/title/tt0125868/?ref_=adv_li_tt - done
# starting: Franchesca's Sexual Whirlpool http://www.imdb.com/title/tt0218273/?ref_=adv_li_tt - done
# starting: Wall Street Walker http://www.imdb.com/title/tt0260527/?ref_=adv_li_tt - done
# starting: Everybody Goes Ape http://www.imdb.com/title/tt2204898/?ref_=adv_li_tt - done
# starting: Barbie's Hospital Affair http://www.imdb.com/title/tt0211217/?ref_=adv_li_tt - done
# starting: Titilated Tex http://www.imdb.com/title/tt2198686/?ref_=adv_li_tt - done
# starting: Analyze Your Sex http://www.imdb.com/title/tt2204806/?ref_=adv_li_tt - done
# starting: Sister Fanny http://www.imdb.com/title/tt3655486/?ref_=adv_li_tt - done
# starting: I Am Curious Gay http://www.imdb.com/title/tt0219088/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 69.3%
# starting: Love Is a Four Letter Word http://www.imdb.com/title/tt2440988/?ref_=adv_li_tt - done
# starting: Yellow Bird http://www.imdb.com/title/tt0261438/?ref_=adv_li_tt - done
# starting: Frenzy http://www.imdb.com/title/tt0218980/?ref_=adv_li_tt - done
# starting: Fusion http://www.imdb.com/title/tt0144211/?ref_=adv_li_tt - done
# starting: Fisherman's Luck http://www.imdb.com/title/tt0261694/?ref_=adv_li_tt - done
# starting: Scent of Love http://www.imdb.com/title/tt4644620/?ref_=adv_li_tt - done
# starting: Shoot-out at Beaver Falls http://www.imdb.com/title/tt0257177/?ref_=adv_li_tt - done
# starting: Lip Service http://www.imdb.com/title/tt3621896/?ref_=adv_li_tt - done
# starting: One Hundred Dollar Wife http://www.imdb.com/title/tt1971490/?ref_=adv_li_tt - done
# starting: Bunny and Clod http://www.imdb.com/title/tt0212014/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 71.1%
# starting: Bar Maid http://www.imdb.com/title/tt0211214/?ref_=adv_li_tt - done
# starting: April in the Wind http://www.imdb.com/title/tt0179645/?ref_=adv_li_tt - done
# starting: Plushette's Sweet Revenge http://www.imdb.com/title/tt0255486/?ref_=adv_li_tt - done
# starting: Lip Smackers http://www.imdb.com/title/tt3631502/?ref_=adv_li_tt - done
# starting: Stick It in Your Ear http://www.imdb.com/title/tt0066405/?ref_=adv_li_tt - done
# starting: Convicts Two and Sex http://www.imdb.com/title/tt2476000/?ref_=adv_li_tt - done
# starting: Lonely Housewife http://www.imdb.com/title/tt0249752/?ref_=adv_li_tt - done
# starting: Can Your Daughter Come Out Tonight? http://www.imdb.com/title/tt6482008/?ref_=adv_li_tt - done
# starting: Take Them - As They Are http://www.imdb.com/title/tt1553381/?ref_=adv_li_tt - done
# starting: The Experiment http://www.imdb.com/title/tt2022557/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 72.9%
# starting: In a Little Country Jail http://www.imdb.com/title/tt2467400/?ref_=adv_li_tt - done
# starting: Hard Knocks http://www.imdb.com/title/tt4662518/?ref_=adv_li_tt - done
# starting: Sweets for the Suite http://www.imdb.com/title/tt1869688/?ref_=adv_li_tt - done
# starting: Girl's Prison http://www.imdb.com/title/tt0219045/?ref_=adv_li_tt - done
# starting: Chicago 70 http://www.imdb.com/title/tt0121143/?ref_=adv_li_tt - done
# starting: The Five Minute Kiss http://www.imdb.com/title/tt1468878/?ref_=adv_li_tt - done
# starting: The Pleasure Game http://www.imdb.com/title/tt0255484/?ref_=adv_li_tt - done
# starting: Septuagenarian Substitute Ball http://www.imdb.com/title/tt0188196/?ref_=adv_li_tt - done
# starting: It All Comes Out in the End http://www.imdb.com/title/tt2198706/?ref_=adv_li_tt - done
# starting: The Upstairs Room http://www.imdb.com/title/tt0260485/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 74.8%
# starting: From Russia with Lust http://www.imdb.com/title/tt2455660/?ref_=adv_li_tt - done
# starting: S.L.I.P. http://www.imdb.com/title/tt13433028/?ref_=adv_li_tt - done
# starting: My Swedish Cousins http://www.imdb.com/title/tt0251884/?ref_=adv_li_tt - done
# starting: Sin for a Song http://www.imdb.com/title/tt2173918/?ref_=adv_li_tt - done
# starting: Little Boy Lust http://www.imdb.com/title/tt4678442/?ref_=adv_li_tt - done
# starting: Lovers by Appointment http://www.imdb.com/title/tt0250540/?ref_=adv_li_tt - done
# starting: I Do Voodoo http://www.imdb.com/title/tt2205126/?ref_=adv_li_tt - done
# starting: West Texas http://www.imdb.com/title/tt15461230/?ref_=adv_li_tt - done
# starting: Carny Girl http://www.imdb.com/title/tt0212043/?ref_=adv_li_tt - done
# starting: Boys in Chains http://www.imdb.com/title/tt0211987/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 76.6%
# starting: 6-9 the Daily Double http://www.imdb.com/title/tt0257352/?ref_=adv_li_tt - done
# starting: Harem Hangups http://www.imdb.com/title/tt2204918/?ref_=adv_li_tt - done
# starting: Lisa's Folly http://www.imdb.com/title/tt0249733/?ref_=adv_li_tt - done
# starting: Runaround http://www.imdb.com/title/tt0257071/?ref_=adv_li_tt - done
# starting: Massacre http://www.imdb.com/title/tt6698246/?ref_=adv_li_tt - done
# starting: Class of 69 http://www.imdb.com/title/tt2203356/?ref_=adv_li_tt - done
# starting: Exchange Student http://www.imdb.com/title/tt0218185/?ref_=adv_li_tt - done
# starting: On the Casting Couch http://www.imdb.com/title/tt2203860/?ref_=adv_li_tt - done
# starting: Penthouse Party Girl http://www.imdb.com/title/tt3768650/?ref_=adv_li_tt - done
# starting: The Love Doctors http://www.imdb.com/title/tt0250519/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 78.4%
# starting: One for the Money http://www.imdb.com/title/tt0261878/?ref_=adv_li_tt - done
# starting: Circus http://www.imdb.com/title/tt0285480/?ref_=adv_li_tt - done
# starting: Bunny Blossom http://www.imdb.com/title/tt2178126/?ref_=adv_li_tt - done
# starting: Love in Chains http://www.imdb.com/title/tt0250533/?ref_=adv_li_tt - done
# starting: The Grapedealer's Daughter http://www.imdb.com/title/tt0206784/?ref_=adv_li_tt - done
# starting: Martin Luther http://www.imdb.com/title/tt9624678/?ref_=adv_li_tt - done
# starting: Make Out Madam http://www.imdb.com/title/tt0250566/?ref_=adv_li_tt - done
# starting: Doctor No http://www.imdb.com/title/tt2203888/?ref_=adv_li_tt - done
# starting: We Do It! http://www.imdb.com/title/tt0260537/?ref_=adv_li_tt - done
# starting: The Sultan http://www.imdb.com/title/tt0259001/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 80.4%
# starting: A Taste of Youth http://www.imdb.com/title/tt2203606/?ref_=adv_li_tt - done
# starting: The Secret of the Sacred Forest http://www.imdb.com/title/tt0066348/?ref_=adv_li_tt - done
# starting: Purse Snatch http://www.imdb.com/title/tt2203574/?ref_=adv_li_tt - done
# starting: Warm in the Bud http://www.imdb.com/title/tt0261402/?ref_=adv_li_tt - done
# starting: Women Women Women Moira http://www.imdb.com/title/tt0261422/?ref_=adv_li_tt - done
# starting: Venice Nitemare http://www.imdb.com/title/tt2204170/?ref_=adv_li_tt - done
# starting: Genius http://www.imdb.com/title/tt0195744/?ref_=adv_li_tt - done
# starting: Thaw the Frigid Bird http://www.imdb.com/title/tt1530506/?ref_=adv_li_tt - done
# starting: Why Russians Are Revolting http://www.imdb.com/title/tt0260569/?ref_=adv_li_tt - done
# starting: Girls for Hire http://www.imdb.com/title/tt0219048/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 82.3%
# starting: Classified Love http://www.imdb.com/title/tt2471504/?ref_=adv_li_tt - done
# starting: Hot Line http://www.imdb.com/title/tt0220532/?ref_=adv_li_tt - done
# starting: Taking Care of Mother Baldwin http://www.imdb.com/title/tt0277368/?ref_=adv_li_tt - done
# starting: Gabrielle http://www.imdb.com/title/tt0218997/?ref_=adv_li_tt - done
# starting: Photo-Finnish Style http://www.imdb.com/title/tt0254684/?ref_=adv_li_tt - done
# starting: Big Beaver http://www.imdb.com/title/tt0211250/?ref_=adv_li_tt - done
# starting: Secretaries Spread http://www.imdb.com/title/tt0257121/?ref_=adv_li_tt - done
# starting: Lust Combo http://www.imdb.com/title/tt0276304/?ref_=adv_li_tt - done
# starting: Notorious Big Sin City http://www.imdb.com/title/tt0145131/?ref_=adv_li_tt - done
# starting: Snow Bear http://www.imdb.com/title/tt0066388/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 84.1%
# starting: Hot Boarding House http://www.imdb.com/title/tt0219815/?ref_=adv_li_tt - done
# starting: Orgy in the Ozarks http://www.imdb.com/title/tt0254635/?ref_=adv_li_tt - done
# starting: Don't Push Me http://www.imdb.com/title/tt0217379/?ref_=adv_li_tt - done
# starting: The Discovery of America http://www.imdb.com/title/tt0216716/?ref_=adv_li_tt - done
# starting: Interplay http://www.imdb.com/title/tt0221285/?ref_=adv_li_tt - done
# starting: The Sidewalk Cowboy http://www.imdb.com/title/tt0258150/?ref_=adv_li_tt - done
# starting: Sweet Is the Meat http://www.imdb.com/title/tt0259013/?ref_=adv_li_tt - done
# starting: Carla's Thing http://www.imdb.com/title/tt0371595/?ref_=adv_li_tt - done
# starting: Here Comes Dodie http://www.imdb.com/title/tt2203662/?ref_=adv_li_tt - done
# starting: Mr. Grabb http://www.imdb.com/title/tt2178252/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 85.9%
# starting: Delightful Dilemma http://www.imdb.com/title/tt2208394/?ref_=adv_li_tt - done
# starting: I, a Pussy http://www.imdb.com/title/tt2204604/?ref_=adv_li_tt - done
# starting: Genesis III http://www.imdb.com/title/tt0065771/?ref_=adv_li_tt - done
# starting: Girls on a Rainy Night http://www.imdb.com/title/tt3623898/?ref_=adv_li_tt - done
# starting: The Married Bachelor http://www.imdb.com/title/tt4644666/?ref_=adv_li_tt - done
# starting: Wild in the Woods http://www.imdb.com/title/tt0261413/?ref_=adv_li_tt - done
# starting: All the Roman Muscles http://www.imdb.com/title/tt2018036/?ref_=adv_li_tt - done
# starting: The Sky Pirate http://www.imdb.com/title/tt0258165/?ref_=adv_li_tt - done
# starting: The Girls in 7-C http://www.imdb.com/title/tt0219049/?ref_=adv_li_tt - done
# starting: Escape to Exstacy http://www.imdb.com/title/tt2203396/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 87.8%
# starting: Gypsy Passion http://www.imdb.com/title/tt2204844/?ref_=adv_li_tt - done
# starting: Am I Female? http://www.imdb.com/title/tt0210492/?ref_=adv_li_tt - done
# starting: Flesh Hustler http://www.imdb.com/title/tt0218254/?ref_=adv_li_tt - done
# starting: Wanderlove http://www.imdb.com/title/tt0295681/?ref_=adv_li_tt - done
# starting: He Is Coming http://www.imdb.com/title/tt0219751/?ref_=adv_li_tt - done
# starting: Imogen Cunningham, Photographer http://www.imdb.com/title/tt0204397/?ref_=adv_li_tt - done
# starting: Scenes from Under Childhood Section #4 http://www.imdb.com/title/tt0278015/?ref_=adv_li_tt - done
# starting: Mac Foster vs. Jerry Quarry http://www.imdb.com/title/tt2338546/?ref_=adv_li_tt - done
# starting: London Clouds http://www.imdb.com/title/tt0065996/?ref_=adv_li_tt - done
# starting: The Hungry Man http://www.imdb.com/title/tt0220560/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 89.6%
# starting: Coming Out Party http://www.imdb.com/title/tt2234146/?ref_=adv_li_tt - done
# starting: Sweet Taste of Joy http://www.imdb.com/title/tt0259016/?ref_=adv_li_tt - done
# starting: Love Models http://www.imdb.com/title/tt3626458/?ref_=adv_li_tt - done
# starting: The Contest http://www.imdb.com/title/tt0261622/?ref_=adv_li_tt - done
# starting: Turned-on Girl http://www.imdb.com/title/tt0260448/?ref_=adv_li_tt - done
# starting: Skool Daze http://www.imdb.com/title/tt3624086/?ref_=adv_li_tt - done
# starting: The Final Blow http://www.imdb.com/title/tt0124554/?ref_=adv_li_tt - done
# starting: Ants in My Pants http://www.imdb.com/title/tt2203418/?ref_=adv_li_tt - done
# starting: India http://www.imdb.com/title/tt0292015/?ref_=adv_li_tt - done
# starting: School Play http://www.imdb.com/title/tt1645874/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 91.4%
# starting: Mixed Fruit http://www.imdb.com/title/tt0251848/?ref_=adv_li_tt - done
# starting: Mother Knows Best http://www.imdb.com/title/tt4287362/?ref_=adv_li_tt - done
# starting: Indian Love Cult http://www.imdb.com/title/tt2178148/?ref_=adv_li_tt - done
# starting: Early to Bed http://www.imdb.com/title/tt2203930/?ref_=adv_li_tt - done
# starting: Coming Attractions http://www.imdb.com/title/tt0215645/?ref_=adv_li_tt - done
# starting: Pipo http://www.imdb.com/title/tt0086441/?ref_=adv_li_tt - done
# starting: Ride Dr. Chicago Ride http://www.imdb.com/title/tt12717934/?ref_=adv_li_tt - done
# starting: The Doctor and His Women http://www.imdb.com/title/tt4621012/?ref_=adv_li_tt - done
# starting: History http://www.imdb.com/title/tt0159477/?ref_=adv_li_tt - done
# starting: You Can't Spell 'Sex' Without ... X http://www.imdb.com/title/tt0261431/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 93.2%
# starting: Field http://www.imdb.com/title/tt0159439/?ref_=adv_li_tt - done
# starting: Trick and the Trade http://www.imdb.com/title/tt0260433/?ref_=adv_li_tt - done
# starting: Marigold Man http://www.imdb.com/title/tt0245263/?ref_=adv_li_tt - done
# starting: Hot Lips for Hot Heads http://www.imdb.com/title/tt0220533/?ref_=adv_li_tt - done
# starting: The Consul http://www.imdb.com/title/tt12958370/?ref_=adv_li_tt - done
# starting: Standing Rock: A Vision http://www.imdb.com/title/tt0301889/?ref_=adv_li_tt - done
# starting: College for Fun and Profit http://www.imdb.com/title/tt14080164/?ref_=adv_li_tt - done
# starting: Laura in Love http://www.imdb.com/title/tt2203834/?ref_=adv_li_tt - done
# starting: It's My Job http://www.imdb.com/title/tt8728684/?ref_=adv_li_tt - done
# starting: Money-Maker http://www.imdb.com/title/tt3626462/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 95.1%
# starting: Why Not: A Serenade of Eschatological Ecology http://www.imdb.com/title/tt0260567/?ref_=adv_li_tt - done
# starting: The Adversary http://www.imdb.com/title/tt0185845/?ref_=adv_li_tt - done
# starting: Your Astronauts http://www.imdb.com/title/tt0154014/?ref_=adv_li_tt - done
# starting: The Honeymoon Is Over http://www.imdb.com/title/tt2203896/?ref_=adv_li_tt - done
# starting: Dixie http://www.imdb.com/title/tt0220567/?ref_=adv_li_tt - done
# starting: Cemeteries http://www.imdb.com/title/tt0284950/?ref_=adv_li_tt - done
# starting: Rindercella http://www.imdb.com/title/tt2204074/?ref_=adv_li_tt - done
# starting: Last of the Two Dollar... http://www.imdb.com/title/tt0249685/?ref_=adv_li_tt - done
# starting: Paradise Island http://www.imdb.com/title/tt3626448/?ref_=adv_li_tt - done
# starting: Nature's Cure http://www.imdb.com/title/tt2203816/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 96.9%
# starting: Friday on My Mind http://www.imdb.com/title/tt0218982/?ref_=adv_li_tt - done
# starting: Branches http://www.imdb.com/title/tt0177570/?ref_=adv_li_tt - done
# starting: That's a Dirty Trick http://www.imdb.com/title/tt2203844/?ref_=adv_li_tt - done
# starting: Spiro Agnew's Asian Trip http://www.imdb.com/title/tt0066398/?ref_=adv_li_tt - done
# starting: The Whale Hunters of Fayal http://www.imdb.com/title/tt0130362/?ref_=adv_li_tt - done
# starting: The Midnight Jogger http://www.imdb.com/title/tt0251269/?ref_=adv_li_tt - done
# starting: Prescription Sex http://www.imdb.com/title/tt3626454/?ref_=adv_li_tt - done
# starting: The Ransom http://www.imdb.com/title/tt2205096/?ref_=adv_li_tt - done
# starting: Tongue Tied http://www.imdb.com/title/tt2204124/?ref_=adv_li_tt - done
# starting: Suzuran-Ko http://www.imdb.com/title/tt0194420/?ref_=adv_li_tt - done
# Saved!
# COMPLETION: 98.7%
# starting: Four in Bed http://www.imdb.com/title/tt1511365/?ref_=adv_li_tt - done
# starting: Two Over Easy! http://www.imdb.com/title/tt3631548/?ref_=adv_li_tt - done
# starting: Mud Maidens http://www.imdb.com/title/tt0251870/?ref_=adv_li_tt - done
# starting: No Holds Barred http://www.imdb.com/title/tt2203922/?ref_=adv_li_tt - done
# starting: The Mad Doctor http://www.imdb.com/title/tt3626452/?ref_=adv_li_tt - done
# starting: The Low Blow http://www.imdb.com/title/tt0250542/?ref_=adv_li_tt - done
# 1970 done.
# Saved!
