# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline                           
# %config InlineBackend.figure_format = 'retina'

# %%
energymix0 = pd.read_csv("./data/World_Energy_Consumption.csv", sep=",", skiprows=[], header=0)
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %%
energymix = energymix0.fillna(0.0)
energymix = energymix.drop('iso_code' , axis=1)
energymix = energymix.set_index('country')
energymix = energymix.set_index('year', append=True)
energymix
# Out:
#                   coal_prod_change_pct  coal_prod_change_twh  \
# country     year
# Afghanistan 1900                 0.000                 0.000
#             1901                 0.000                 0.000
#             1902                 0.000                 0.000
#             1903                 0.000                 0.000
#             1904                 0.000                 0.000
# ...                                ...                   ...
# Zimbabwe    2015               -25.013               -10.847
#             2016               -37.694               -12.257
#             2017                 8.375                 1.697
#             2018                22.555                 4.952
#             2019               -35.015                -9.422
#
#                   gas_prod_change_pct  gas_prod_change_twh  \
# country     year
# Afghanistan 1900                  0.0                  0.0
#             1901                  0.0                  0.0
# ...

# %%
columns = energymix.columns.values.tolist()
energymix.loc['France'].loc[2019]
# Out:
# coal_prod_change_pct         0.000
# coal_prod_change_twh         0.000
# gas_prod_change_pct          0.000
# gas_prod_change_twh          0.000
# oil_prod_change_pct          0.000
#                             ...
# wind_share_energy            3.176
# wind_cons_change_twh        15.579
# wind_consumption            85.380
# wind_elec_per_capita       515.877
# wind_energy_per_capita    1310.922
# Name: 2019, Length: 119, dtype: float64
